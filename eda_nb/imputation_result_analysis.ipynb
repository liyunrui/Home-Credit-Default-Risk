# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 10] # customizing
import os

# %%
method = ['base_featurs_filled_knn_10_w_target',
                                    'base_featurs_filled_knn_5_wo_target',
                                    'base_featurs_filled_knn_5_w_target',
                                    'base_featurs_filled_knn_15_wo_target',
                                    'base_featurs_filled_knn_20_wo_target',
                                    'base_featurs_filled_knn_20_w_target',
                                    'base_featurs_filled_knn_10_wo_target',
                                    'base_featurs_filled_knn_15_w_target',
                                    'base_featurs_filled_mice_clustering',
                                    'base_featurs_filled_knn_65_wo_target',
                                    'base_featurs_filled_knn_95_w_target',
                                    'base_featurs_filled_knn_30_wo_target',
                                    'base_featurs_filled_knn_45_w_target',
                                    'base_featurs_filled_knn_75_wo_target',
                                    'base_featurs_filled_knn_40_w_target',
                                    'base_featurs_filled_mice_by_cluster_2',
                                    'base_featurs_filled_mice_by_cluster_1',
                                    'base_featurs_filled_mice_by_cluster_2+1',
                                    'base_featurs_filled_knn_k_65_by_cluster_2',
                                    'base_featurs_filled_knn_k_65_by_cluster_1',
                                    'base_featurs_filled_knn_k_65_by_cluster_0',
                                    'base_featurs_filled_knn_k_65_by_cluster_2+1',
                                    'base_featurs_filled_by_matrix_cluster_2_1',
                                    'base_featurs_filled_by_matrix_cluster_1',
                                    'base_featurs_filled_by_matrix_cluster_2', 
                                    'base_featurs_filled_knn_k_65_corr_0_95',
                                    'base_featurs_filled_knn_k_65_corr_0_95_with_10_fold',
                                    'normalized_knn_65_similar_features_2',
                                    'normalized_knn_65_similar_features_2_180',
                                    'normalized_knn_65_similar_features_3',
                                    'normalized_knn_65_similar_features_7',
                                    'normalized_knn_65_similar_features_19',
                                    'normalized_knn_65_similar_features_36',
                                    'normalized_knn_65_cluster1',
                                    'normalized_knn_65_discrete',
                                    'normalized_mice_discrete',
                                    'normalized_mice_similar_features_th_09_5',
                                    'normalized_knn_65_cluster_1_2_3',
                                    'normalized_knn_65_similar_features_th_09_1',
                                    'normalized_mice_cluster_3',
                                    'normalized_mice_cluster_1_2_3',
                                    'normalized_mice_similar_features_th_09_2',
                                    'normalized_mice_similar_features_th_09_1',
                                    'normalized_mice_cluster_2',
                                    'normalized_mice_cluster_1',
                                    'normalized_knn_65_similar_features_th_09_2',
                                    'normalized_knn_65_cluster3',
                                    'normalized_mice_discrete_wo_target',
                                    'normalized_mice_discrete_w_peeking_target_724'
                                    ]
result = pd.DataFrame({'inputation_method': method,
              'Over-iterations val AUC score_before_imputation':[0.795883003439369 for i in range(len(method))],
              'Over-iterations val AUC score_after_imputation':[0.7929492979464368,
                                                                0.7917706414389409,
                                                                0.7917425417690069,
                                                                0.7929189796343843,
                                                                0.7934440947821526,
                                                                0.7933124590025196,
                                                                0.7928583434662771,
                                                                0.7929393397993938,
                                                                0.7934668162310325,
                                                                0.7939862930253605,
                                                                0.7939162903386083,
                                                                0.7932531052706889,
                                                                0.7935473870756299,
                                                                0.79391868959853,
                                                                0.7935994923549614,
                                                                0.7957702270796132,
                                                                0.7958559069641756,
                                                                0.7960693479739345,
                                                                0.795858457757803,
                                                                0.7959288901225524,
                                                                0.793722729741624,
                                                                0.7958257291421369,
                                                                0.7942451313046186,
                                                                0.7954564159800571,
                                                                0.794750009563481,
                                                                0.7955948901705888,
                                                                0.7954045365620417,
                                                                0.7958420690042229,
                                                                0.7959379558537741,
                                                                0.7959339612007167,
                                                                0.7958031352728379,
                                                                0.7957407025881491,
                                                                0.7955405998789626,
                                                                0.7959569681895997,
                                                                0.8228565418909719,
                                                                0.8229662814491487,
                                                                0.7960100099312716,
                                                                0.7958134202276678,
                                                                0.7959534564665103,
                                                                0.7960349309986199,
                                                                0.7959737467926358,
                                                                0.7957615166275289,
                                                                0.7959143905100685,
                                                                0.7959409677179841,
                                                                0.7958536576847178,
                                                                0.7957680800576193,
                                                                0.7958758104475793,
                                                                0.7958061506425296,
                                                                0.7958496530282128],
             })
# compiled_k = re.compile(r'knn_\d*')
# result['w_target'] = [0 if 'wo' in i else 1 for i in result.inputation_method]
# result['k'] = [int(compiled_k.findall(i)[0][4:]) for i in result.inputation_method if compiled_k.search(i) ]
# result.sort_values(by = 'k', inplace = True)
# result.index = [i for i in range(len(result))]
# result
#result = result[~result.inputation_method.str.contains('discrete')]
result.sort_values(by = 'Over-iterations val AUC score_after_imputation', ascending = False)
# Out:
#                                     inputation_method  \
# 35                           normalized_mice_discrete
# 34                         normalized_knn_65_discrete
# 17            base_featurs_filled_mice_by_cluster_2+1
# 39                          normalized_mice_cluster_3
# 36           normalized_mice_similar_features_th_09_5
# 40                      normalized_mice_cluster_1_2_3
# 33                         normalized_knn_65_cluster1
# 38         normalized_knn_65_similar_features_th_09_1
# 43                          normalized_mice_cluster_2
# 28           normalized_knn_65_similar_features_2_180
# 29               normalized_knn_65_similar_features_3
# 19          base_featurs_filled_knn_k_65_by_cluster_1
# 42           normalized_mice_similar_features_th_09_1
# 46                         normalized_knn_65_cluster3
# 18          base_featurs_filled_knn_k_65_by_cluster_2
# 16              base_featurs_filled_mice_by_cluster_1
# 44                          normalized_mice_cluster_1
# 48      normalized_mice_discrete_w_peeking_target_724
# 27               normalized_knn_65_similar_features_2
# 21        base_featurs_filled_knn_k_65_by_cluster_2+1
# 37                    normalized_knn_65_cluster_1_2_3
# 47                 normalized_mice_discrete_wo_target
# 30               normalized_knn_65_similar_features_7
# 15              base_featurs_filled_mice_by_cluster_2
# 45         normalized_knn_65_similar_features_th_09_2
# 41           normalized_mice_similar_features_th_09_2
# 31              normalized_knn_65_similar_features_19
# 25             base_featurs_filled_knn_k_65_corr_0_95
# 32              normalized_knn_65_similar_features_36
# 23            base_featurs_filled_by_matrix_cluster_1
# 26  base_featurs_filled_knn_k_65_corr_0_95_with_10...
# 24            base_featurs_filled_by_matrix_cluster_2
# 22          base_featurs_filled_by_matrix_cluster_2_1
# 9                base_featurs_filled_knn_65_wo_target
# 13               base_featurs_filled_knn_75_wo_target
# 10                base_featurs_filled_knn_95_w_target
# 20          base_featurs_filled_knn_k_65_by_cluster_0
# 14                base_featurs_filled_knn_40_w_target
# 12                base_featurs_filled_knn_45_w_target
# 8                 base_featurs_filled_mice_clustering
# 4                base_featurs_filled_knn_20_wo_target
# 5                 base_featurs_filled_knn_20_w_target
# 11               base_featurs_filled_knn_30_wo_target
# 0                 base_featurs_filled_knn_10_w_target
# 7                 base_featurs_filled_knn_15_w_target
# 3                base_featurs_filled_knn_15_wo_target
# 6                base_featurs_filled_knn_10_wo_target
# 1                 base_featurs_filled_knn_5_wo_target
# 2                  base_featurs_filled_knn_5_w_target
#
#     Over-iterations val AUC score_before_imputation  \
# 35                                         0.795883
# 34                                         0.795883
# 17                                         0.795883
# 39                                         0.795883
# 36                                         0.795883
# 40                                         0.795883
# 33                                         0.795883
# 38                                         0.795883
# 43                                         0.795883
# 28                                         0.795883
# 29                                         0.795883
# 19                                         0.795883
# 42                                         0.795883
# 46                                         0.795883
# 18                                         0.795883
# 16                                         0.795883
# 44                                         0.795883
# 48                                         0.795883
# 27                                         0.795883
# 21                                         0.795883
# 37                                         0.795883
# 47                                         0.795883
# 30                                         0.795883
# 15                                         0.795883
# 45                                         0.795883
# 41                                         0.795883
# 31                                         0.795883
# 25                                         0.795883
# 32                                         0.795883
# 23                                         0.795883
# 26                                         0.795883
# 24                                         0.795883
# 22                                         0.795883
# 9                                          0.795883
# 13                                         0.795883
# 10                                         0.795883
# 20                                         0.795883
# 14                                         0.795883
# 12                                         0.795883
# 8                                          0.795883
# 4                                          0.795883
# 5                                          0.795883
# 11                                         0.795883
# 0                                          0.795883
# 7                                          0.795883
# 3                                          0.795883
# 6                                          0.795883
# 1                                          0.795883
# 2                                          0.795883
#
#     Over-iterations val AUC score_after_imputation
# 35                                        0.822966
# 34                                        0.822857
# 17                                        0.796069
# 39                                        0.796035
# 36                                        0.796010
# 40                                        0.795974
# 33                                        0.795957
# 38                                        0.795953
# 43                                        0.795941
# 28                                        0.795938
# 29                                        0.795934
# 19                                        0.795929
# 42                                        0.795914
# 46                                        0.795876
# 18                                        0.795858
# 16                                        0.795856
# 44                                        0.795854
# 48                                        0.795850
# 27                                        0.795842
# 21                                        0.795826
# 37                                        0.795813
# 47                                        0.795806
# 30                                        0.795803
# 15                                        0.795770
# 45                                        0.795768
# 41                                        0.795762
# 31                                        0.795741
# 25                                        0.795595
# 32                                        0.795541
# 23                                        0.795456
# 26                                        0.795405
# 24                                        0.794750
# 22                                        0.794245
# 9                                         0.793986
# 13                                        0.793919
# 10                                        0.793916
# 20                                        0.793723
# 14                                        0.793599
# 12                                        0.793547
# 8                                         0.793467
# 4                                         0.793444
# 5                                         0.793312
# 11                                        0.793253
# 0                                         0.792949
# 7                                         0.792939
# 3                                         0.792919
# 6                                         0.792858
# 1                                         0.791771
# 2                                         0.791743

# %%
result.plot() # 先找到一組好的subset of features, 再來調整參數

# %%
0.795883 + 0.00028004088712766187
# Out:
# 0.7961630408871276

# %% [markdown]
# # best k

# %%
compiled_k = re.compile(r'knn_\d*')
result['w_target'] = [0 if 'wo' in i else 1 for i in result.inputation_method]
result = result[result.inputation_method != 'base_featurs_filled_mice_clustering']
result['k'] = [int(compiled_k.findall(i)[0][4:]) for i in result.inputation_method if compiled_k.search(i) ]
result.sort_values(by = 'k', inplace = True)
result.index = [i for i in range(len(result))]
result
# Out:
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                        inputation_method  \
# 0    base_featurs_filled_knn_5_wo_target
# 1     base_featurs_filled_knn_5_w_target
# 2    base_featurs_filled_knn_10_w_target
# 3   base_featurs_filled_knn_10_wo_target
# 4   base_featurs_filled_knn_15_wo_target
# 5    base_featurs_filled_knn_15_w_target
# 6   base_featurs_filled_knn_20_wo_target
# 7    base_featurs_filled_knn_20_w_target
# 8   base_featurs_filled_knn_30_wo_target
# 9    base_featurs_filled_knn_40_w_target
# 10   base_featurs_filled_knn_45_w_target
# 11  base_featurs_filled_knn_65_wo_target
# 12  base_featurs_filled_knn_75_wo_target
# 13   base_featurs_filled_knn_95_w_target
#
#     Over-iterations val AUC score_before_imputation  \
# 0                                          0.795883
# 1                                          0.795883
# 2                                          0.795883
# 3                                          0.795883
# 4                                          0.795883
# 5                                          0.795883
# 6                                          0.795883
# 7                                          0.795883
# 8                                          0.795883
# 9                                          0.795883
# 10                                         0.795883
# 11                                         0.795883
# 12                                         0.795883
# 13                                         0.795883
#
#     Over-iterations val AUC score_after_imputation  w_target   k
# 0                                         0.791771         0   5
# 1                                         0.791743         1   5
# 2                                         0.792949         1  10
# 3                                         0.792858         0  10
# 4                                         0.792919         0  15
# 5                                         0.792939         1  15
# 6                                         0.793444         0  20
# 7                                         0.793312         1  20
# 8                                         0.793253         0  30
# 9                                         0.793599         1  40
# 10                                        0.793547         1  45
# 11                                        0.793986         0  65
# 12                                        0.793919         0  75
# 13                                        0.793916         1  95

# %% [markdown]
# # w_target vs wo_target

# %%
result[result.w_target == 1]['Over-iterations val AUC score_after_imputation'].mean()
# Out:
# 0.7931438297552225

# %%
result[result.w_target == 0]['Over-iterations val AUC score_after_imputation'].mean() # 沒有target好一點
# Out:
# 0.7931643067451908

# %%
0.7931438297552225 - 0.7931643067451908 # 但根本沒有好多少, 是因為太多feature了, 影響價值
# Out:
# -2.0476989968321035e-05

# %%
result[result.w_target == 1][result.columns.tolist()[:-2]].plot()
plt.show() # k越大越好啊

# %%
result[result.w_target == 0][result.columns.tolist()[:-2]].plot()
plt.show()

# %%
len([k for k in np.arange(25, 100, step = 5)])
# Out:
# 15

# %%
df = pd.read_hdf('../features/filled_by_knn/normalized_knn_65_similar_features_2.h5')
b = pd.read_hdf('../features/base_featurs.h5')

# %%
set(df.columns.tolist()) - set(b.columns.tolist())
# Out:
# {'APARTMENTS_AVG',
#  'APARTMENTS_MODE',
#  'ELEVATORS_AVG',
#  'ELEVATORS_MEDI',
#  'ELEVATORS_MODE',
#  'LIVINGAPARTMENTS_AVG',
#  'LIVINGAPARTMENTS_MEDI',
#  'LIVINGAPARTMENTS_MODE',
#  'LIVINGAREA_AVG',
#  'LIVINGAREA_MODE',
#  'TOTALAREA_MODE'}

# %%
b.shape
# Out:
# (356251, 281)
