# %%
import pandas as pd
import missingno as msno # visualzing missing value
import numpy as np

# %%
filled_feature_w_target = pd.read_hdf('../features/filled_by_knn/base_featurs_filled_knn_10_w_target.h5')
filled_feature_wo_target = pd.read_hdf('../features/filled_by_knn/base_featurs_filled_knn_10_wo_target.h5')

# %%
'TARGET' in filled_feature_w_target.columns.tolist()
# Out:
# True

# %%
filled_feature_w_target.TARGET.describe()
# Out:
# count    356251.000000
# mean          0.082762
# std           0.257525
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: TARGET, dtype: float64

# %%
filled_feature_w_target.columns.tolist()
# Out:
# ['AMT_ANNUITY',
#  'AMT_CREDIT',
#  'AMT_GOODS_PRICE',
#  'AMT_REQ_CREDIT_BUREAU_QRT',
#  'APARTMENTS_MEDI',
#  'CODE_GENDER',
#  'DAYS_BIRTH',
#  'DAYS_EMPLOYED',
#  'DAYS_ID_PUBLISH',
#  'DAYS_LAST_PHONE_CHANGE',
#  'DEF_30_CNT_SOCIAL_CIRCLE',
#  'DEF_60_CNT_SOCIAL_CIRCLE',
#  'ENTRANCES_MEDI',
#  'EXT_SOURCE_1',
#  'EXT_SOURCE_2',
#  'EXT_SOURCE_3',
#  'FLAG_DOCUMENT_11',
#  'FLAG_DOCUMENT_18',
#  'FLAG_DOCUMENT_3',
#  'FLAG_DOCUMENT_8',
#  'FLAG_OWN_CAR',
#  'FLAG_PHONE',
#  'FLAG_WORK_PHONE',
#  'LIVE_CITY_NOT_WORK_CITY',
#  'LIVINGAREA_MEDI',
#  'OBS_60_CNT_SOCIAL_CIRCLE',
#  'OWN_CAR_AGE',
#  'REGION_POPULATION_RELATIVE',
#  'REGION_RATING_CLIENT',
#  'REGION_RATING_CLIENT_W_CITY',
#  'REG_CITY_NOT_LIVE_CITY',
#  'TARGET',
#  'YEARS_BEGINEXPLUATATION_MEDI',
#  'NEW_CREDIT_TO_ANNUITY_RATIO',
#  'DIFF_CREDIT_AND_GOODS_RATIO',
#  'NEW_DOC_IND_MED',
#  'NEW_DOC_IND_STD',
#  'NEW_DOC_IND_KURT',
#  'NEW_EMPLOY_TO_BIRTH_RATIO',
#  'NEW_ANNUITY_TO_INCOME_RATIO',
# ...
