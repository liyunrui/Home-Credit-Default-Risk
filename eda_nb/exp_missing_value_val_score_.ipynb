# %%
'''

One imputation method, 10 iterations may take 1 hrs.

test_id 如果是隨機的, 會有引響麼, 理論上只要sort就好, 就算有?
'''
import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold, StratifiedKFold
import multiprocessing
import warnings
import sys
sys.path.append('../py_model')
from utils import init_logging
import logging 
import os
warnings.simplefilter(action='ignore', category=FutureWarning)
np.random.seed(int(time.time()))

NUM_FOLDS = 5
STRATIFIED = True  
TEST_NULL_HYPO = False
ITERATION = (80 if TEST_NULL_HYPO else 10) # It means how many iterations need to get the final stable AUC score.

# %%
@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))

# LightGBM GBDT with KFold or Stratified KFold
# Parameters from Tilii kernel: https://www.kaggle.com/tilii7/olivier-lightgbm-parameters-by-bayesian-opt/code
def kfold_lightgbm(df, num_folds, stratified = False):
    '''
    num_folds: int, how many foles u'r going to split.

    Maybe we can write a helper function, to find a best parametres each time when u add a new features, to make sure reliability of experiment.
    But, the experiement time will go up more.
    '''
    #---------------------
    # Divide in training/validation and test data
    #---------------------
    train_df = df[df['TARGET'].notnull()]
    test_df = df[df['TARGET'].isnull()]
    # 
    logging.info('no bugging in split' if train_df.shape[0] + test_df.shape[0] == df.shape[0] else " opps")
    #---------------------
    # core
    #---------------------
    logging.info("Starting LightGBM. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))
    del df
    gc.collect()
    # Cross validation model
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=int(time.time()))
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=int(time.time()))
    # Create arrays and dataframes to store results
    # train
    oof_preds = np.zeros(train_df.shape[0])
    train_preds = np.zeros(train_df.shape[0])
    # test
    sub_preds = np.zeros(test_df.shape[0])
    # feature importance
    feature_importance_df = pd.DataFrame()

    feats = [f for f in train_df.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]
    
    if TEST_NULL_HYPO:
        train_df['TARGET'] = train_df['TARGET'].copy().sample(frac = 1.0).values
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['TARGET'])):
        train_x, train_y = train_df[feats].iloc[train_idx], train_df['TARGET'].iloc[train_idx]
        valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['TARGET'].iloc[valid_idx]

        # LightGBM parameters found by Bayesian optimization
        if TEST_NULL_HYPO:
            clf = LGBMClassifier(
                nthread=int(multiprocessing.cpu_count()*CPU_USE_RATE),
                n_estimators=10000,
                learning_rate=0.02,
                num_leaves=127,
                max_depth=8,
                silent=-1,
                verbose=-1,
                random_state=int(time.time()),
                )
        else:
            clf = LGBMClassifier(
                nthread=int(multiprocessing.cpu_count()*CPU_USE_RATE),
                n_estimators=10000,
                learning_rate=0.02,
                num_leaves=34, # 20
                colsample_bytree=0.2, #0.9497036 < 0.2
                subsample=0.8715623,
                max_depth=8, # 7
                reg_alpha=0.041545473, # 0.3
                reg_lambda=0.0735294,
                min_split_gain=0.0222415,
                min_child_weight=39.3259775, # 60
                silent=-1,
                verbose=-1,
                random_state=int(time.time()),
                )

        clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], 
            eval_metric= 'auc', verbose= False, early_stopping_rounds= 100) # early_stopping_rounds= 200
        # training/validating
        oof_preds[valid_idx] = clf.predict_proba(valid_x, num_iteration=clf.best_iteration_)[:, 1]
        train_preds[train_idx] += clf.predict_proba(train_x, num_iteration=clf.best_iteration_)[:, 1] / folds.n_splits
        # testing
        sub_preds += clf.predict_proba(test_df[feats], num_iteration=clf.best_iteration_)[:, 1] / folds.n_splits

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = clf.feature_importances_
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

        logging.info('Fold %2d val AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))

        del clf, train_x, train_y, valid_x, valid_y
        gc.collect()
    logging.info('Over-folds train AUC score : {}'.format(roc_auc_score(train_df['TARGET'], train_preds)))
    
    over_folds_val_auc = roc_auc_score(train_df['TARGET'], oof_preds)
    logging.info('Over-folds val AUC score : {}'.format(over_folds_val_auc))
    
    # # Write submission file and plot feature importance
    # test_df.loc[:,'TARGET'] = sub_preds
    # test_df[['SK_ID_CURR', 'TARGET']].to_csv(submission_file_name, index= False)

    return feature_importance_df, over_folds_val_auc

# %%
def main():
    #--------------------
    # load features
    #--------------------
    import re
    compiled_k = re.compile(r'knn_\d*')
    #[int(compiled_k.findall(i)[0][4:]) for i in result.inputation_method if compiled_k.search(i) ]
    for p in os.listdir('../features/filled_by_knn/'):
        if int(compiled_k.findall(p)[0][4:]) > 20:
            df = pd.read_hdf('../features/filled_by_knn/{}'.format(p))
            logging.info('loading features: {}'.format(p))
            #--------------------
            # out-of-fold validating stratigy + LGB
            #--------------------    
            with timer("Run LightGBM with kfold"):
                feature_importance_df = pd.DataFrame()
                over_folds_val_auc_list = np.zeros(ITERATION)
                for i in range(ITERATION):
                    logging.info('Iteration %i' %i)
                    iter_feat_imp, over_folds_val_auc = kfold_lightgbm(df, num_folds= NUM_FOLDS, stratified= STRATIFIED)
                    feature_importance_df = pd.concat([feature_importance_df, iter_feat_imp], axis=0)
                    over_folds_val_auc_list[i] = over_folds_val_auc

                logging.info('Over-iterations val AUC score : {}'.format(over_folds_val_auc_list.mean()))
                logging.info('Standard deviation : {}'.format(over_folds_val_auc_list.std()))

                # display_importances(feature_importance_df)
                feature_importance_df_median = feature_importance_df[["feature", "importance"]].groupby("feature").median().sort_values(by="importance", ascending=False)
                useless_features_df = feature_importance_df_median.loc[feature_importance_df_median['importance'] == 0]
                feature_importance_df_mean = feature_importance_df[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)
                #---------------------
                # save
                #---------------------
                output_path = '../output'
                if not os.path.isdir(output_path):
                    os.mkdir(output_path)

                if TEST_NULL_HYPO:
                    feature_importance_df_mean.to_csv(os.path.join(output_path, 'feature_importance-null_hypo.csv'), index = True)
                else:
                    feature_importance_df_mean.to_csv(os.path.join(output_path, 'feature_importance.csv'), index = True)
                    useless_features_list = useless_features_df.index.tolist()
                    logging.info('useless/overfitting features: \'' + '\', \''.join(useless_features_list) + '\'')

# %%
already_trained = ['base_featurs_filled_knn_65_wo_target',
                'base_featurs_filled_knn_95_w_target',
                'base_featurs_filled_knn_30_wo_target',
                'base_featurs_filled_knn_45_w_target',
                'base_featurs_filled_knn_75_wo_target',
                'base_featurs_filled_knn_40_w_target']

# %%
import re
compiled_k = re.compile(r'knn_\d*')
#[int(compiled_k.findall(i)[0][4:]) for i in result.inputation_method if compiled_k.search(i) ]
for p in os.listdir('../features/filled_by_knn/'):
    if int(compiled_k.findall(p)[0][4:]) > 20:
        if (p[:-3] not in already_trained):
            print (p[:-3])
# Out:
# base_featurs_filled_knn_35_wo_target
# base_featurs_filled_knn_90_wo_target
# base_featurs_filled_knn_80_w_target
# base_featurs_filled_knn_40_wo_target
# base_featurs_filled_knn_65_w_target
# base_featurs_filled_knn_50_w_target
# base_featurs_filled_knn_70_wo_target
# base_featurs_filled_knn_25_wo_target
# base_featurs_filled_knn_90_w_target
# base_featurs_filled_knn_85_wo_target
# base_featurs_filled_knn_55_wo_target
# base_featurs_filled_knn_35_w_target
# base_featurs_filled_knn_85_w_target
# base_featurs_filled_knn_80_wo_target
# base_featurs_filled_knn_95_wo_target
# base_featurs_filled_knn_30_w_target
# base_featurs_filled_knn_45_wo_target
# base_featurs_filled_knn_60_w_target
# base_featurs_filled_knn_50_wo_target
# base_featurs_filled_knn_55_w_target
# base_featurs_filled_knn_60_wo_target
# base_featurs_filled_knn_75_w_target
# base_featurs_filled_knn_70_w_target
# base_featurs_filled_knn_25_w_target

# %%
CPU_USE_RATE = 0.8
log_dir = '../log_imputating_exp'
init_logging(log_dir)
with timer("Lightgbm run a score"):
    main()
# Out:
# loading features: base_featurs_filled_knn_65_wo_target.h5
# Iteration 0
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.795578
# Fold  2 val AUC : 0.793440
# Fold  3 val AUC : 0.791083
# Fold  4 val AUC : 0.793510
# Fold  5 val AUC : 0.794859
# Over-folds train AUC score : 0.8882419196707059
# Over-folds val AUC score : 0.7936738837479553
# Iteration 1
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.790206
# Fold  2 val AUC : 0.795358
# Fold  3 val AUC : 0.791259
# Fold  4 val AUC : 0.796197
# Fold  5 val AUC : 0.798026
# Over-folds train AUC score : 0.8882638420407751
# Over-folds val AUC score : 0.7941974738829686
# Iteration 2
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.791424
# Fold  2 val AUC : 0.791561
# Fold  3 val AUC : 0.794598
# Fold  4 val AUC : 0.792357
# Fold  5 val AUC : 0.798179
# Over-folds train AUC score : 0.8766414563400848
# Over-folds val AUC score : 0.7935901943642073
# Iteration 3
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.792961
# Fold  2 val AUC : 0.792444
# Fold  3 val AUC : 0.790712
# Fold  4 val AUC : 0.798766
# Fold  5 val AUC : 0.794258
# Over-folds train AUC score : 0.8851063313394196
# Over-folds val AUC score : 0.7938184552250211
# Iteration 4
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.789962
# Fold  2 val AUC : 0.796177
# Fold  3 val AUC : 0.795681
# Fold  4 val AUC : 0.796173
# Fold  5 val AUC : 0.792095
# Over-folds train AUC score : 0.8863135935601967
# Over-folds val AUC score : 0.7940145807943084
# Iteration 5
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.798098
# Fold  2 val AUC : 0.791524
# Fold  3 val AUC : 0.787365
# Fold  4 val AUC : 0.797313
# Fold  5 val AUC : 0.797222
# Over-folds train AUC score : 0.8863972454666411
# Over-folds val AUC score : 0.7942577282670773
# Iteration 6
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.794306
# Fold  2 val AUC : 0.790500
# Fold  3 val AUC : 0.797286
# Fold  4 val AUC : 0.793069
# Fold  5 val AUC : 0.795038
# Over-folds train AUC score : 0.892076797578379
# Over-folds val AUC score : 0.7940335011326162
# Iteration 7
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.799936
# Fold  2 val AUC : 0.791044
# Fold  3 val AUC : 0.793076
# Fold  4 val AUC : 0.791343
# Fold  5 val AUC : 0.792610
# Over-folds train AUC score : 0.884560328636907
# Over-folds val AUC score : 0.7935717699232996
# Iteration 8
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.791495
# Fold  2 val AUC : 0.792626
# Fold  3 val AUC : 0.795024
# Fold  4 val AUC : 0.794217
# Fold  5 val AUC : 0.797885
# Over-folds train AUC score : 0.8865710439679806
# Over-folds val AUC score : 0.7942343263272649
# Iteration 9
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.796760
# Fold  2 val AUC : 0.797713
# Fold  3 val AUC : 0.791703
# Fold  4 val AUC : 0.794200
# Fold  5 val AUC : 0.792096
# Over-folds train AUC score : 0.8935129713115588
# Over-folds val AUC score : 0.7944710165888866
# Over-iterations val AUC score : 0.7939862930253605
# Standard deviation : 0.0002953427391287697
# useless/overfitting features: 'ORGANIZATION_TYPE_Restaurant', 'OCCUPATION_TYPE_Accountants', 'OCCUPATION_TYPE_Core staff', 'OCCUPATION_TYPE_High skill tech staff', 'OCCUPATION_TYPE_Low-skill Laborers', 'OCCUPATION_TYPE_Medicine staff', 'OCCUPATION_TYPE_Sales staff'
# Run LightGBM with kfold - done in 7897s
# loading features: base_featurs_filled_knn_95_w_target.h5
# Iteration 0
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.796519
# Fold  2 val AUC : 0.793272
# Fold  3 val AUC : 0.793979
# Fold  4 val AUC : 0.795288
# Fold  5 val AUC : 0.789979
# Over-folds train AUC score : 0.8912352988775412
# Over-folds val AUC score : 0.7938032467072538
# Iteration 1
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.794676
# Fold  2 val AUC : 0.791726
# Fold  3 val AUC : 0.791217
# Fold  4 val AUC : 0.798257
# Fold  5 val AUC : 0.793735
# Over-folds train AUC score : 0.8853842747072669
# Over-folds val AUC score : 0.7938591403292243
# Iteration 2
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.791988
# Fold  2 val AUC : 0.791791
# Fold  3 val AUC : 0.796336
# Fold  4 val AUC : 0.794331
# Fold  5 val AUC : 0.795788
# Over-folds train AUC score : 0.8930021861594137
# Over-folds val AUC score : 0.7939914091332887
# Iteration 3
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.788280
# Fold  2 val AUC : 0.796273
# Fold  3 val AUC : 0.798330
# Fold  4 val AUC : 0.798001
# Fold  5 val AUC : 0.788525
# Over-folds train AUC score : 0.8892601468000229
# Over-folds val AUC score : 0.793877444215764
# Iteration 4
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.792843
# Fold  2 val AUC : 0.799455
# Fold  3 val AUC : 0.790203
# Fold  4 val AUC : 0.792354
# Fold  5 val AUC : 0.793952
# Over-folds train AUC score : 0.8900826522029355
# Over-folds val AUC score : 0.7937493043275534
# Iteration 5
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.798181
# Fold  2 val AUC : 0.797618
# Fold  3 val AUC : 0.788628
# Fold  4 val AUC : 0.796384
# Fold  5 val AUC : 0.789021
# Over-folds train AUC score : 0.8916052074157494
# Over-folds val AUC score : 0.7939361797003359
# Iteration 6
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.794928
# Fold  2 val AUC : 0.799886
# Fold  3 val AUC : 0.791165
# Fold  4 val AUC : 0.790648
# Fold  5 val AUC : 0.793400
# Over-folds train AUC score : 0.8847628671000739
# Over-folds val AUC score : 0.793990959120648
# Iteration 7
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.788095
# Fold  2 val AUC : 0.792408
# Fold  3 val AUC : 0.796792
# Fold  4 val AUC : 0.798504
# Fold  5 val AUC : 0.794112
# Over-folds train AUC score : 0.8877934383269255
# Over-folds val AUC score : 0.7939325542343428
# Iteration 8
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.793349
# Fold  2 val AUC : 0.793388
# Fold  3 val AUC : 0.796891
# Fold  4 val AUC : 0.790191
# Fold  5 val AUC : 0.796999
# Over-folds train AUC score : 0.8821425167375883
# Over-folds val AUC score : 0.7941084913644705
# Iteration 9
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.793785
# Fold  2 val AUC : 0.790413
# Fold  3 val AUC : 0.798024
# Fold  4 val AUC : 0.791970
# Fold  5 val AUC : 0.795362
# Over-folds train AUC score : 0.8858146724683527
# Over-folds val AUC score : 0.7939141742532023
# Over-iterations val AUC score : 0.7939162903386083
# Standard deviation : 9.70888298468484e-05
# useless/overfitting features: 'OCCUPATION_TYPE_Sales staff', 'OCCUPATION_TYPE_Medicine staff', 'OCCUPATION_TYPE_Accountants', 'OCCUPATION_TYPE_Low-skill Laborers', 'OCCUPATION_TYPE_Core staff', 'ORGANIZATION_TYPE_Restaurant'
# Run LightGBM with kfold - done in 8166s
# loading features: base_featurs_filled_knn_30_wo_target.h5
# Iteration 0
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.796100
# Fold  2 val AUC : 0.798183
# Fold  3 val AUC : 0.789831
# Fold  4 val AUC : 0.787950
# Fold  5 val AUC : 0.794036
# Over-folds train AUC score : 0.8863588853802484
# Over-folds val AUC score : 0.7932133426923993
# Iteration 1
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.795292
# Fold  2 val AUC : 0.796955
# Fold  3 val AUC : 0.788999
# Fold  4 val AUC : 0.792898
# Fold  5 val AUC : 0.791656
# Over-folds train AUC score : 0.8882306999920264
# Over-folds val AUC score : 0.7931474573078117
# Iteration 2
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.788583
# Fold  2 val AUC : 0.794593
# Fold  3 val AUC : 0.796301
# Fold  4 val AUC : 0.791809
# Fold  5 val AUC : 0.792180
# Over-folds train AUC score : 0.8784139754774318
# Over-folds val AUC score : 0.7926691896301897
# Iteration 3
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.793065
# Fold  2 val AUC : 0.795163
# Fold  3 val AUC : 0.793697
# Fold  4 val AUC : 0.791875
# Fold  5 val AUC : 0.794554
# Over-folds train AUC score : 0.8851489170986585
# Over-folds val AUC score : 0.7936522334089599
# Iteration 4
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.793999
# Fold  2 val AUC : 0.800485
# Fold  3 val AUC : 0.790974
# Fold  4 val AUC : 0.785299
# Fold  5 val AUC : 0.793892
# Over-folds train AUC score : 0.8865400818728033
# Over-folds val AUC score : 0.7929057197226511
# Iteration 5
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.791619
# Fold  2 val AUC : 0.797945
# Fold  3 val AUC : 0.800373
# Fold  4 val AUC : 0.789839
# Fold  5 val AUC : 0.790861
# Over-folds train AUC score : 0.8949088193236512
# Over-folds val AUC score : 0.7941168570681122
# Iteration 6
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.791642
# Fold  2 val AUC : 0.798298
# Fold  3 val AUC : 0.794710
# Fold  4 val AUC : 0.789823
# Fold  5 val AUC : 0.794175
# Over-folds train AUC score : 0.8877766017551934
# Over-folds val AUC score : 0.7937406700128199
# Iteration 7
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.791187
# Fold  2 val AUC : 0.793600
# Fold  3 val AUC : 0.791300
# Fold  4 val AUC : 0.795302
# Fold  5 val AUC : 0.794288
# Over-folds train AUC score : 0.888016052084845
# Over-folds val AUC score : 0.7931359058908714
# Iteration 8
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.792650
# Fold  2 val AUC : 0.796227
# Fold  3 val AUC : 0.798353
# Fold  4 val AUC : 0.793187
# Fold  5 val AUC : 0.785074
# Over-folds train AUC score : 0.8765830743961597
# Over-folds val AUC score : 0.7931032030248202
# Iteration 9
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.794024
# Fold  2 val AUC : 0.796562
# Fold  3 val AUC : 0.792100
# Fold  4 val AUC : 0.793561
# Fold  5 val AUC : 0.788004
# Over-folds train AUC score : 0.8776809902426985
# Over-folds val AUC score : 0.7928464739482546
# Over-iterations val AUC score : 0.7932531052706889
# Standard deviation : 0.00042649993848874895
# useless/overfitting features: 'ORGANIZATION_TYPE_Restaurant', 'OCCUPATION_TYPE_Accountants', 'OCCUPATION_TYPE_Core staff', 'OCCUPATION_TYPE_Low-skill Laborers', 'OCCUPATION_TYPE_Medicine staff', 'OCCUPATION_TYPE_Sales staff', 'OCCUPATION_TYPE_High skill tech staff'
# Run LightGBM with kfold - done in 8314s
# loading features: base_featurs_filled_knn_45_w_target.h5
# Iteration 0
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.791434
# Fold  2 val AUC : 0.791309
# Fold  3 val AUC : 0.795739
# Fold  4 val AUC : 0.793949
# Fold  5 val AUC : 0.794295
# Over-folds train AUC score : 0.8879075957609408
# Over-folds val AUC score : 0.7933277563400715
# Iteration 1
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.793838
# Fold  2 val AUC : 0.798371
# Fold  3 val AUC : 0.791686
# Fold  4 val AUC : 0.791256
# Fold  5 val AUC : 0.794083
# Over-folds train AUC score : 0.8946931972915766
# Over-folds val AUC score : 0.7938262361117289
# Iteration 2
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.791930
# Fold  2 val AUC : 0.798911
# Fold  3 val AUC : 0.792862
# Fold  4 val AUC : 0.791037
# Fold  5 val AUC : 0.792012
# Over-folds train AUC score : 0.8855060363289162
# Over-folds val AUC score : 0.7932953587074201
# Iteration 3
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.789448
# Fold  2 val AUC : 0.794538
# Fold  3 val AUC : 0.791165
# Fold  4 val AUC : 0.797514
# Fold  5 val AUC : 0.795503
# Over-folds train AUC score : 0.8907821114959327
# Over-folds val AUC score : 0.7936154978140508
# Iteration 4
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.794223
# Fold  2 val AUC : 0.789922
# Fold  3 val AUC : 0.794240
# Fold  4 val AUC : 0.797252
# Fold  5 val AUC : 0.790442
# Over-folds train AUC score : 0.8890658922459267
# Over-folds val AUC score : 0.793219860465729
# Iteration 5
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.797813
# Fold  2 val AUC : 0.792519
# Fold  3 val AUC : 0.790425
# Fold  4 val AUC : 0.793736
# Fold  5 val AUC : 0.794824
# Over-folds train AUC score : 0.8846719683941218
# Over-folds val AUC score : 0.7938599092551932
# Iteration 6
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.792837
# Fold  2 val AUC : 0.797368
# Fold  3 val AUC : 0.792381
# Fold  4 val AUC : 0.792257
# Fold  5 val AUC : 0.791392
# Over-folds train AUC score : 0.8869929368036547
# Over-folds val AUC score : 0.7932439515319286
# Iteration 7
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.791711
# Fold  2 val AUC : 0.795998
# Fold  3 val AUC : 0.789818
# Fold  4 val AUC : 0.793501
# Fold  5 val AUC : 0.796940
# Over-folds train AUC score : 0.8861101573517364
# Over-folds val AUC score : 0.7935782889791227
# Iteration 8
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.794142
# Fold  2 val AUC : 0.794000
# Fold  3 val AUC : 0.801462
# Fold  4 val AUC : 0.793535
# Fold  5 val AUC : 0.786908
# Over-folds train AUC score : 0.8866987814383009
# Over-folds val AUC score : 0.7939778507568702
# Iteration 9
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.796634
# Fold  2 val AUC : 0.795238
# Fold  3 val AUC : 0.794631
# Fold  4 val AUC : 0.793249
# Fold  5 val AUC : 0.788015
# Over-folds train AUC score : 0.8858718088263082
# Over-folds val AUC score : 0.7935291607941835
# Over-iterations val AUC score : 0.7935473870756299
# Standard deviation : 0.0002603372512609952
# useless/overfitting features: 'OCCUPATION_TYPE_Accountants', 'OCCUPATION_TYPE_Core staff', 'OCCUPATION_TYPE_High skill tech staff', 'OCCUPATION_TYPE_Low-skill Laborers', 'OCCUPATION_TYPE_Medicine staff', 'ORGANIZATION_TYPE_Restaurant', 'OCCUPATION_TYPE_Sales staff'
# Run LightGBM with kfold - done in 3316s
# loading features: base_featurs_filled_knn_75_wo_target.h5
# Iteration 0
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.795101
# Fold  2 val AUC : 0.790877
# Fold  3 val AUC : 0.797865
# Fold  4 val AUC : 0.791207
# Fold  5 val AUC : 0.794849
# Over-folds train AUC score : 0.8902715165802904
# Over-folds val AUC score : 0.7939472436273319
# Iteration 1
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.790608
# Fold  2 val AUC : 0.798392
# Fold  3 val AUC : 0.794463
# Fold  4 val AUC : 0.791736
# Fold  5 val AUC : 0.794684
# Over-folds train AUC score : 0.8851009914649146
# Over-folds val AUC score : 0.7939376742325006
# Iteration 2
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.792229
# Fold  2 val AUC : 0.796503
# Fold  3 val AUC : 0.793552
# Fold  4 val AUC : 0.794438
# Fold  5 val AUC : 0.794433
# Over-folds train AUC score : 0.8904763048216624
# Over-folds val AUC score : 0.794203229855292
# Iteration 3
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.798557
# Fold  2 val AUC : 0.793304
# Fold  3 val AUC : 0.791723
# Fold  4 val AUC : 0.793799
# Fold  5 val AUC : 0.791944
# Over-folds train AUC score : 0.8884926928484961
# Over-folds val AUC score : 0.7938307845453831
# Iteration 4
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.797806
# Fold  2 val AUC : 0.786111
# Fold  3 val AUC : 0.790439
# Fold  4 val AUC : 0.800182
# Fold  5 val AUC : 0.794853
# Over-folds train AUC score : 0.8904181608514895
# Over-folds val AUC score : 0.7938728816746838
# Iteration 5
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.793839
# Fold  2 val AUC : 0.800479
# Fold  3 val AUC : 0.792147
# Fold  4 val AUC : 0.790530
# Fold  5 val AUC : 0.796180
# Over-folds train AUC score : 0.8887867293694729
# Over-folds val AUC score : 0.7946145156165751
# Iteration 6
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.793749
# Fold  2 val AUC : 0.801315
# Fold  3 val AUC : 0.792810
# Fold  4 val AUC : 0.789906
# Fold  5 val AUC : 0.791969
# Over-folds train AUC score : 0.888264345633135
# Over-folds val AUC score : 0.7939372683946283
# Iteration 7
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.790434
# Fold  2 val AUC : 0.788067
# Fold  3 val AUC : 0.799655
# Fold  4 val AUC : 0.795043
# Fold  5 val AUC : 0.795285
# Over-folds train AUC score : 0.8846011033731405
# Over-folds val AUC score : 0.7936419034956157
# Iteration 8
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.789830
# Fold  2 val AUC : 0.794968
# Fold  3 val AUC : 0.795618
# Fold  4 val AUC : 0.793476
# Fold  5 val AUC : 0.794499
# Over-folds train AUC score : 0.8842668447280332
# Over-folds val AUC score : 0.7936704921232363
# Iteration 9
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.792769
# Fold  2 val AUC : 0.797549
# Fold  3 val AUC : 0.797606
# Fold  4 val AUC : 0.790743
# Fold  5 val AUC : 0.789083
# Over-folds train AUC score : 0.8816516387310775
# Over-folds val AUC score : 0.7935309024200528
# Over-iterations val AUC score : 0.79391868959853
# Standard deviation : 0.00029412157676969315
# useless/overfitting features: 'OCCUPATION_TYPE_Low-skill Laborers', 'ORGANIZATION_TYPE_Restaurant', 'OCCUPATION_TYPE_Medicine staff', 'OCCUPATION_TYPE_High skill tech staff', 'OCCUPATION_TYPE_Accountants', 'OCCUPATION_TYPE_Core staff', 'OCCUPATION_TYPE_Sales staff'
# Run LightGBM with kfold - done in 3291s
# loading features: base_featurs_filled_knn_40_w_target.h5
# Iteration 0
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.794576
# Fold  2 val AUC : 0.796330
# Fold  3 val AUC : 0.793971
# Fold  4 val AUC : 0.788968
# Fold  5 val AUC : 0.793659
# Over-folds train AUC score : 0.8812123903413922
# Over-folds val AUC score : 0.7934930707208901
# Iteration 1
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.790830
# Fold  2 val AUC : 0.791425
# Fold  3 val AUC : 0.794240
# Fold  4 val AUC : 0.795480
# Fold  5 val AUC : 0.795349
# Over-folds train AUC score : 0.8892724808228603
# Over-folds val AUC score : 0.793432182357605
# Iteration 2
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.796684
# Fold  2 val AUC : 0.794937
# Fold  3 val AUC : 0.791620
# Fold  4 val AUC : 0.794617
# Fold  5 val AUC : 0.790079
# Over-folds train AUC score : 0.8844556523906854
# Over-folds val AUC score : 0.7935710159597524
# Iteration 3
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.792501
# Fold  2 val AUC : 0.792919
# Fold  3 val AUC : 0.796781
# Fold  4 val AUC : 0.791567
# Fold  5 val AUC : 0.795297
# Over-folds train AUC score : 0.8876480940764107
# Over-folds val AUC score : 0.7937742505317699
# Iteration 4
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.800196
# Fold  2 val AUC : 0.787871
# Fold  3 val AUC : 0.791320
# Fold  4 val AUC : 0.797713
# Fold  5 val AUC : 0.794662
# Over-folds train AUC score : 0.8898428581650858
# Over-folds val AUC score : 0.7942991807297576
# Iteration 5
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.798024
# Fold  2 val AUC : 0.788939
# Fold  3 val AUC : 0.787421
# Fold  4 val AUC : 0.797842
# Fold  5 val AUC : 0.795069
# Over-folds train AUC score : 0.8864017799353684
# Over-folds val AUC score : 0.7934058544806322
# Iteration 6
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.792270
# Fold  2 val AUC : 0.788064
# Fold  3 val AUC : 0.797189
# Fold  4 val AUC : 0.798557
# Fold  5 val AUC : 0.791444
# Over-folds train AUC score : 0.8888282547917706
# Over-folds val AUC score : 0.7934668162310325
# Iteration 7
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)

# %%
# 不要把時間花在沒有技術含量的東西, 這邊做完實驗就知道結果了。
