# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import math
import sys
sys.path.append('../py_model')
from utils import init_logging
import logging
# Out:
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %% [markdown]
# # auto-encoder network architecture

# %%
def autoencoder(dimensions=[278, 1000, 100, 278]):
    """
    Build a stacked deep autoencoder with tied weights, that is w = wT.

    return a dict.
    
    Parameters
    ----------
    dimensions : list, optional
        The number of neurons for each layer of the autoencoder.
    Returns
    -------
    x : Tensor
        Input placeholder to the network
    z : Tensor
        Inner-most latent representation
    y : Tensor
        Output reconstruction of the input
    loss : Tensor
        Overall cost to use for training
    """    
    logging.info('activation : {}'.format('relu'))
    # input to the network
    x = tf.placeholder(tf.float32, [None, dimensions[0]], name='x')
    current_input = x
    logging.info('current_input : {}'.format(current_input.shape))
    #---------------------------
    # Build the encoder
    #---------------------------
    encoder = [] # for putting the weight of encoder, w1,w2,..
    for layer_i, n_output in enumerate(dimensions[1:]):
        logging.info('layer_i-encoder : {}'.format(layer_i))
        logging.info('n_output-encoder: {}'.format(n_output))
        n_input = int(current_input.get_shape()[1]) # [0]: batch_szie, [1]:input_dim
        logging.info('n_input : {}'.format(n_input))
        W = tf.Variable(
            tf.random_uniform([n_input, n_output],
                              minval = -1.0 / math.sqrt(n_input),
                              maxval = 1.0 / math.sqrt(n_input)))
        b = tf.Variable(tf.zeros([n_output]))
        # saving layer of encoding for decoder
        encoder.append(W)
        output = tf.nn.relu(tf.matmul(current_input, W) + b)
        # assign current_input
        current_input = output
    #---------------------------
    # latent representation (output of encoder)
    #---------------------------
    z = current_input
    encoder.reverse() # [...,w2,w1]
    
    #---------------------------
    # Build the decoder using the same weights
    #---------------------------
    for layer_i, n_output in enumerate(dimensions[:-1][::-1]):
        logging.info('layer_i-decoder : {}'.format(layer_i))
        logging.info('n_output-decoder : {}'.format(n_output))
        W = tf.transpose(encoder[layer_i])
        b = tf.Variable(tf.zeros([n_output]))
        output = tf.nn.relu(tf.matmul(current_input, W) + b)
        # assign current_input
        current_input = output

    # now have the reconstruction through the network
    y = current_input
    # Define loss and, minimize the mean squared error
    loss = tf.reduce_mean(tf.pow(x - y, 2)) 
    return {'x': x, 'z': z, 'y': y, 'loss': loss}

# %% [markdown]
# # input

# %%
log_dir = '../log/auto_encoder'
checkpoint_dir = '../log/auto_encoder/checkpoints'

init_logging(log_dir)

# %%
pad_zero = True
# reload again for filling
df = pd.read_hdf('../features/base_featurs.h5','base_featurs')
print (df.shape)
copy_for_the_following_merge = df[['SK_ID_CURR','TARGET']].copy()
no_need_to_comoress = ['index','TARGET', 'SK_ID_CURR']
df.drop(no_need_to_comoress, axis = 1, inplace = True)
# handling with infinity
df.replace([np.inf, -np.inf], np.nan, inplace = True)
print (df.shape)
if pad_zero == True:
    # preprocessing for feature scailing
    df.replace(np.nan, 0, inplace = True)
    logging.info('pad_zero : {}'.format('True'))
else:
    logging.info('pad_zero : {}'.format('False'))
# preprocessing for feature scailing ignoring nan
for f in df.columns.tolist():
    mean = df[f].mean()
    std = df[f].std()
    df[f] = (df[f] - mean) / std
logging.info('input of ae : {}'.format(df.shape))
# Out:
# (356251, 281)
# (356251, 278)
# pad_zero : True
# input of ae : (356251, 278)

# %% [markdown]
# # raw_feature_generator
# ### raw_feature_generator which allows to quickly set up Python generators that can automatically turn image files on disk into batches of pre-processed tensors. This is what we will use here.

# %%
length = len(df)
print ('length',length)
idx = np.arange(length) # 1-D array
print ('idx', idx.shape, idx)
# Out:
# length 356251
# idx (356251,) [     0      1      2 ... 356248 356249 356250]

# %%
# def raw_feature_generator(batch_size = 128, shuffle = True, num_epochs = 10000, allow_smaller_final_batch = False):
#     epoch_num = 0
#     while epoch_num < num_epochs:
#         if shuffle:
#             np.random.shuffle(idx)
#         for i in range(0, length, batch_size):
#             batch_idx = idx[i: i + batch_size]
#             if not allow_smaller_final_batch and len(batch_idx) != batch_size:
#                 break # terminate the loop
#             yield df.values[batch_idx]
#         epoch_num += 1

# %%
def raw_feature_generator(batch_size = 128, shuffle = True, allow_smaller_final_batch = False):
    if shuffle:
        np.random.shuffle(idx)
    for i in range(0, length, batch_size):
        batch_idx = idx[i: i + batch_size]
        if not allow_smaller_final_batch and len(batch_idx) != batch_size:
            break # terminate the loop
        yield df.values[batch_idx]
def save(step, averaged = False):
    '''
    
    '''
    #--------
    # create saver object
    #--------
    if averaged:
        saver = tf.train.Saver(self.ema.variables_to_restore(), max_to_keep=1)
        checkpoint_dir_averaged = checkpoint_dir + '_avg'
        checkpoint_dir =  checkpoint_dir_averaged
    else:
        saver = tf.train.Saver(max_to_keep=1)
        checkpoint_dir = checkpoint_dir
    
    if not os.path.isdir(checkpoint_dir):
        logging.info('creating checkpoint directory {}'.format(checkpoint_dir))
        os.mkdir(checkpoint_dir)

    model_path = os.path.join(checkpoint_dir, 'model')
    logging.info('saving model to {}'.format(model_path))
    saver.save(sess, model_path, global_step=step)

# %% [markdown]
# # training

# %%
# display_step
log_interval = 100
# learning_rate
learning_rate = 0.001
# define auto-encoder network architecture
ae = autoencoder(dimensions=[278, 140, 70, 30])
# optimizer
optimizer = tf.train.RMSPropOptimizer(learning_rate).minimize(ae['loss'])

# Initialize the variables (i.e. assign their default value)
# We create a session to use the graph
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# Training
batch_size = 256
n_epochs = 10
step = 0
min_steps_to_checkpoint = 100
enable_parameter_averaging = False
logging.info('learning_rate : {}'.format(learning_rate))
logging.info('batch_size : {}'.format(batch_size))
logging.info('n_epochs : {}'.format(n_epochs))
logging.info('log_interval : {}'.format(log_interval))
logging.info('min_steps_to_checkpoint : {}'.format(min_steps_to_checkpoint))
logging.info('enable_parameter_averaging : {}'.format(enable_parameter_averaging))

#-------------------------
# training - fit
#-------------------------
for epoch in range(n_epochs):
    epoch_cost = 0.0
    for batch_xs in raw_feature_generator(batch_size = batch_size):
        _, batch_loss = sess.run([optimizer, ae['loss']], feed_dict={ae['x']: batch_xs})
        epoch_cost += batch_loss / batch_size
    metric_log = (
                "[[epoch {:>8}]]     "
                "[[loss at this epoch]]     loss: {:<12}"
            ).format(epoch, round(epoch_cost, 8))

    logging.info(metric_log)
    if step > min_steps_to_checkpoint:
        save(step)
        if enable_parameter_averaging:
            save(step, averaged=True)
# Out:
# activation : relu
# current_input : (?, 278)
# layer_i-encoder : 0
# n_output-encoder: 140
# n_input : 278
# layer_i-encoder : 1
# n_output-encoder: 70
# n_input : 140
# layer_i-encoder : 2
# n_output-encoder: 30
# n_input : 70
# layer_i-decoder : 0
# n_output-decoder : 70
# layer_i-decoder : 1
# n_output-decoder : 140
# layer_i-decoder : 2
# n_output-decoder : 278
# learning_rate : 0.001
# batch_size : 256
# n_epochs : 1000
# log_interval : 100
# [[epoch        0]]     [[loss at this epoch]]     loss: 4.01145299
# [[epoch        1]]     [[loss at this epoch]]     loss: 3.21221754
# [[epoch        2]]     [[loss at this epoch]]     loss: 2.95331249
# [[epoch        3]]     [[loss at this epoch]]     loss: 2.82267365
# [[epoch        4]]     [[loss at this epoch]]     loss: 2.73162832
# [[epoch        5]]     [[loss at this epoch]]     loss: 2.67879417
# [[epoch        6]]     [[loss at this epoch]]     loss: 2.63703678
# [[epoch        7]]     [[loss at this epoch]]     loss: 2.60075413
# [[epoch        8]]     [[loss at this epoch]]     loss: 2.55194673
# [[epoch        9]]     [[loss at this epoch]]     loss: 2.51357667
# [[epoch       10]]     [[loss at this epoch]]     loss: 2.49679375
# [[epoch       11]]     [[loss at this epoch]]     loss: 2.47473401
# [[epoch       12]]     [[loss at this epoch]]     loss: 2.45557502
# [[epoch       13]]     [[loss at this epoch]]     loss: 2.4253165
# [[epoch       14]]     [[loss at this epoch]]     loss: 2.41013695
# [[epoch       15]]     [[loss at this epoch]]     loss: 2.40280465
# [[epoch       16]]     [[loss at this epoch]]     loss: 2.39177982
# [[epoch       17]]     [[loss at this epoch]]     loss: 2.38371771
# [[epoch       18]]     [[loss at this epoch]]     loss: 2.37806539
# [[epoch       19]]     [[loss at this epoch]]     loss: 2.36107448
# [[epoch       20]]     [[loss at this epoch]]     loss: 2.34983282
# [[epoch       21]]     [[loss at this epoch]]     loss: 2.34214053
# [[epoch       22]]     [[loss at this epoch]]     loss: 2.33746669
# [[epoch       23]]     [[loss at this epoch]]     loss: 2.33314433
# [[epoch       24]]     [[loss at this epoch]]     loss: 2.32872279
# [[epoch       25]]     [[loss at this epoch]]     loss: 2.32505202
# [[epoch       26]]     [[loss at this epoch]]     loss: 2.32143241
# [[epoch       27]]     [[loss at this epoch]]     loss: 2.29540083
# [[epoch       28]]     [[loss at this epoch]]     loss: 2.27957822
# [[epoch       29]]     [[loss at this epoch]]     loss: 2.27591075
# [[epoch       30]]     [[loss at this epoch]]     loss: 2.27440214
# [[epoch       31]]     [[loss at this epoch]]     loss: 2.27096426
# [[epoch       32]]     [[loss at this epoch]]     loss: 2.26755648
# [[epoch       33]]     [[loss at this epoch]]     loss: 2.26491053
# [[epoch       34]]     [[loss at this epoch]]     loss: 2.26232615
# [[epoch       35]]     [[loss at this epoch]]     loss: 2.26382916
# [[epoch       36]]     [[loss at this epoch]]     loss: 2.25997715
# [[epoch       37]]     [[loss at this epoch]]     loss: 2.25773356
# [[epoch       38]]     [[loss at this epoch]]     loss: 2.25699398
# [[epoch       39]]     [[loss at this epoch]]     loss: 2.25496349
# [[epoch       40]]     [[loss at this epoch]]     loss: 2.25242815
# [[epoch       41]]     [[loss at this epoch]]     loss: 2.25177946
# [[epoch       42]]     [[loss at this epoch]]     loss: 2.25031551
# [[epoch       43]]     [[loss at this epoch]]     loss: 2.24929476
# [[epoch       44]]     [[loss at this epoch]]     loss: 2.24711787
# [[epoch       45]]     [[loss at this epoch]]     loss: 2.24646621
# [[epoch       46]]     [[loss at this epoch]]     loss: 2.24412498
# [[epoch       47]]     [[loss at this epoch]]     loss: 2.24356064
# [[epoch       48]]     [[loss at this epoch]]     loss: 2.24278205
# [[epoch       49]]     [[loss at this epoch]]     loss: 2.24151997
# [[epoch       50]]     [[loss at this epoch]]     loss: 2.24154529
# [[epoch       51]]     [[loss at this epoch]]     loss: 2.24025405
# [[epoch       52]]     [[loss at this epoch]]     loss: 2.23816185
# [[epoch       53]]     [[loss at this epoch]]     loss: 2.23758378
# [[epoch       54]]     [[loss at this epoch]]     loss: 2.23673028
# [[epoch       55]]     [[loss at this epoch]]     loss: 2.23790555
# [[epoch       56]]     [[loss at this epoch]]     loss: 2.235397
# [[epoch       57]]     [[loss at this epoch]]     loss: 2.23479676
# [[epoch       58]]     [[loss at this epoch]]     loss: 2.23446071
# [[epoch       59]]     [[loss at this epoch]]     loss: 2.23391781
# [[epoch       60]]     [[loss at this epoch]]     loss: 2.2334354
# [[epoch       61]]     [[loss at this epoch]]     loss: 2.23247663
# [[epoch       62]]     [[loss at this epoch]]     loss: 2.22946379
# [[epoch       63]]     [[loss at this epoch]]     loss: 2.22355046
# [[epoch       64]]     [[loss at this epoch]]     loss: 2.2186454
# [[epoch       65]]     [[loss at this epoch]]     loss: 2.21350728
# [[epoch       66]]     [[loss at this epoch]]     loss: 2.20909938
# [[epoch       67]]     [[loss at this epoch]]     loss: 2.20814082
# [[epoch       68]]     [[loss at this epoch]]     loss: 2.20603869
# [[epoch       69]]     [[loss at this epoch]]     loss: 2.20893968
# [[epoch       70]]     [[loss at this epoch]]     loss: 2.2103424
# [[epoch       71]]     [[loss at this epoch]]     loss: 2.20576076
# [[epoch       72]]     [[loss at this epoch]]     loss: 2.20398637
# [[epoch       73]]     [[loss at this epoch]]     loss: 2.20417415
# [[epoch       74]]     [[loss at this epoch]]     loss: 2.20504261
# [[epoch       75]]     [[loss at this epoch]]     loss: 2.21436758
# [[epoch       76]]     [[loss at this epoch]]     loss: 2.21098193
# [[epoch       77]]     [[loss at this epoch]]     loss: 2.20539277
# [[epoch       78]]     [[loss at this epoch]]     loss: 2.20303435
# [[epoch       79]]     [[loss at this epoch]]     loss: 2.20925223
# [[epoch       80]]     [[loss at this epoch]]     loss: 2.20319837
# [[epoch       81]]     [[loss at this epoch]]     loss: 2.200708
# [[epoch       82]]     [[loss at this epoch]]     loss: 2.20047472
# [[epoch       83]]     [[loss at this epoch]]     loss: 2.20156735
# [[epoch       84]]     [[loss at this epoch]]     loss: 2.19917187
# [[epoch       85]]     [[loss at this epoch]]     loss: 2.20564882
# [[epoch       86]]     [[loss at this epoch]]     loss: 2.20202514
# [[epoch       87]]     [[loss at this epoch]]     loss: 2.19839479
# [[epoch       88]]     [[loss at this epoch]]     loss: 2.2010444
# [[epoch       89]]     [[loss at this epoch]]     loss: 2.1984983
# [[epoch       90]]     [[loss at this epoch]]     loss: 2.19763543
# [[epoch       91]]     [[loss at this epoch]]     loss: 2.20280672
# [[epoch       92]]     [[loss at this epoch]]     loss: 2.19679349
# [[epoch       93]]     [[loss at this epoch]]     loss: 2.19731742
# [[epoch       94]]     [[loss at this epoch]]     loss: 2.20122633
# [[epoch       95]]     [[loss at this epoch]]     loss: 2.19583028
# [[epoch       96]]     [[loss at this epoch]]     loss: 2.19763135
# [[epoch       97]]     [[loss at this epoch]]     loss: 2.20064888
# [[epoch       98]]     [[loss at this epoch]]     loss: 2.20556274
# [[epoch       99]]     [[loss at this epoch]]     loss: 2.19611227
# [[epoch      100]]     [[loss at this epoch]]     loss: 2.19413021
# [[epoch      101]]     [[loss at this epoch]]     loss: 2.19954814
# [[epoch      102]]     [[loss at this epoch]]     loss: 2.19445679
# [[epoch      103]]     [[loss at this epoch]]     loss: 2.19347333
# [[epoch      104]]     [[loss at this epoch]]     loss: 2.19329937
# [[epoch      105]]     [[loss at this epoch]]     loss: 2.19474518
# [[epoch      106]]     [[loss at this epoch]]     loss: 2.19360472
# [[epoch      107]]     [[loss at this epoch]]     loss: 2.1958438
# [[epoch      108]]     [[loss at this epoch]]     loss: 2.19827536
# [[epoch      109]]     [[loss at this epoch]]     loss: 2.19363859
# [[epoch      110]]     [[loss at this epoch]]     loss: 2.19190406
# [[epoch      111]]     [[loss at this epoch]]     loss: 2.19519472
# [[epoch      112]]     [[loss at this epoch]]     loss: 2.19931768
# [[epoch      113]]     [[loss at this epoch]]     loss: 2.19308126
# [[epoch      114]]     [[loss at this epoch]]     loss: 2.19315659
# [[epoch      115]]     [[loss at this epoch]]     loss: 2.19849456
# [[epoch      116]]     [[loss at this epoch]]     loss: 2.19442061
# [[epoch      117]]     [[loss at this epoch]]     loss: 2.19153523
# [[epoch      118]]     [[loss at this epoch]]     loss: 2.19284991
# [[epoch      119]]     [[loss at this epoch]]     loss: 2.19029327
# [[epoch      120]]     [[loss at this epoch]]     loss: 2.19027032
# [[epoch      121]]     [[loss at this epoch]]     loss: 2.19089144
# [[epoch      122]]     [[loss at this epoch]]     loss: 2.18939261
# [[epoch      123]]     [[loss at this epoch]]     loss: 2.19119215
# [[epoch      124]]     [[loss at this epoch]]     loss: 2.19026759
# [[epoch      125]]     [[loss at this epoch]]     loss: 2.19525368
# [[epoch      126]]     [[loss at this epoch]]     loss: 2.1875733
# [[epoch      127]]     [[loss at this epoch]]     loss: 2.18915051
# [[epoch      128]]     [[loss at this epoch]]     loss: 2.18866882
# [[epoch      129]]     [[loss at this epoch]]     loss: 2.19067064
# [[epoch      130]]     [[loss at this epoch]]     loss: 2.18850664
# [[epoch      131]]     [[loss at this epoch]]     loss: 2.19090683
# [[epoch      132]]     [[loss at this epoch]]     loss: 2.18691036
# [[epoch      133]]     [[loss at this epoch]]     loss: 2.18788159
# [[epoch      134]]     [[loss at this epoch]]     loss: 2.18821518
# [[epoch      135]]     [[loss at this epoch]]     loss: 2.18597946
# [[epoch      136]]     [[loss at this epoch]]     loss: 2.18785388
# [[epoch      137]]     [[loss at this epoch]]     loss: 2.18612979
# [[epoch      138]]     [[loss at this epoch]]     loss: 2.19046755
# [[epoch      139]]     [[loss at this epoch]]     loss: 2.18642743
# [[epoch      140]]     [[loss at this epoch]]     loss: 2.18662003
# [[epoch      141]]     [[loss at this epoch]]     loss: 2.18762484
# [[epoch      142]]     [[loss at this epoch]]     loss: 2.18676191
# [[epoch      143]]     [[loss at this epoch]]     loss: 2.18735365
# [[epoch      144]]     [[loss at this epoch]]     loss: 2.18527501
# [[epoch      145]]     [[loss at this epoch]]     loss: 2.19114979
# [[epoch      146]]     [[loss at this epoch]]     loss: 2.1858326
# [[epoch      147]]     [[loss at this epoch]]     loss: 2.18493432
# [[epoch      148]]     [[loss at this epoch]]     loss: 2.18819415
# [[epoch      149]]     [[loss at this epoch]]     loss: 2.18467699
# [[epoch      150]]     [[loss at this epoch]]     loss: 2.18309989
# [[epoch      151]]     [[loss at this epoch]]     loss: 2.18585191
# [[epoch      152]]     [[loss at this epoch]]     loss: 2.18616661
# [[epoch      153]]     [[loss at this epoch]]     loss: 2.18878254
# [[epoch      154]]     [[loss at this epoch]]     loss: 2.1832759
# [[epoch      155]]     [[loss at this epoch]]     loss: 2.1851955
# [[epoch      156]]     [[loss at this epoch]]     loss: 2.18591791
# [[epoch      157]]     [[loss at this epoch]]     loss: 2.18336458
# [[epoch      158]]     [[loss at this epoch]]     loss: 2.18375275
# [[epoch      159]]     [[loss at this epoch]]     loss: 2.18428133
# [[epoch      160]]     [[loss at this epoch]]     loss: 2.18770077
# [[epoch      161]]     [[loss at this epoch]]     loss: 2.18699034
# [[epoch      162]]     [[loss at this epoch]]     loss: 2.18245006
# [[epoch      163]]     [[loss at this epoch]]     loss: 2.18409685
# [[epoch      164]]     [[loss at this epoch]]     loss: 2.18314295
# [[epoch      165]]     [[loss at this epoch]]     loss: 2.1815546
# [[epoch      166]]     [[loss at this epoch]]     loss: 2.18488248
# [[epoch      167]]     [[loss at this epoch]]     loss: 2.18460575
# [[epoch      168]]     [[loss at this epoch]]     loss: 2.19403107
# [[epoch      169]]     [[loss at this epoch]]     loss: 2.18322708
# [[epoch      170]]     [[loss at this epoch]]     loss: 2.18346464
# [[epoch      171]]     [[loss at this epoch]]     loss: 2.18446023
# [[epoch      172]]     [[loss at this epoch]]     loss: 2.19595007
# [[epoch      173]]     [[loss at this epoch]]     loss: 2.18335139
# [[epoch      174]]     [[loss at this epoch]]     loss: 2.18612797
# [[epoch      175]]     [[loss at this epoch]]     loss: 2.18070354
# [[epoch      176]]     [[loss at this epoch]]     loss: 2.18297819
# [[epoch      177]]     [[loss at this epoch]]     loss: 2.18533019
# [[epoch      178]]     [[loss at this epoch]]     loss: 2.18106029
# [[epoch      179]]     [[loss at this epoch]]     loss: 2.18621777
# [[epoch      180]]     [[loss at this epoch]]     loss: 2.17982225
# [[epoch      181]]     [[loss at this epoch]]     loss: 2.18043768
# [[epoch      182]]     [[loss at this epoch]]     loss: 2.18268536
# [[epoch      183]]     [[loss at this epoch]]     loss: 2.18237568
# [[epoch      184]]     [[loss at this epoch]]     loss: 2.18812611
# [[epoch      185]]     [[loss at this epoch]]     loss: 2.18214264
# [[epoch      186]]     [[loss at this epoch]]     loss: 2.18484106
# [[epoch      187]]     [[loss at this epoch]]     loss: 2.17975865
# [[epoch      188]]     [[loss at this epoch]]     loss: 2.18878569
# [[epoch      189]]     [[loss at this epoch]]     loss: 2.18046627
# [[epoch      190]]     [[loss at this epoch]]     loss: 2.1859483
# [[epoch      191]]     [[loss at this epoch]]     loss: 2.18427108
# [[epoch      192]]     [[loss at this epoch]]     loss: 2.1817579
# [[epoch      193]]     [[loss at this epoch]]     loss: 2.19244842
# [[epoch      194]]     [[loss at this epoch]]     loss: 2.181842
# [[epoch      195]]     [[loss at this epoch]]     loss: 2.18369448
# [[epoch      196]]     [[loss at this epoch]]     loss: 2.17945715
# [[epoch      197]]     [[loss at this epoch]]     loss: 2.18431894
# [[epoch      198]]     [[loss at this epoch]]     loss: 2.1779778
# [[epoch      199]]     [[loss at this epoch]]     loss: 2.18129419
# [[epoch      200]]     [[loss at this epoch]]     loss: 2.17846976
# [[epoch      201]]     [[loss at this epoch]]     loss: 2.18603683
# [[epoch      202]]     [[loss at this epoch]]     loss: 2.18165468
# [[epoch      203]]     [[loss at this epoch]]     loss: 2.17809377
# [[epoch      204]]     [[loss at this epoch]]     loss: 2.18153011
# [[epoch      205]]     [[loss at this epoch]]     loss: 2.17797081
# [[epoch      206]]     [[loss at this epoch]]     loss: 2.17832077
# [[epoch      207]]     [[loss at this epoch]]     loss: 2.17940435
# [[epoch      208]]     [[loss at this epoch]]     loss: 2.18119786
# [[epoch      209]]     [[loss at this epoch]]     loss: 2.18515213
# [[epoch      210]]     [[loss at this epoch]]     loss: 2.18108812
# [[epoch      211]]     [[loss at this epoch]]     loss: 2.18089566
# [[epoch      212]]     [[loss at this epoch]]     loss: 2.18091015
# [[epoch      213]]     [[loss at this epoch]]     loss: 2.17897135
# [[epoch      214]]     [[loss at this epoch]]     loss: 2.17867395
# [[epoch      215]]     [[loss at this epoch]]     loss: 2.18059697
# [[epoch      216]]     [[loss at this epoch]]     loss: 2.17956299
# [[epoch      217]]     [[loss at this epoch]]     loss: 2.1807552
# [[epoch      218]]     [[loss at this epoch]]     loss: 2.18066621
# [[epoch      219]]     [[loss at this epoch]]     loss: 2.18037926
# [[epoch      220]]     [[loss at this epoch]]     loss: 2.17756142
# [[epoch      221]]     [[loss at this epoch]]     loss: 2.17834552
# [[epoch      222]]     [[loss at this epoch]]     loss: 2.17742229
# [[epoch      223]]     [[loss at this epoch]]     loss: 2.18183025
# [[epoch      224]]     [[loss at this epoch]]     loss: 2.17897795
# [[epoch      225]]     [[loss at this epoch]]     loss: 2.17757746
# [[epoch      226]]     [[loss at this epoch]]     loss: 2.18076018
# [[epoch      227]]     [[loss at this epoch]]     loss: 2.17698079
# [[epoch      228]]     [[loss at this epoch]]     loss: 2.17956446
# [[epoch      229]]     [[loss at this epoch]]     loss: 2.18174715
# [[epoch      230]]     [[loss at this epoch]]     loss: 2.17998094
# [[epoch      231]]     [[loss at this epoch]]     loss: 2.17709735
# [[epoch      232]]     [[loss at this epoch]]     loss: 2.17709087
# [[epoch      233]]     [[loss at this epoch]]     loss: 2.17904708
# [[epoch      234]]     [[loss at this epoch]]     loss: 2.18206759
# [[epoch      235]]     [[loss at this epoch]]     loss: 2.17708546
# [[epoch      236]]     [[loss at this epoch]]     loss: 2.18257644
# [[epoch      237]]     [[loss at this epoch]]     loss: 2.17837302
# [[epoch      238]]     [[loss at this epoch]]     loss: 2.18083998
# [[epoch      239]]     [[loss at this epoch]]     loss: 2.17771769
# [[epoch      240]]     [[loss at this epoch]]     loss: 2.17878121
# [[epoch      241]]     [[loss at this epoch]]     loss: 2.17919793
# [[epoch      242]]     [[loss at this epoch]]     loss: 2.17453858
# [[epoch      243]]     [[loss at this epoch]]     loss: 2.18017379
# [[epoch      244]]     [[loss at this epoch]]     loss: 2.17746148
# [[epoch      245]]     [[loss at this epoch]]     loss: 2.19387091
# [[epoch      246]]     [[loss at this epoch]]     loss: 2.17799916
# [[epoch      247]]     [[loss at this epoch]]     loss: 2.17920167
# [[epoch      248]]     [[loss at this epoch]]     loss: 2.17699169
# [[epoch      249]]     [[loss at this epoch]]     loss: 2.17557846
# [[epoch      250]]     [[loss at this epoch]]     loss: 2.17646434
# [[epoch      251]]     [[loss at this epoch]]     loss: 2.17871319
# [[epoch      252]]     [[loss at this epoch]]     loss: 2.17750901
# [[epoch      253]]     [[loss at this epoch]]     loss: 2.18499999
# [[epoch      254]]     [[loss at this epoch]]     loss: 2.17890348
# [[epoch      255]]     [[loss at this epoch]]     loss: 2.18036338
# [[epoch      256]]     [[loss at this epoch]]     loss: 2.17821488
# [[epoch      257]]     [[loss at this epoch]]     loss: 2.17775273
# [[epoch      258]]     [[loss at this epoch]]     loss: 2.17723237
# [[epoch      259]]     [[loss at this epoch]]     loss: 2.17882945
# [[epoch      260]]     [[loss at this epoch]]     loss: 2.17638177
# [[epoch      261]]     [[loss at this epoch]]     loss: 2.17879159
# [[epoch      262]]     [[loss at this epoch]]     loss: 2.17744098
# [[epoch      263]]     [[loss at this epoch]]     loss: 2.18066369
# [[epoch      264]]     [[loss at this epoch]]     loss: 2.18266607
# [[epoch      265]]     [[loss at this epoch]]     loss: 2.17896993
# [[epoch      266]]     [[loss at this epoch]]     loss: 2.1810722
# [[epoch      267]]     [[loss at this epoch]]     loss: 2.18036481
# [[epoch      268]]     [[loss at this epoch]]     loss: 2.18129432
# [[epoch      269]]     [[loss at this epoch]]     loss: 2.18359445
# [[epoch      270]]     [[loss at this epoch]]     loss: 2.18333124
# [[epoch      271]]     [[loss at this epoch]]     loss: 2.18382226
# [[epoch      272]]     [[loss at this epoch]]     loss: 2.18013053
# [[epoch      273]]     [[loss at this epoch]]     loss: 2.18026336
# [[epoch      274]]     [[loss at this epoch]]     loss: 2.18612409
# [[epoch      275]]     [[loss at this epoch]]     loss: 2.18327218
# [[epoch      276]]     [[loss at this epoch]]     loss: 2.1830477
# [[epoch      277]]     [[loss at this epoch]]     loss: 2.18338997
# [[epoch      278]]     [[loss at this epoch]]     loss: 2.18391072
# [[epoch      279]]     [[loss at this epoch]]     loss: 2.1896335
# [[epoch      280]]     [[loss at this epoch]]     loss: 2.19101997
# [[epoch      281]]     [[loss at this epoch]]     loss: 2.1846022
# [[epoch      282]]     [[loss at this epoch]]     loss: 2.17969385
# [[epoch      283]]     [[loss at this epoch]]     loss: 2.18580471
# [[epoch      284]]     [[loss at this epoch]]     loss: 2.17893522
# [[epoch      285]]     [[loss at this epoch]]     loss: 2.17955097
# [[epoch      286]]     [[loss at this epoch]]     loss: 2.17707834
# [[epoch      287]]     [[loss at this epoch]]     loss: 2.18474985
# [[epoch      288]]     [[loss at this epoch]]     loss: 2.18041495
# [[epoch      289]]     [[loss at this epoch]]     loss: 2.17984024
# [[epoch      290]]     [[loss at this epoch]]     loss: 2.18259245
# [[epoch      291]]     [[loss at this epoch]]     loss: 2.18254812
# [[epoch      292]]     [[loss at this epoch]]     loss: 2.17912104
# [[epoch      293]]     [[loss at this epoch]]     loss: 2.17808258
# [[epoch      294]]     [[loss at this epoch]]     loss: 2.18291255
# [[epoch      295]]     [[loss at this epoch]]     loss: 2.18185841
# [[epoch      296]]     [[loss at this epoch]]     loss: 2.17682811
# [[epoch      297]]     [[loss at this epoch]]     loss: 2.17825048
# [[epoch      298]]     [[loss at this epoch]]     loss: 2.18212084
# [[epoch      299]]     [[loss at this epoch]]     loss: 2.17830565
# [[epoch      300]]     [[loss at this epoch]]     loss: 2.17735979
# [[epoch      301]]     [[loss at this epoch]]     loss: 2.17662266
# [[epoch      302]]     [[loss at this epoch]]     loss: 2.19182164
# [[epoch      303]]     [[loss at this epoch]]     loss: 2.1783299
# [[epoch      304]]     [[loss at this epoch]]     loss: 2.17814116
# [[epoch      305]]     [[loss at this epoch]]     loss: 2.17661829
# [[epoch      306]]     [[loss at this epoch]]     loss: 2.17240489
# [[epoch      307]]     [[loss at this epoch]]     loss: 2.17661496
# [[epoch      308]]     [[loss at this epoch]]     loss: 2.17398445
# [[epoch      309]]     [[loss at this epoch]]     loss: 2.17389349
# [[epoch      310]]     [[loss at this epoch]]     loss: 2.17741198
# [[epoch      311]]     [[loss at this epoch]]     loss: 2.17694063
# [[epoch      312]]     [[loss at this epoch]]     loss: 2.1801469
# [[epoch      313]]     [[loss at this epoch]]     loss: 2.1758432
# [[epoch      314]]     [[loss at this epoch]]     loss: 2.1732066
# [[epoch      315]]     [[loss at this epoch]]     loss: 2.17857568
# [[epoch      316]]     [[loss at this epoch]]     loss: 2.18397007
# [[epoch      317]]     [[loss at this epoch]]     loss: 2.1736631
# [[epoch      318]]     [[loss at this epoch]]     loss: 2.1747909
# [[epoch      319]]     [[loss at this epoch]]     loss: 2.17656963
# [[epoch      320]]     [[loss at this epoch]]     loss: 2.17427612
# [[epoch      321]]     [[loss at this epoch]]     loss: 2.17478953
# [[epoch      322]]     [[loss at this epoch]]     loss: 2.17938363
# [[epoch      323]]     [[loss at this epoch]]     loss: 2.17461174
# [[epoch      324]]     [[loss at this epoch]]     loss: 2.17724564
# [[epoch      325]]     [[loss at this epoch]]     loss: 2.17650418
# [[epoch      326]]     [[loss at this epoch]]     loss: 2.17348545
# [[epoch      327]]     [[loss at this epoch]]     loss: 2.17444879
# [[epoch      328]]     [[loss at this epoch]]     loss: 2.17411215
# [[epoch      329]]     [[loss at this epoch]]     loss: 2.18744219
# [[epoch      330]]     [[loss at this epoch]]     loss: 2.17683777
# [[epoch      331]]     [[loss at this epoch]]     loss: 2.17612817
# [[epoch      332]]     [[loss at this epoch]]     loss: 2.17666353
# [[epoch      333]]     [[loss at this epoch]]     loss: 2.17604832
# [[epoch      334]]     [[loss at this epoch]]     loss: 2.1818402
# [[epoch      335]]     [[loss at this epoch]]     loss: 2.17245614
# [[epoch      336]]     [[loss at this epoch]]     loss: 2.17348882
# [[epoch      337]]     [[loss at this epoch]]     loss: 2.17811301
# [[epoch      338]]     [[loss at this epoch]]     loss: 2.1779283
# [[epoch      339]]     [[loss at this epoch]]     loss: 2.17556444
# [[epoch      340]]     [[loss at this epoch]]     loss: 2.17684358
# [[epoch      341]]     [[loss at this epoch]]     loss: 2.18383218
# [[epoch      342]]     [[loss at this epoch]]     loss: 2.17371483
# [[epoch      343]]     [[loss at this epoch]]     loss: 2.17621102
# [[epoch      344]]     [[loss at this epoch]]     loss: 2.17253447
# [[epoch      345]]     [[loss at this epoch]]     loss: 2.18230239
# [[epoch      346]]     [[loss at this epoch]]     loss: 2.1774633
# [[epoch      347]]     [[loss at this epoch]]     loss: 2.17628339
# [[epoch      348]]     [[loss at this epoch]]     loss: 2.17612517
# [[epoch      349]]     [[loss at this epoch]]     loss: 2.17479961
# [[epoch      350]]     [[loss at this epoch]]     loss: 2.17572264
# [[epoch      351]]     [[loss at this epoch]]     loss: 2.17463637
# [[epoch      352]]     [[loss at this epoch]]     loss: 2.17167081
# [[epoch      353]]     [[loss at this epoch]]     loss: 2.18575687
# [[epoch      354]]     [[loss at this epoch]]     loss: 2.17833275
# [[epoch      355]]     [[loss at this epoch]]     loss: 2.17390456
# [[epoch      356]]     [[loss at this epoch]]     loss: 2.17589149
# [[epoch      357]]     [[loss at this epoch]]     loss: 2.18027171
# [[epoch      358]]     [[loss at this epoch]]     loss: 2.17604421
# [[epoch      359]]     [[loss at this epoch]]     loss: 2.17373018
# [[epoch      360]]     [[loss at this epoch]]     loss: 2.1760234
# [[epoch      361]]     [[loss at this epoch]]     loss: 2.17580766
# [[epoch      362]]     [[loss at this epoch]]     loss: 2.17435522
# [[epoch      363]]     [[loss at this epoch]]     loss: 2.17437845
# [[epoch      364]]     [[loss at this epoch]]     loss: 2.17420072
# [[epoch      365]]     [[loss at this epoch]]     loss: 2.17919208
# [[epoch      366]]     [[loss at this epoch]]     loss: 2.18165543
# [[epoch      367]]     [[loss at this epoch]]     loss: 2.17091109
# [[epoch      368]]     [[loss at this epoch]]     loss: 2.17439998
# [[epoch      369]]     [[loss at this epoch]]     loss: 2.17369152
# [[epoch      370]]     [[loss at this epoch]]     loss: 2.1789538
# [[epoch      371]]     [[loss at this epoch]]     loss: 2.21291755
# [[epoch      372]]     [[loss at this epoch]]     loss: 2.17367485
# [[epoch      373]]     [[loss at this epoch]]     loss: 2.17329363
# [[epoch      374]]     [[loss at this epoch]]     loss: 2.17498013
# [[epoch      375]]     [[loss at this epoch]]     loss: 2.17416384
# [[epoch      376]]     [[loss at this epoch]]     loss: 2.17326388
# [[epoch      377]]     [[loss at this epoch]]     loss: 2.17124491
# [[epoch      378]]     [[loss at this epoch]]     loss: 2.17622689
# [[epoch      379]]     [[loss at this epoch]]     loss: 2.17192113
# [[epoch      380]]     [[loss at this epoch]]     loss: 2.17451622
# [[epoch      381]]     [[loss at this epoch]]     loss: 2.17395661
# [[epoch      382]]     [[loss at this epoch]]     loss: 2.17484794
# [[epoch      383]]     [[loss at this epoch]]     loss: 2.17263729
# [[epoch      384]]     [[loss at this epoch]]     loss: 2.17481912
# [[epoch      385]]     [[loss at this epoch]]     loss: 2.17411466
# [[epoch      386]]     [[loss at this epoch]]     loss: 2.17379246
# [[epoch      387]]     [[loss at this epoch]]     loss: 2.17694817
# [[epoch      388]]     [[loss at this epoch]]     loss: 2.17388642
# [[epoch      389]]     [[loss at this epoch]]     loss: 2.17100599
# [[epoch      390]]     [[loss at this epoch]]     loss: 2.17974952
# [[epoch      391]]     [[loss at this epoch]]     loss: 2.17158974
# [[epoch      392]]     [[loss at this epoch]]     loss: 2.17464595
# [[epoch      393]]     [[loss at this epoch]]     loss: 2.17639051
# [[epoch      394]]     [[loss at this epoch]]     loss: 2.17567724
# [[epoch      395]]     [[loss at this epoch]]     loss: 2.17448439
# [[epoch      396]]     [[loss at this epoch]]     loss: 2.18206526
# [[epoch      397]]     [[loss at this epoch]]     loss: 2.17794649
# [[epoch      398]]     [[loss at this epoch]]     loss: 2.1869049
# [[epoch      399]]     [[loss at this epoch]]     loss: 2.17562886
# [[epoch      400]]     [[loss at this epoch]]     loss: 2.17581441
# [[epoch      401]]     [[loss at this epoch]]     loss: 2.17965085
# [[epoch      402]]     [[loss at this epoch]]     loss: 2.17492668
# [[epoch      403]]     [[loss at this epoch]]     loss: 2.17506448
# [[epoch      404]]     [[loss at this epoch]]     loss: 2.16954911
# [[epoch      405]]     [[loss at this epoch]]     loss: 2.17315922
# [[epoch      406]]     [[loss at this epoch]]     loss: 2.21719595
# [[epoch      407]]     [[loss at this epoch]]     loss: 2.17348999
# [[epoch      408]]     [[loss at this epoch]]     loss: 2.17282537
# [[epoch      409]]     [[loss at this epoch]]     loss: 2.17236485
# [[epoch      410]]     [[loss at this epoch]]     loss: 2.18405452
# [[epoch      411]]     [[loss at this epoch]]     loss: 2.1712747
# [[epoch      412]]     [[loss at this epoch]]     loss: 2.17793599
# [[epoch      413]]     [[loss at this epoch]]     loss: 2.17562297
# [[epoch      414]]     [[loss at this epoch]]     loss: 2.17678996
# [[epoch      415]]     [[loss at this epoch]]     loss: 2.16909694
# [[epoch      416]]     [[loss at this epoch]]     loss: 2.17184953
# [[epoch      417]]     [[loss at this epoch]]     loss: 2.17146737
# [[epoch      418]]     [[loss at this epoch]]     loss: 2.18386307
# [[epoch      419]]     [[loss at this epoch]]     loss: 2.17219883
# [[epoch      420]]     [[loss at this epoch]]     loss: 2.17329049
# [[epoch      421]]     [[loss at this epoch]]     loss: 2.17607631
# [[epoch      422]]     [[loss at this epoch]]     loss: 2.17073999
# [[epoch      423]]     [[loss at this epoch]]     loss: 2.17784363
# [[epoch      424]]     [[loss at this epoch]]     loss: 2.18016023
# [[epoch      425]]     [[loss at this epoch]]     loss: 2.17924529
# [[epoch      426]]     [[loss at this epoch]]     loss: 2.19014012
# [[epoch      427]]     [[loss at this epoch]]     loss: 2.17721565
# [[epoch      428]]     [[loss at this epoch]]     loss: 2.17243889
# [[epoch      429]]     [[loss at this epoch]]     loss: 2.17773895
# [[epoch      430]]     [[loss at this epoch]]     loss: 2.17244097
# [[epoch      431]]     [[loss at this epoch]]     loss: 2.17572017
# [[epoch      432]]     [[loss at this epoch]]     loss: 2.17436353
# [[epoch      433]]     [[loss at this epoch]]     loss: 2.17716132
# [[epoch      434]]     [[loss at this epoch]]     loss: 2.17268122
# [[epoch      435]]     [[loss at this epoch]]     loss: 2.17267136
# [[epoch      436]]     [[loss at this epoch]]     loss: 2.17304248
# [[epoch      437]]     [[loss at this epoch]]     loss: 2.17898749
# [[epoch      438]]     [[loss at this epoch]]     loss: 2.17760091
# [[epoch      439]]     [[loss at this epoch]]     loss: 2.17132719
# [[epoch      440]]     [[loss at this epoch]]     loss: 2.17060348
# [[epoch      441]]     [[loss at this epoch]]     loss: 2.17280757
# [[epoch      442]]     [[loss at this epoch]]     loss: 2.17611034
# [[epoch      443]]     [[loss at this epoch]]     loss: 2.17094683
# [[epoch      444]]     [[loss at this epoch]]     loss: 2.16996192
# [[epoch      445]]     [[loss at this epoch]]     loss: 2.17037676
# [[epoch      446]]     [[loss at this epoch]]     loss: 2.17474425
# [[epoch      447]]     [[loss at this epoch]]     loss: 2.17479067
# [[epoch      448]]     [[loss at this epoch]]     loss: 2.16918454
# [[epoch      449]]     [[loss at this epoch]]     loss: 2.18500141
# [[epoch      450]]     [[loss at this epoch]]     loss: 2.19197854
# [[epoch      451]]     [[loss at this epoch]]     loss: 2.17000085
# [[epoch      452]]     [[loss at this epoch]]     loss: 2.18096696
# [[epoch      453]]     [[loss at this epoch]]     loss: 2.168259
# [[epoch      454]]     [[loss at this epoch]]     loss: 2.17443335
# [[epoch      455]]     [[loss at this epoch]]     loss: 2.16846609
# [[epoch      456]]     [[loss at this epoch]]     loss: 2.16934108
# [[epoch      457]]     [[loss at this epoch]]     loss: 2.17156625
# [[epoch      458]]     [[loss at this epoch]]     loss: 2.17810704
# [[epoch      459]]     [[loss at this epoch]]     loss: 2.17158382
# [[epoch      460]]     [[loss at this epoch]]     loss: 2.17505678
# [[epoch      461]]     [[loss at this epoch]]     loss: 2.17255908
# [[epoch      462]]     [[loss at this epoch]]     loss: 2.17219609
# [[epoch      463]]     [[loss at this epoch]]     loss: 2.17229022
# [[epoch      464]]     [[loss at this epoch]]     loss: 2.17043555
# [[epoch      465]]     [[loss at this epoch]]     loss: 2.17295854
# [[epoch      466]]     [[loss at this epoch]]     loss: 2.17081523
# [[epoch      467]]     [[loss at this epoch]]     loss: 2.1697712
# [[epoch      468]]     [[loss at this epoch]]     loss: 2.17087667
# [[epoch      469]]     [[loss at this epoch]]     loss: 2.17183679
# [[epoch      470]]     [[loss at this epoch]]     loss: 2.16781328
# [[epoch      471]]     [[loss at this epoch]]     loss: 2.17823437
# [[epoch      472]]     [[loss at this epoch]]     loss: 2.17463402
# [[epoch      473]]     [[loss at this epoch]]     loss: 2.16960617
# [[epoch      474]]     [[loss at this epoch]]     loss: 2.17356381
# [[epoch      475]]     [[loss at this epoch]]     loss: 2.17286434
# [[epoch      476]]     [[loss at this epoch]]     loss: 2.17685036
# [[epoch      477]]     [[loss at this epoch]]     loss: 2.16869671
# [[epoch      478]]     [[loss at this epoch]]     loss: 2.17105615
# [[epoch      479]]     [[loss at this epoch]]     loss: 2.17072783
# [[epoch      480]]     [[loss at this epoch]]     loss: 2.17010348
# [[epoch      481]]     [[loss at this epoch]]     loss: 2.16838062
# [[epoch      482]]     [[loss at this epoch]]     loss: 2.16962099
# [[epoch      483]]     [[loss at this epoch]]     loss: 2.17224354
# [[epoch      484]]     [[loss at this epoch]]     loss: 2.17378234
# [[epoch      485]]     [[loss at this epoch]]     loss: 2.17211098
# [[epoch      486]]     [[loss at this epoch]]     loss: 2.17061186
# [[epoch      487]]     [[loss at this epoch]]     loss: 2.1695881
# [[epoch      488]]     [[loss at this epoch]]     loss: 2.1706817
# [[epoch      489]]     [[loss at this epoch]]     loss: 2.17288269
# [[epoch      490]]     [[loss at this epoch]]     loss: 2.17973336
# [[epoch      491]]     [[loss at this epoch]]     loss: 2.17454519
# [[epoch      492]]     [[loss at this epoch]]     loss: 2.17809764
# [[epoch      493]]     [[loss at this epoch]]     loss: 2.17054188
# [[epoch      494]]     [[loss at this epoch]]     loss: 2.17651576
# [[epoch      495]]     [[loss at this epoch]]     loss: 2.19008375
# [[epoch      496]]     [[loss at this epoch]]     loss: 2.16923378
# [[epoch      497]]     [[loss at this epoch]]     loss: 2.17083392
# [[epoch      498]]     [[loss at this epoch]]     loss: 2.17293272
# [[epoch      499]]     [[loss at this epoch]]     loss: 2.16941154
# [[epoch      500]]     [[loss at this epoch]]     loss: 2.17304679
# [[epoch      501]]     [[loss at this epoch]]     loss: 2.170195
# [[epoch      502]]     [[loss at this epoch]]     loss: 2.17267867
# [[epoch      503]]     [[loss at this epoch]]     loss: 2.1693215
# [[epoch      504]]     [[loss at this epoch]]     loss: 2.17923101
# [[epoch      505]]     [[loss at this epoch]]     loss: 2.16995553
# [[epoch      506]]     [[loss at this epoch]]     loss: 2.17420455
# [[epoch      507]]     [[loss at this epoch]]     loss: 2.17039285
# [[epoch      508]]     [[loss at this epoch]]     loss: 2.17848375
# [[epoch      509]]     [[loss at this epoch]]     loss: 2.17301285
# [[epoch      510]]     [[loss at this epoch]]     loss: 2.1712006
# [[epoch      511]]     [[loss at this epoch]]     loss: 2.17200072
# [[epoch      512]]     [[loss at this epoch]]     loss: 2.17289663
# [[epoch      513]]     [[loss at this epoch]]     loss: 2.17642734
# [[epoch      514]]     [[loss at this epoch]]     loss: 2.17174936
# [[epoch      515]]     [[loss at this epoch]]     loss: 2.17340096
# [[epoch      516]]     [[loss at this epoch]]     loss: 2.17918056
# [[epoch      517]]     [[loss at this epoch]]     loss: 2.17495935
# [[epoch      518]]     [[loss at this epoch]]     loss: 2.17355855
# [[epoch      519]]     [[loss at this epoch]]     loss: 2.17155948
# [[epoch      520]]     [[loss at this epoch]]     loss: 2.17252245
# [[epoch      521]]     [[loss at this epoch]]     loss: 2.17022275
# [[epoch      522]]     [[loss at this epoch]]     loss: 2.174144
# [[epoch      523]]     [[loss at this epoch]]     loss: 2.17321104
# [[epoch      524]]     [[loss at this epoch]]     loss: 2.17178661
# [[epoch      525]]     [[loss at this epoch]]     loss: 2.17249452
# [[epoch      526]]     [[loss at this epoch]]     loss: 2.17102306
# [[epoch      527]]     [[loss at this epoch]]     loss: 2.17517819
# [[epoch      528]]     [[loss at this epoch]]     loss: 2.17134697
# [[epoch      529]]     [[loss at this epoch]]     loss: 2.1780988
# [[epoch      530]]     [[loss at this epoch]]     loss: 2.17251988
# [[epoch      531]]     [[loss at this epoch]]     loss: 2.16878918
# [[epoch      532]]     [[loss at this epoch]]     loss: 2.17364637
# [[epoch      533]]     [[loss at this epoch]]     loss: 2.17560054
# [[epoch      534]]     [[loss at this epoch]]     loss: 2.17523924
# [[epoch      535]]     [[loss at this epoch]]     loss: 2.17295986
# [[epoch      536]]     [[loss at this epoch]]     loss: 2.17057696
# [[epoch      537]]     [[loss at this epoch]]     loss: 2.17037078
# [[epoch      538]]     [[loss at this epoch]]     loss: 2.17376742
# [[epoch      539]]     [[loss at this epoch]]     loss: 2.17601133
# [[epoch      540]]     [[loss at this epoch]]     loss: 2.17481237
# [[epoch      541]]     [[loss at this epoch]]     loss: 2.17642301
# [[epoch      542]]     [[loss at this epoch]]     loss: 2.17432961
# [[epoch      543]]     [[loss at this epoch]]     loss: 2.1712485
# [[epoch      544]]     [[loss at this epoch]]     loss: 2.17876751
# [[epoch      545]]     [[loss at this epoch]]     loss: 2.17887993
# [[epoch      546]]     [[loss at this epoch]]     loss: 2.17010724
# [[epoch      547]]     [[loss at this epoch]]     loss: 2.17445398
# [[epoch      548]]     [[loss at this epoch]]     loss: 2.17767439
# [[epoch      549]]     [[loss at this epoch]]     loss: 2.17375509
# [[epoch      550]]     [[loss at this epoch]]     loss: 2.17281904
# [[epoch      551]]     [[loss at this epoch]]     loss: 2.17431139
# [[epoch      552]]     [[loss at this epoch]]     loss: 2.17805225
# [[epoch      553]]     [[loss at this epoch]]     loss: 2.17440321
# [[epoch      554]]     [[loss at this epoch]]     loss: 2.17359476
# [[epoch      555]]     [[loss at this epoch]]     loss: 2.17072821
# [[epoch      556]]     [[loss at this epoch]]     loss: 2.17160805
# [[epoch      557]]     [[loss at this epoch]]     loss: 2.18519834
# [[epoch      558]]     [[loss at this epoch]]     loss: 2.17866445
# [[epoch      559]]     [[loss at this epoch]]     loss: 2.17186808
# [[epoch      560]]     [[loss at this epoch]]     loss: 2.17234323
# [[epoch      561]]     [[loss at this epoch]]     loss: 2.17461702
# [[epoch      562]]     [[loss at this epoch]]     loss: 2.17431197
# [[epoch      563]]     [[loss at this epoch]]     loss: 2.1753595
# [[epoch      564]]     [[loss at this epoch]]     loss: 2.18150085
# [[epoch      565]]     [[loss at this epoch]]     loss: 2.17211388
# [[epoch      566]]     [[loss at this epoch]]     loss: 2.17585093
# [[epoch      567]]     [[loss at this epoch]]     loss: 2.17659922
# [[epoch      568]]     [[loss at this epoch]]     loss: 2.17523313
# [[epoch      569]]     [[loss at this epoch]]     loss: 2.17620712
# [[epoch      570]]     [[loss at this epoch]]     loss: 2.17427358
# [[epoch      571]]     [[loss at this epoch]]     loss: 2.16730114
# [[epoch      572]]     [[loss at this epoch]]     loss: 2.17453471
# [[epoch      573]]     [[loss at this epoch]]     loss: 2.17345859
# [[epoch      574]]     [[loss at this epoch]]     loss: 2.1725073
# [[epoch      575]]     [[loss at this epoch]]     loss: 2.1784577
# [[epoch      576]]     [[loss at this epoch]]     loss: 2.17749699
# [[epoch      577]]     [[loss at this epoch]]     loss: 2.17523546
# [[epoch      578]]     [[loss at this epoch]]     loss: 2.17510234
# [[epoch      579]]     [[loss at this epoch]]     loss: 2.1776534
# [[epoch      580]]     [[loss at this epoch]]     loss: 2.17941401
# [[epoch      581]]     [[loss at this epoch]]     loss: 2.17757421
# [[epoch      582]]     [[loss at this epoch]]     loss: 2.1751721
# [[epoch      583]]     [[loss at this epoch]]     loss: 2.18150497
# [[epoch      584]]     [[loss at this epoch]]     loss: 2.17255612
# [[epoch      585]]     [[loss at this epoch]]     loss: 2.17696315
# [[epoch      586]]     [[loss at this epoch]]     loss: 2.1773671
# [[epoch      587]]     [[loss at this epoch]]     loss: 2.17405519
# [[epoch      588]]     [[loss at this epoch]]     loss: 2.177134
# [[epoch      589]]     [[loss at this epoch]]     loss: 2.17656042
# [[epoch      590]]     [[loss at this epoch]]     loss: 2.17999265
# [[epoch      591]]     [[loss at this epoch]]     loss: 2.1743945
# [[epoch      592]]     [[loss at this epoch]]     loss: 2.17186172
# [[epoch      593]]     [[loss at this epoch]]     loss: 2.17525246
# [[epoch      594]]     [[loss at this epoch]]     loss: 2.17419183
# [[epoch      595]]     [[loss at this epoch]]     loss: 2.18514063
# [[epoch      596]]     [[loss at this epoch]]     loss: 2.17361228
# [[epoch      597]]     [[loss at this epoch]]     loss: 2.1759076
# [[epoch      598]]     [[loss at this epoch]]     loss: 2.18375139
# [[epoch      599]]     [[loss at this epoch]]     loss: 2.17428079
# [[epoch      600]]     [[loss at this epoch]]     loss: 2.17642672
# [[epoch      601]]     [[loss at this epoch]]     loss: 2.17585171
# [[epoch      602]]     [[loss at this epoch]]     loss: 2.17273115
# [[epoch      603]]     [[loss at this epoch]]     loss: 2.17511214
# [[epoch      604]]     [[loss at this epoch]]     loss: 2.18086659
# [[epoch      605]]     [[loss at this epoch]]     loss: 2.17748623
# [[epoch      606]]     [[loss at this epoch]]     loss: 2.17214668
# [[epoch      607]]     [[loss at this epoch]]     loss: 2.18375901
# [[epoch      608]]     [[loss at this epoch]]     loss: 2.17301579
# [[epoch      609]]     [[loss at this epoch]]     loss: 2.17344256
# [[epoch      610]]     [[loss at this epoch]]     loss: 2.18459232
# [[epoch      611]]     [[loss at this epoch]]     loss: 2.17724474
# [[epoch      612]]     [[loss at this epoch]]     loss: 2.17448131
# [[epoch      613]]     [[loss at this epoch]]     loss: 2.1748436
# [[epoch      614]]     [[loss at this epoch]]     loss: 2.17760458
# [[epoch      615]]     [[loss at this epoch]]     loss: 2.17276175
# [[epoch      616]]     [[loss at this epoch]]     loss: 2.17376305
# [[epoch      617]]     [[loss at this epoch]]     loss: 2.17328777
# [[epoch      618]]     [[loss at this epoch]]     loss: 2.17452829
# [[epoch      619]]     [[loss at this epoch]]     loss: 2.17281319
# [[epoch      620]]     [[loss at this epoch]]     loss: 2.17309658
# [[epoch      621]]     [[loss at this epoch]]     loss: 2.16828102
# [[epoch      622]]     [[loss at this epoch]]     loss: 2.16695577
# [[epoch      623]]     [[loss at this epoch]]     loss: 2.17557592
# [[epoch      624]]     [[loss at this epoch]]     loss: 2.17164758
# [[epoch      625]]     [[loss at this epoch]]     loss: 2.16925444
# [[epoch      626]]     [[loss at this epoch]]     loss: 2.17075462
# [[epoch      627]]     [[loss at this epoch]]     loss: 2.16807084
# [[epoch      628]]     [[loss at this epoch]]     loss: 2.1716015
# [[epoch      629]]     [[loss at this epoch]]     loss: 2.17725597
# [[epoch      630]]     [[loss at this epoch]]     loss: 2.17266646
# [[epoch      631]]     [[loss at this epoch]]     loss: 2.17293859
# [[epoch      632]]     [[loss at this epoch]]     loss: 2.1764019
# [[epoch      633]]     [[loss at this epoch]]     loss: 2.16746802
# [[epoch      634]]     [[loss at this epoch]]     loss: 2.17073507
# [[epoch      635]]     [[loss at this epoch]]     loss: 2.16953059
# [[epoch      636]]     [[loss at this epoch]]     loss: 2.17038516
# [[epoch      637]]     [[loss at this epoch]]     loss: 2.17205837
# [[epoch      638]]     [[loss at this epoch]]     loss: 2.16900278
# [[epoch      639]]     [[loss at this epoch]]     loss: 2.18330058
# [[epoch      640]]     [[loss at this epoch]]     loss: 2.16836812
# [[epoch      641]]     [[loss at this epoch]]     loss: 2.17104098
# [[epoch      642]]     [[loss at this epoch]]     loss: 2.17076245
# [[epoch      643]]     [[loss at this epoch]]     loss: 2.16708122
# [[epoch      644]]     [[loss at this epoch]]     loss: 2.16644013
# [[epoch      645]]     [[loss at this epoch]]     loss: 2.17022578
# [[epoch      646]]     [[loss at this epoch]]     loss: 2.17523587
# [[epoch      647]]     [[loss at this epoch]]     loss: 2.16885544
# [[epoch      648]]     [[loss at this epoch]]     loss: 2.18562663
# [[epoch      649]]     [[loss at this epoch]]     loss: 2.1699132
# [[epoch      650]]     [[loss at this epoch]]     loss: 2.16926474
# [[epoch      651]]     [[loss at this epoch]]     loss: 2.16775181
# [[epoch      652]]     [[loss at this epoch]]     loss: 2.17699689
# [[epoch      653]]     [[loss at this epoch]]     loss: 2.16564438
# [[epoch      654]]     [[loss at this epoch]]     loss: 2.17116755
# [[epoch      655]]     [[loss at this epoch]]     loss: 2.16743823
# [[epoch      656]]     [[loss at this epoch]]     loss: 2.17377773
# [[epoch      657]]     [[loss at this epoch]]     loss: 2.17349349
# [[epoch      658]]     [[loss at this epoch]]     loss: 2.16773021
# [[epoch      659]]     [[loss at this epoch]]     loss: 2.16934907
# [[epoch      660]]     [[loss at this epoch]]     loss: 2.16947331
# [[epoch      661]]     [[loss at this epoch]]     loss: 2.16907123
# [[epoch      662]]     [[loss at this epoch]]     loss: 2.16910944
# [[epoch      663]]     [[loss at this epoch]]     loss: 2.16722004
# [[epoch      664]]     [[loss at this epoch]]     loss: 2.17275146
# [[epoch      665]]     [[loss at this epoch]]     loss: 2.16705221
# [[epoch      666]]     [[loss at this epoch]]     loss: 2.16922342
# [[epoch      667]]     [[loss at this epoch]]     loss: 2.177922
# [[epoch      668]]     [[loss at this epoch]]     loss: 2.1672789
# [[epoch      669]]     [[loss at this epoch]]     loss: 2.16993582
# [[epoch      670]]     [[loss at this epoch]]     loss: 2.16531564
# [[epoch      671]]     [[loss at this epoch]]     loss: 2.17359947
# [[epoch      672]]     [[loss at this epoch]]     loss: 2.17250751
# [[epoch      673]]     [[loss at this epoch]]     loss: 2.16943953
# [[epoch      674]]     [[loss at this epoch]]     loss: 2.17180653
# [[epoch      675]]     [[loss at this epoch]]     loss: 2.16607173
# [[epoch      676]]     [[loss at this epoch]]     loss: 2.17618197
# [[epoch      677]]     [[loss at this epoch]]     loss: 2.1642844
# [[epoch      678]]     [[loss at this epoch]]     loss: 2.16564875
# [[epoch      679]]     [[loss at this epoch]]     loss: 2.16564301
# [[epoch      680]]     [[loss at this epoch]]     loss: 2.1687377
# [[epoch      681]]     [[loss at this epoch]]     loss: 2.16566197
# [[epoch      682]]     [[loss at this epoch]]     loss: 2.17234713
# [[epoch      683]]     [[loss at this epoch]]     loss: 2.1715222
# [[epoch      684]]     [[loss at this epoch]]     loss: 2.16805295
# [[epoch      685]]     [[loss at this epoch]]     loss: 2.16577338
# [[epoch      686]]     [[loss at this epoch]]     loss: 2.17165276
# [[epoch      687]]     [[loss at this epoch]]     loss: 2.17172356
# [[epoch      688]]     [[loss at this epoch]]     loss: 2.1661584
# ...
# [[epoch      768]]     [[loss at this epoch]]     loss: 2.16609924
# [[epoch      769]]     [[loss at this epoch]]     loss: 2.17367453
# [[epoch      770]]     [[loss at this epoch]]     loss: 2.16779085
# [[epoch      771]]     [[loss at this epoch]]     loss: 2.1830054
# [[epoch      772]]     [[loss at this epoch]]     loss: 2.16728518
# [[epoch      773]]     [[loss at this epoch]]     loss: 2.17043978
# [[epoch      774]]     [[loss at this epoch]]     loss: 2.16858263
# [[epoch      775]]     [[loss at this epoch]]     loss: 2.17151489
# [[epoch      776]]     [[loss at this epoch]]     loss: 2.17565567
# [[epoch      777]]     [[loss at this epoch]]     loss: 2.16360728
# [[epoch      778]]     [[loss at this epoch]]     loss: 2.16785266
# [[epoch      779]]     [[loss at this epoch]]     loss: 2.17420591
# [[epoch      780]]     [[loss at this epoch]]     loss: 2.16732376
# [[epoch      781]]     [[loss at this epoch]]     loss: 2.1690603
# [[epoch      782]]     [[loss at this epoch]]     loss: 2.18795334
# [[epoch      783]]     [[loss at this epoch]]     loss: 2.17551575
# [[epoch      784]]     [[loss at this epoch]]     loss: 2.17197904
# [[epoch      785]]     [[loss at this epoch]]     loss: 2.16614923
# [[epoch      786]]     [[loss at this epoch]]     loss: 2.18210715
# [[epoch      787]]     [[loss at this epoch]]     loss: 2.17641212
# [[epoch      788]]     [[loss at this epoch]]     loss: 2.17372695
# [[epoch      789]]     [[loss at this epoch]]     loss: 2.17307781
# [[epoch      790]]     [[loss at this epoch]]     loss: 2.16268611
# [[epoch      791]]     [[loss at this epoch]]     loss: 2.1731429
# [[epoch      792]]     [[loss at this epoch]]     loss: 2.16794367
# [[epoch      793]]     [[loss at this epoch]]     loss: 2.16350411
# [[epoch      794]]     [[loss at this epoch]]     loss: 2.16654254
# [[epoch      795]]     [[loss at this epoch]]     loss: 2.16674867
# [[epoch      796]]     [[loss at this epoch]]     loss: 2.16731065
# [[epoch      797]]     [[loss at this epoch]]     loss: 2.16336929
# [[epoch      798]]     [[loss at this epoch]]     loss: 2.17691239
# [[epoch      799]]     [[loss at this epoch]]     loss: 2.16280314
# [[epoch      800]]     [[loss at this epoch]]     loss: 2.16353214
# [[epoch      801]]     [[loss at this epoch]]     loss: 2.17250756
# [[epoch      802]]     [[loss at this epoch]]     loss: 2.1660617
# [[epoch      803]]     [[loss at this epoch]]     loss: 2.16333338
# [[epoch      804]]     [[loss at this epoch]]     loss: 2.16552572
# [[epoch      805]]     [[loss at this epoch]]     loss: 2.17375263
# [[epoch      806]]     [[loss at this epoch]]     loss: 2.17201565
# [[epoch      807]]     [[loss at this epoch]]     loss: 2.16333995
# [[epoch      808]]     [[loss at this epoch]]     loss: 2.16757242
# [[epoch      809]]     [[loss at this epoch]]     loss: 2.16823872
# [[epoch      810]]     [[loss at this epoch]]     loss: 2.16560234
# [[epoch      811]]     [[loss at this epoch]]     loss: 2.16351208
# [[epoch      812]]     [[loss at this epoch]]     loss: 2.16572383
# [[epoch      813]]     [[loss at this epoch]]     loss: 2.16261266
# [[epoch      814]]     [[loss at this epoch]]     loss: 2.16305382
# [[epoch      815]]     [[loss at this epoch]]     loss: 2.16392584
# [[epoch      816]]     [[loss at this epoch]]     loss: 2.16849514
# [[epoch      817]]     [[loss at this epoch]]     loss: 2.17162589
# [[epoch      818]]     [[loss at this epoch]]     loss: 2.16338056
# [[epoch      819]]     [[loss at this epoch]]     loss: 2.16408467
# [[epoch      820]]     [[loss at this epoch]]     loss: 2.16508919
# [[epoch      821]]     [[loss at this epoch]]     loss: 2.16980813
# [[epoch      822]]     [[loss at this epoch]]     loss: 2.16541607
# [[epoch      823]]     [[loss at this epoch]]     loss: 2.16759453
# [[epoch      824]]     [[loss at this epoch]]     loss: 2.16808268
# [[epoch      825]]     [[loss at this epoch]]     loss: 2.16624575
# [[epoch      826]]     [[loss at this epoch]]     loss: 2.171041
# [[epoch      827]]     [[loss at this epoch]]     loss: 2.18415643
# [[epoch      828]]     [[loss at this epoch]]     loss: 2.17560517
# [[epoch      829]]     [[loss at this epoch]]     loss: 2.18023867
# [[epoch      830]]     [[loss at this epoch]]     loss: 2.18330648
# [[epoch      831]]     [[loss at this epoch]]     loss: 2.18095476
# [[epoch      832]]     [[loss at this epoch]]     loss: 2.16541528
# [[epoch      833]]     [[loss at this epoch]]     loss: 2.17695363
# [[epoch      834]]     [[loss at this epoch]]     loss: 2.1831426
# [[epoch      835]]     [[loss at this epoch]]     loss: 2.18193662
# [[epoch      836]]     [[loss at this epoch]]     loss: 2.18858589
# [[epoch      837]]     [[loss at this epoch]]     loss: 2.18602701
# [[epoch      838]]     [[loss at this epoch]]     loss: 2.18126771
# [[epoch      839]]     [[loss at this epoch]]     loss: 2.1844276
# [[epoch      840]]     [[loss at this epoch]]     loss: 2.18278778
# [[epoch      841]]     [[loss at this epoch]]     loss: 2.18285343
# [[epoch      842]]     [[loss at this epoch]]     loss: 2.1826867
# [[epoch      843]]     [[loss at this epoch]]     loss: 2.18365721
# [[epoch      844]]     [[loss at this epoch]]     loss: 2.18295001
# [[epoch      845]]     [[loss at this epoch]]     loss: 2.17850849
# [[epoch      846]]     [[loss at this epoch]]     loss: 2.18345465
# [[epoch      847]]     [[loss at this epoch]]     loss: 2.18312015
# [[epoch      848]]     [[loss at this epoch]]     loss: 2.18049023
# [[epoch      849]]     [[loss at this epoch]]     loss: 2.18202542
# [[epoch      850]]     [[loss at this epoch]]     loss: 2.18332258
# [[epoch      851]]     [[loss at this epoch]]     loss: 2.18420957
# [[epoch      852]]     [[loss at this epoch]]     loss: 2.1812359
# [[epoch      853]]     [[loss at this epoch]]     loss: 2.18145402
# [[epoch      854]]     [[loss at this epoch]]     loss: 2.1844002
# [[epoch      855]]     [[loss at this epoch]]     loss: 2.18344378
# [[epoch      856]]     [[loss at this epoch]]     loss: 2.18554001
# [[epoch      857]]     [[loss at this epoch]]     loss: 2.18258285
# [[epoch      858]]     [[loss at this epoch]]     loss: 2.18060419
# [[epoch      859]]     [[loss at this epoch]]     loss: 2.18109721
# [[epoch      860]]     [[loss at this epoch]]     loss: 2.18461348
# [[epoch      861]]     [[loss at this epoch]]     loss: 2.18339072
# [[epoch      862]]     [[loss at this epoch]]     loss: 2.18762216
# [[epoch      863]]     [[loss at this epoch]]     loss: 2.18353
# [[epoch      864]]     [[loss at this epoch]]     loss: 2.18176685
# [[epoch      865]]     [[loss at this epoch]]     loss: 2.18273095
# [[epoch      866]]     [[loss at this epoch]]     loss: 2.18447688
# [[epoch      867]]     [[loss at this epoch]]     loss: 2.18294499
# [[epoch      868]]     [[loss at this epoch]]     loss: 2.18571014
# [[epoch      869]]     [[loss at this epoch]]     loss: 2.18744784
# [[epoch      870]]     [[loss at this epoch]]     loss: 2.18498837
# [[epoch      871]]     [[loss at this epoch]]     loss: 2.184805
# [[epoch      872]]     [[loss at this epoch]]     loss: 2.18441008
# [[epoch      873]]     [[loss at this epoch]]     loss: 2.18388447
# [[epoch      874]]     [[loss at this epoch]]     loss: 2.18310053
# [[epoch      875]]     [[loss at this epoch]]     loss: 2.18218817
# [[epoch      876]]     [[loss at this epoch]]     loss: 2.18351551
# [[epoch      877]]     [[loss at this epoch]]     loss: 2.18378798
# [[epoch      878]]     [[loss at this epoch]]     loss: 2.18246751
# [[epoch      879]]     [[loss at this epoch]]     loss: 2.18308811
# [[epoch      880]]     [[loss at this epoch]]     loss: 2.1816953
# [[epoch      881]]     [[loss at this epoch]]     loss: 2.18672995
# [[epoch      882]]     [[loss at this epoch]]     loss: 2.18509082
# [[epoch      883]]     [[loss at this epoch]]     loss: 2.1864369
# [[epoch      884]]     [[loss at this epoch]]     loss: 2.18292292
# [[epoch      885]]     [[loss at this epoch]]     loss: 2.17904862
# [[epoch      886]]     [[loss at this epoch]]     loss: 2.1823274
# [[epoch      887]]     [[loss at this epoch]]     loss: 2.18398947
# [[epoch      888]]     [[loss at this epoch]]     loss: 2.1826534
# [[epoch      889]]     [[loss at this epoch]]     loss: 2.18387209
# [[epoch      890]]     [[loss at this epoch]]     loss: 2.18569453
# [[epoch      891]]     [[loss at this epoch]]     loss: 2.18380324
# [[epoch      892]]     [[loss at this epoch]]     loss: 2.18801816
# [[epoch      893]]     [[loss at this epoch]]     loss: 2.18460801
# [[epoch      894]]     [[loss at this epoch]]     loss: 2.1835869
# [[epoch      895]]     [[loss at this epoch]]     loss: 2.18310699
# [[epoch      896]]     [[loss at this epoch]]     loss: 2.18125902
# [[epoch      897]]     [[loss at this epoch]]     loss: 2.17960487
# [[epoch      898]]     [[loss at this epoch]]     loss: 2.18276433
# [[epoch      899]]     [[loss at this epoch]]     loss: 2.18096413
# [[epoch      900]]     [[loss at this epoch]]     loss: 2.18160148
# [[epoch      901]]     [[loss at this epoch]]     loss: 2.18015833
# [[epoch      902]]     [[loss at this epoch]]     loss: 2.17971315
# [[epoch      903]]     [[loss at this epoch]]     loss: 2.19057385
# [[epoch      904]]     [[loss at this epoch]]     loss: 2.17921238
# [[epoch      905]]     [[loss at this epoch]]     loss: 2.18125549
# [[epoch      906]]     [[loss at this epoch]]     loss: 2.18967446
# [[epoch      907]]     [[loss at this epoch]]     loss: 2.18835557
# [[epoch      908]]     [[loss at this epoch]]     loss: 2.18330082
# [[epoch      909]]     [[loss at this epoch]]     loss: 2.18592049
# [[epoch      910]]     [[loss at this epoch]]     loss: 2.18572477
# [[epoch      911]]     [[loss at this epoch]]     loss: 2.18711944
# [[epoch      912]]     [[loss at this epoch]]     loss: 2.19234415
# [[epoch      913]]     [[loss at this epoch]]     loss: 2.18658701
# [[epoch      914]]     [[loss at this epoch]]     loss: 2.1843343
# [[epoch      915]]     [[loss at this epoch]]     loss: 2.18291019
# [[epoch      916]]     [[loss at this epoch]]     loss: 2.19195266
# [[epoch      917]]     [[loss at this epoch]]     loss: 2.18339134
# [[epoch      918]]     [[loss at this epoch]]     loss: 2.17984367
# [[epoch      919]]     [[loss at this epoch]]     loss: 2.18061621
# [[epoch      920]]     [[loss at this epoch]]     loss: 2.19634946
# [[epoch      921]]     [[loss at this epoch]]     loss: 2.18612457
# [[epoch      922]]     [[loss at this epoch]]     loss: 2.18191606
# [[epoch      923]]     [[loss at this epoch]]     loss: 2.17926325
# [[epoch      924]]     [[loss at this epoch]]     loss: 2.18132311
# [[epoch      925]]     [[loss at this epoch]]     loss: 2.18314041
# [[epoch      926]]     [[loss at this epoch]]     loss: 2.18160078
# [[epoch      927]]     [[loss at this epoch]]     loss: 2.18246604
# [[epoch      928]]     [[loss at this epoch]]     loss: 2.18306212
# [[epoch      929]]     [[loss at this epoch]]     loss: 2.17993523
# [[epoch      930]]     [[loss at this epoch]]     loss: 2.1900433
# [[epoch      931]]     [[loss at this epoch]]     loss: 2.18530301
# [[epoch      932]]     [[loss at this epoch]]     loss: 2.17874
# [[epoch      933]]     [[loss at this epoch]]     loss: 2.1833792
# [[epoch      934]]     [[loss at this epoch]]     loss: 2.17794922
# [[epoch      935]]     [[loss at this epoch]]     loss: 2.18099775
# [[epoch      936]]     [[loss at this epoch]]     loss: 2.17991938
# [[epoch      937]]     [[loss at this epoch]]     loss: 2.17953833
# [[epoch      938]]     [[loss at this epoch]]     loss: 2.18211808
# [[epoch      939]]     [[loss at this epoch]]     loss: 2.18537321
# [[epoch      940]]     [[loss at this epoch]]     loss: 2.17868747
# [[epoch      941]]     [[loss at this epoch]]     loss: 2.18260822
# [[epoch      942]]     [[loss at this epoch]]     loss: 2.17967973
# [[epoch      943]]     [[loss at this epoch]]     loss: 2.18115988
# [[epoch      944]]     [[loss at this epoch]]     loss: 2.17909133
# [[epoch      945]]     [[loss at this epoch]]     loss: 2.18650994
# [[epoch      946]]     [[loss at this epoch]]     loss: 2.18741653
# [[epoch      947]]     [[loss at this epoch]]     loss: 2.18226489
# [[epoch      948]]     [[loss at this epoch]]     loss: 2.17905997
# [[epoch      949]]     [[loss at this epoch]]     loss: 2.18707792
# [[epoch      950]]     [[loss at this epoch]]     loss: 2.17906212
# [[epoch      951]]     [[loss at this epoch]]     loss: 2.19148916
# [[epoch      952]]     [[loss at this epoch]]     loss: 2.18631561
# [[epoch      953]]     [[loss at this epoch]]     loss: 2.18072447
# [[epoch      954]]     [[loss at this epoch]]     loss: 2.18271791
# [[epoch      955]]     [[loss at this epoch]]     loss: 2.18842459
# [[epoch      956]]     [[loss at this epoch]]     loss: 2.18112125
# [[epoch      957]]     [[loss at this epoch]]     loss: 2.18661168
# [[epoch      958]]     [[loss at this epoch]]     loss: 2.18437008
# [[epoch      959]]     [[loss at this epoch]]     loss: 2.1908459
# [[epoch      960]]     [[loss at this epoch]]     loss: 2.18347662
# [[epoch      961]]     [[loss at this epoch]]     loss: 2.17877747
# [[epoch      962]]     [[loss at this epoch]]     loss: 2.17725768
# [[epoch      963]]     [[loss at this epoch]]     loss: 2.18630996
# [[epoch      964]]     [[loss at this epoch]]     loss: 2.17968838
# [[epoch      965]]     [[loss at this epoch]]     loss: 2.18798997
# [[epoch      966]]     [[loss at this epoch]]     loss: 2.18328447
# [[epoch      967]]     [[loss at this epoch]]     loss: 2.1892988
# [[epoch      968]]     [[loss at this epoch]]     loss: 2.18306666
# [[epoch      969]]     [[loss at this epoch]]     loss: 2.18292794
# [[epoch      970]]     [[loss at this epoch]]     loss: 2.1780601
# [[epoch      971]]     [[loss at this epoch]]     loss: 2.18223665
# [[epoch      972]]     [[loss at this epoch]]     loss: 2.1796613
# [[epoch      973]]     [[loss at this epoch]]     loss: 2.18224713
# [[epoch      974]]     [[loss at this epoch]]     loss: 2.19103316
# [[epoch      975]]     [[loss at this epoch]]     loss: 2.19464009
# [[epoch      976]]     [[loss at this epoch]]     loss: 2.18524603
# [[epoch      977]]     [[loss at this epoch]]     loss: 2.17963182
# [[epoch      978]]     [[loss at this epoch]]     loss: 2.18039936
# [[epoch      979]]     [[loss at this epoch]]     loss: 2.17950253
# [[epoch      980]]     [[loss at this epoch]]     loss: 2.18750748
# [[epoch      981]]     [[loss at this epoch]]     loss: 2.17923198
# [[epoch      982]]     [[loss at this epoch]]     loss: 2.18032561
# [[epoch      983]]     [[loss at this epoch]]     loss: 2.18569042
# [[epoch      984]]     [[loss at this epoch]]     loss: 2.18206461
# [[epoch      985]]     [[loss at this epoch]]     loss: 2.18231001
# [[epoch      986]]     [[loss at this epoch]]     loss: 2.18228033
# [[epoch      987]]     [[loss at this epoch]]     loss: 2.18611034
# [[epoch      988]]     [[loss at this epoch]]     loss: 2.17944043
# [[epoch      989]]     [[loss at this epoch]]     loss: 2.18976698
# [[epoch      990]]     [[loss at this epoch]]     loss: 2.17993884
# [[epoch      991]]     [[loss at this epoch]]     loss: 2.18951073
# [[epoch      992]]     [[loss at this epoch]]     loss: 2.18550145
# [[epoch      993]]     [[loss at this epoch]]     loss: 2.18652683
# [[epoch      994]]     [[loss at this epoch]]     loss: 2.18059006
# [[epoch      995]]     [[loss at this epoch]]     loss: 2.17989299
# [[epoch      996]]     [[loss at this epoch]]     loss: 2.18366135
# [[epoch      997]]     [[loss at this epoch]]     loss: 2.18601221
# [[epoch      998]]     [[loss at this epoch]]     loss: 2.19137289
# [[epoch      999]]     [[loss at this epoch]]     loss: 2.18762616
