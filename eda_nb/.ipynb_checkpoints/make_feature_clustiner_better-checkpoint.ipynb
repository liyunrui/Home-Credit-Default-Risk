# %%
import pandas as pd
import numpy as np
from kmodes.kmodes import KModes
import pandas as pd
import time
import os
import multiprocessing as mp # for speeding up some process
import sys
sys.path.append('../py_model')
from utils import init_logging
import logging 
from scipy.cluster import hierarchy
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [16, 10] # customizing

# %% [markdown]
# # Clustering using k-mode

# %%
import pandas as pd

feature_scaling = True

#----------------------------
# loading original features
#----------------------------
original_raw_featurs = pd.read_hdf('../features/original_raw_featurs.h5','original_raw_featurs')
no_need_to_inpute = ['index']
original_raw_featurs.drop(no_need_to_inpute, axis = 1, inplace = True)
# handling with infinity
original_raw_featurs.replace([np.inf, -np.inf], np.nan, inplace = True)
print (original_raw_featurs.shape)

# # feature scaling with ignoring np.nan
# if feature_scaling == True:
#     for f in original_raw_featurs.columns.tolist():
#         mean = original_raw_featurs[f].mean()
#         std = original_raw_featurs[f].std()
#         original_raw_featurs[f] = (original_raw_featurs[f] - mean) / std

# preprocessing for clusting
original_raw_featurs.replace(np.nan, 0, inplace = True)

# check transpose
df_transposed = original_raw_featurs.T
print (df_transposed.shape)

# clustering

km = KModes(n_clusters=4, init='Cao', n_init=5, verbose=1)

clusters = km.fit_predict(df_transposed)

# output the clustering result
feature_clustering = pd.DataFrame({
    'features':df_transposed.index.tolist(),
    'cluster': km.labels_
})
# save the clustering result
feature_clustering.to_csv('../output/without_normalizing_feature_clustering.csv', index = False)

feature_clustering.cluster.value_counts()

# %%
feature_clustering = pd.read_csv('../output/without_normalizing_feature_clustering.csv')
feature_clustering.cluster.value_counts()
# Out:
# 0    775
# 1     28
# 3      9
# 2      7
# Name: cluster, dtype: int64

# %% [markdown]
# # KNN

# %%
# reload again for filling
df = pd.read_hdf('../features/base_featurs.h5','base_featurs')
print (df.shape)
copy_for_the_following_merge = df[['SK_ID_CURR','TARGET']].copy()
no_need_to_inpute = ['index']
df.drop(no_need_to_inpute, axis = 1, inplace = True)
# handling with infinity
df.replace([np.inf, -np.inf], np.nan, inplace = True)
# check the feature nullity
feature_clustering = pd.read_csv('../output/without_normalizing_feature_clustering.csv')
same_cluster_features = feature_clustering[feature_clustering.cluster == 1].features.tolist()
for f_in_same_cluster in same_cluster_features:
    if f_in_same_cluster in set(df.columns.tolist()):
        print (f_in_same_cluster)
        print (df[f_in_same_cluster].count())
# Out:
# (356251, 281)
# CODE_GENDER
# 356251
# FLAG_DOCUMENT_3
# 356251
# REGION_RATING_CLIENT
# 356251
# REGION_RATING_CLIENT_W_CITY
# 356251
# NAME_CONTRACT_TYPE_Cash loans
# 356251
# NAME_EDUCATION_TYPE_Secondary / secondary special
# 356251
# NAME_FAMILY_STATUS_Married
# 356251
# NAME_HOUSING_TYPE_House / apartment
# 356251
# NAME_INCOME_TYPE_Working
# 356251
# PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN
# 338853
# PREV_NAME_CONTRACT_STATUS_Approved_MEAN
# 338853
# PREV_CODE_REJECT_REASON_XAP_MEAN
# 338853
# PREV_NAME_PORTFOLIO_POS_MEAN
# 338853
# POS_NAME_CONTRACT_STATUS_Active_MEAN
# 337248

# %%
base_feature_worth_imputing_ls = list(set(df.columns.tolist()) & set(same_cluster_features))
len(base_feature_worth_imputing_ls)
# Out:
# 14

# %%
X_missing_df = df[base_feature_worth_imputing_ls]
# feature scaling before KNN
feature_scaling = True
if feature_scaling == True:
    for f in X_missing_df.columns.tolist():
        mean = X_missing_df[f].mean()
        std = X_missing_df[f].std()
        X_missing_df[f] = (X_missing_df[f] - mean) / std
        
print ('X_missing_df', X_missing_df.shape)
small_df_ls = []
num_split = 20
previous_step = None
for i, step in enumerate(np.arange(0, X_missing_df.shape[0], step = int(X_missing_df.shape[0] / num_split))):
    # for memory problem, we cannot feed all the data points into algorithm, which depends on row and n_features
    if i == 0:
        pass
    elif i == 1:
        small_df_ls.append(X_missing_df[0: step])
        previous_step = step
    elif i == (num_split):
        small_df_ls.append(X_missing_df[previous_step: ])
        break
    else:
        small_df_ls.append(X_missing_df[previous_step: step])
        previous_step = step
pd.concat(small_df_ls, axis = 0).shape
# Out:
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# X_missing_df (356251, 14)
# (356251, 14)

# %%
from ycimpute.imputer.knnimput import KNN # inputation library

def multi(small_df):
    k = 65
    X_missing = small_df.copy()
    print ('input of KNN imputing : {}'.format(X_missing.shape))
    # core algorithm: input should be array
    X_filled = KNN(k = k).complete(X_missing.values)
    return pd.DataFrame(X_filled, columns = X_missing.columns)

mp_pool = mp.Pool(len(small_df_ls)) 
small_df_filled_ls = mp_pool.map(multi, small_df_ls)
# Out:
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17812, 14)
# input of KNN imputing : (17823, 14)
# Imputing row 1/17812 with 0 missing, elapsed time: 104.181
# Imputing row 101/17812 with 0 missing, elapsed time: 104.190
# Imputing row 201/17812 with 0 missing, elapsed time: 104.199
# Imputing row 301/17812 with 0 missing, elapsed time: 104.212
# Imputing row 401/17812 with 0 missing, elapsed time: 104.221
# Imputing row 501/17812 with 0 missing, elapsed time: 104.230
# Imputing row 601/17812 with 0 missing, elapsed time: 104.243
# Imputing row 701/17812 with 0 missing, elapsed time: 104.249
# Imputing row 801/17812 with 0 missing, elapsed time: 104.259
# Imputing row 901/17812 with 0 missing, elapsed time: 104.273
# Imputing row 1001/17812 with 5 missing, elapsed time: 104.282
# Imputing row 1101/17812 with 0 missing, elapsed time: 104.292
# Imputing row 1201/17812 with 0 missing, elapsed time: 104.301
# Imputing row 1301/17812 with 0 missing, elapsed time: 104.307
# Imputing row 1401/17812 with 0 missing, elapsed time: 104.314
# Imputing row 1501/17812 with 0 missing, elapsed time: 104.319
# Imputing row 1601/17812 with 0 missing, elapsed time: 104.325
# Imputing row 1701/17812 with 0 missing, elapsed time: 104.334
# Imputing row 1801/17812 with 0 missing, elapsed time: 104.342
# Imputing row 1901/17812 with 0 missing, elapsed time: 104.353
# Imputing row 2001/17812 with 0 missing, elapsed time: 104.359
# Imputing row 2101/17812 with 0 missing, elapsed time: 104.367
# Imputing row 2201/17812 with 0 missing, elapsed time: 104.376
# Imputing row 2301/17812 with 0 missing, elapsed time: 104.382
# Imputing row 2401/17812 with 0 missing, elapsed time: 104.390
# Imputing row 2501/17812 with 0 missing, elapsed time: 104.394
# Imputing row 2601/17812 with 0 missing, elapsed time: 104.398
# Imputing row 2701/17812 with 0 missing, elapsed time: 104.405
# Imputing row 2801/17812 with 0 missing, elapsed time: 104.413
# Imputing row 2901/17812 with 0 missing, elapsed time: 104.417
# Imputing row 3001/17812 with 0 missing, elapsed time: 104.424
# Imputing row 3101/17812 with 0 missing, elapsed time: 104.430
# Imputing row 3201/17812 with 0 missing, elapsed time: 104.437
# Imputing row 2601/17823 with 0 missing, elapsed time: 106.537
# Imputing row 2701/17823 with 0 missing, elapsed time: 106.539
# Imputing row 2801/17823 with 0 missing, elapsed time: 106.541
# Imputing row 2901/17823 with 0 missing, elapsed time: 106.543
# Imputing row 3001/17823 with 0 missing, elapsed time: 106.546
# Imputing row 3101/17823 with 0 missing, elapsed time: 106.548
# Imputing row 3201/17823 with 0 missing, elapsed time: 106.551
# Imputing row 3301/17823 with 0 missing, elapsed time: 106.552
# Imputing row 3401/17823 with 0 missing, elapsed time: 106.555
# Imputing row 3501/17823 with 0 missing, elapsed time: 106.556
# Imputing row 3601/17823 with 0 missing, elapsed time: 106.558
# Imputing row 3701/17823 with 0 missing, elapsed time: 106.561
# Imputing row 3801/17823 with 0 missing, elapsed time: 106.564
# Imputing row 3901/17823 with 0 missing, elapsed time: 106.566
# Imputing row 4001/17823 with 0 missing, elapsed time: 106.569
# Imputing row 4101/17823 with 0 missing, elapsed time: 106.573
# Imputing row 4201/17823 with 0 missing, elapsed time: 106.575
# Imputing row 4301/17823 with 0 missing, elapsed time: 106.576
# Imputing row 4401/17823 with 0 missing, elapsed time: 106.578
# Imputing row 4501/17823 with 0 missing, elapsed time: 106.580
# Imputing row 4601/17823 with 0 missing, elapsed time: 106.582
# Imputing row 4701/17823 with 0 missing, elapsed time: 106.584
# Imputing row 4801/17823 with 0 missing, elapsed time: 106.587
# Imputing row 4901/17823 with 0 missing, elapsed time: 106.590
# Imputing row 5001/17823 with 0 missing, elapsed time: 106.593
# Imputing row 5101/17823 with 0 missing, elapsed time: 106.595
# Imputing row 5201/17823 with 0 missing, elapsed time: 106.598
# Imputing row 5301/17823 with 5 missing, elapsed time: 106.600
# Imputing row 5401/17823 with 0 missing, elapsed time: 106.602
# Imputing row 5501/17823 with 0 missing, elapsed time: 106.604
# Imputing row 5601/17823 with 0 missing, elapsed time: 106.607
# Imputing row 5701/17823 with 0 missing, elapsed time: 106.609
# Imputing row 5801/17823 with 0 missing, elapsed time: 106.611
# Imputing row 5901/17823 with 0 missing, elapsed time: 106.612
# Imputing row 6001/17823 with 0 missing, elapsed time: 106.614
# Imputing row 6101/17823 with 0 missing, elapsed time: 106.615
# Imputing row 6201/17823 with 0 missing, elapsed time: 106.618
# Imputing row 6301/17823 with 0 missing, elapsed time: 106.620
# Imputing row 6401/17823 with 0 missing, elapsed time: 106.621
# Imputing row 6501/17823 with 0 missing, elapsed time: 106.624
# Imputing row 6601/17823 with 0 missing, elapsed time: 106.625
# Imputing row 6701/17823 with 0 missing, elapsed time: 106.628
# Imputing row 6801/17823 with 0 missing, elapsed time: 106.629
# Imputing row 6901/17823 with 0 missing, elapsed time: 106.632
# Imputing row 7001/17823 with 0 missing, elapsed time: 106.633
# Imputing row 7101/17823 with 0 missing, elapsed time: 106.635
# Imputing row 7201/17823 with 0 missing, elapsed time: 106.636
# Imputing row 7301/17823 with 0 missing, elapsed time: 106.638
# Imputing row 7401/17823 with 0 missing, elapsed time: 106.640
# Imputing row 7501/17823 with 0 missing, elapsed time: 106.641
# Imputing row 7601/17823 with 0 missing, elapsed time: 106.642
# Imputing row 7701/17823 with 0 missing, elapsed time: 106.643
# Imputing row 7801/17823 with 0 missing, elapsed time: 106.646
# Imputing row 7901/17823 with 0 missing, elapsed time: 106.648
# Imputing row 8001/17823 with 0 missing, elapsed time: 106.649
# Imputing row 8101/17823 with 0 missing, elapsed time: 106.650
# Imputing row 8201/17823 with 0 missing, elapsed time: 106.652
# Imputing row 8301/17823 with 0 missing, elapsed time: 106.653
# Imputing row 8401/17823 with 0 missing, elapsed time: 106.654
# Imputing row 8501/17823 with 0 missing, elapsed time: 106.656
# Imputing row 8601/17823 with 0 missing, elapsed time: 106.657
# Imputing row 8701/17823 with 0 missing, elapsed time: 106.659
# Imputing row 8801/17823 with 0 missing, elapsed time: 106.661
# Imputing row 8901/17823 with 0 missing, elapsed time: 106.665
# Imputing row 9001/17823 with 0 missing, elapsed time: 106.667
# Imputing row 9101/17823 with 0 missing, elapsed time: 106.671
# Imputing row 9201/17823 with 0 missing, elapsed time: 106.672
# Imputing row 9301/17823 with 0 missing, elapsed time: 106.675
# Imputing row 9401/17823 with 0 missing, elapsed time: 106.677
# Imputing row 9501/17823 with 0 missing, elapsed time: 106.680
# Imputing row 9601/17823 with 0 missing, elapsed time: 106.682
# Imputing row 9701/17823 with 0 missing, elapsed time: 106.683
# Imputing row 9801/17823 with 0 missing, elapsed time: 106.685
# Imputing row 9901/17823 with 0 missing, elapsed time: 106.688
# Imputing row 10001/17823 with 0 missing, elapsed time: 106.691
# Imputing row 10101/17823 with 0 missing, elapsed time: 106.693
# Imputing row 10201/17823 with 0 missing, elapsed time: 106.697
# Imputing row 10301/17823 with 0 missing, elapsed time: 106.701
# Imputing row 10401/17823 with 0 missing, elapsed time: 106.703
# Imputing row 10501/17823 with 0 missing, elapsed time: 106.707
# Imputing row 10601/17823 with 0 missing, elapsed time: 106.710
# Imputing row 10701/17823 with 0 missing, elapsed time: 106.715
# Imputing row 10801/17823 with 0 missing, elapsed time: 106.718
# Imputing row 10901/17823 with 0 missing, elapsed time: 106.722
# Imputing row 11001/17823 with 0 missing, elapsed time: 106.725
# Imputing row 11101/17823 with 0 missing, elapsed time: 106.726
# Imputing row 11201/17823 with 0 missing, elapsed time: 106.731
# Imputing row 11301/17823 with 0 missing, elapsed time: 106.734
# Imputing row 11401/17823 with 0 missing, elapsed time: 106.736
# Imputing row 11501/17823 with 0 missing, elapsed time: 106.739
# Imputing row 11601/17823 with 0 missing, elapsed time: 106.745
# Imputing row 11701/17823 with 0 missing, elapsed time: 106.748
# Imputing row 11801/17823 with 0 missing, elapsed time: 106.754
# Imputing row 11901/17823 with 0 missing, elapsed time: 106.759
# Imputing row 12001/17823 with 0 missing, elapsed time: 106.764
# Imputing row 12101/17823 with 0 missing, elapsed time: 106.767
# Imputing row 12201/17823 with 0 missing, elapsed time: 106.774
# Imputing row 12301/17823 with 0 missing, elapsed time: 106.779
# Imputing row 12401/17823 with 0 missing, elapsed time: 106.783
# Imputing row 12501/17823 with 0 missing, elapsed time: 106.785
# Imputing row 12601/17823 with 0 missing, elapsed time: 106.789
# Imputing row 12701/17823 with 0 missing, elapsed time: 106.792
# Imputing row 12801/17823 with 0 missing, elapsed time: 106.796
# Imputing row 12901/17823 with 0 missing, elapsed time: 106.799
# Imputing row 13001/17823 with 0 missing, elapsed time: 106.801
# Imputing row 13101/17823 with 0 missing, elapsed time: 106.805
# Imputing row 13201/17823 with 0 missing, elapsed time: 106.807
# Imputing row 13301/17823 with 0 missing, elapsed time: 106.809
# Imputing row 13401/17823 with 0 missing, elapsed time: 106.812
# Imputing row 13501/17823 with 0 missing, elapsed time: 106.813
# Imputing row 13601/17823 with 0 missing, elapsed time: 106.816
# Imputing row 13701/17823 with 0 missing, elapsed time: 106.819
# Imputing row 13801/17823 with 0 missing, elapsed time: 106.820
# Imputing row 13901/17823 with 0 missing, elapsed time: 106.822
# Imputing row 14001/17823 with 0 missing, elapsed time: 106.824
# Imputing row 14101/17823 with 0 missing, elapsed time: 106.828
# Imputing row 14201/17823 with 0 missing, elapsed time: 106.838
# Imputing row 14301/17823 with 0 missing, elapsed time: 106.842
# Imputing row 14401/17823 with 0 missing, elapsed time: 106.846
# Imputing row 14501/17823 with 5 missing, elapsed time: 106.848
# Imputing row 14601/17823 with 0 missing, elapsed time: 106.854
# Imputing row 14701/17823 with 0 missing, elapsed time: 106.858
# Imputing row 14801/17823 with 0 missing, elapsed time: 106.862
# Imputing row 14901/17823 with 0 missing, elapsed time: 106.867
# Imputing row 15001/17823 with 0 missing, elapsed time: 106.872
# Imputing row 15101/17823 with 0 missing, elapsed time: 106.876
# Imputing row 15201/17823 with 0 missing, elapsed time: 106.881
# Imputing row 15301/17823 with 0 missing, elapsed time: 106.884
# Imputing row 15401/17823 with 0 missing, elapsed time: 106.886
# Imputing row 15501/17823 with 0 missing, elapsed time: 106.887
# Imputing row 15601/17823 with 0 missing, elapsed time: 106.889
# Imputing row 15701/17823 with 0 missing, elapsed time: 106.890
# Imputing row 15801/17823 with 0 missing, elapsed time: 106.892
# Imputing row 15901/17823 with 0 missing, elapsed time: 106.894
# Imputing row 16001/17823 with 0 missing, elapsed time: 106.896
# Imputing row 16101/17823 with 0 missing, elapsed time: 106.897
# Imputing row 16201/17823 with 0 missing, elapsed time: 106.899
# Imputing row 16301/17823 with 0 missing, elapsed time: 106.900
# Imputing row 16401/17823 with 0 missing, elapsed time: 106.901
# Imputing row 16501/17823 with 0 missing, elapsed time: 106.904
# Imputing row 16601/17823 with 5 missing, elapsed time: 106.905
# Imputing row 16701/17823 with 0 missing, elapsed time: 106.908
# Imputing row 16801/17823 with 0 missing, elapsed time: 106.911
# Imputing row 16901/17823 with 0 missing, elapsed time: 106.912
# Imputing row 17001/17823 with 0 missing, elapsed time: 106.916
# Imputing row 17101/17823 with 0 missing, elapsed time: 106.918
# Imputing row 17201/17823 with 0 missing, elapsed time: 106.923
# Imputing row 17301/17823 with 0 missing, elapsed time: 106.925
# Imputing row 17401/17823 with 0 missing, elapsed time: 106.926
# Imputing row 17501/17823 with 0 missing, elapsed time: 106.928
# Imputing row 1801/17812 with 0 missing, elapsed time: 110.247
# Imputing row 1901/17812 with 0 missing, elapsed time: 110.255
# Imputing row 2001/17812 with 0 missing, elapsed time: 110.263
# Imputing row 2101/17812 with 0 missing, elapsed time: 110.270
# Imputing row 2201/17812 with 0 missing, elapsed time: 110.278
# Imputing row 2301/17812 with 0 missing, elapsed time: 110.282
# Imputing row 2401/17812 with 0 missing, elapsed time: 110.290
# Imputing row 2501/17812 with 0 missing, elapsed time: 110.294
# Imputing row 2601/17812 with 5 missing, elapsed time: 110.301
# Imputing row 2701/17812 with 0 missing, elapsed time: 110.309
# Imputing row 2801/17812 with 0 missing, elapsed time: 110.314
# Imputing row 2901/17812 with 0 missing, elapsed time: 110.319
# Imputing row 3001/17812 with 0 missing, elapsed time: 110.323
# Imputing row 3101/17812 with 0 missing, elapsed time: 110.326
# Imputing row 3201/17812 with 0 missing, elapsed time: 110.331
# Imputing row 3301/17812 with 0 missing, elapsed time: 110.336
# Imputing row 3401/17812 with 0 missing, elapsed time: 110.339
# Imputing row 3501/17812 with 1 missing, elapsed time: 110.342
# Imputing row 3601/17812 with 0 missing, elapsed time: 110.348
# Imputing row 3701/17812 with 0 missing, elapsed time: 110.351
# Imputing row 3801/17812 with 0 missing, elapsed time: 110.357
# Imputing row 3901/17812 with 0 missing, elapsed time: 110.364
# Imputing row 4001/17812 with 0 missing, elapsed time: 110.368
# Imputing row 4101/17812 with 0 missing, elapsed time: 110.373
# ...
# Imputing row 17301/17812 with 0 missing, elapsed time: 119.056
# Imputing row 17401/17812 with 0 missing, elapsed time: 119.058
# Imputing row 17501/17812 with 0 missing, elapsed time: 119.060
# Imputing row 17801/17812 with 0 missing, elapsed time: 119.040
# Imputing row 17601/17812 with 0 missing, elapsed time: 119.062
# Imputing row 17701/17812 with 0 missing, elapsed time: 119.063
# Imputing row 17801/17812 with 0 missing, elapsed time: 119.066
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-18:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %%
X_filled1 = pd.concat(small_df_filled_ls, axis = 0)
'X_filled1 : {}'.format(X_filled1.shape)
# Out:
# 'X_filled1 : (356251, 14)'

# %%
#----------------------------
# reload base_features for filling
#----------------------------
df = pd.read_hdf('../features/base_featurs.h5','base_featurs')
copy_for_the_following_merge = df[['SK_ID_CURR','TARGET']].copy()
no_need_to_inpute = ['index']
df.drop(no_need_to_inpute, axis = 1, inplace = True)
for f_in_same_cluster in X_filled1.columns.tolist():
    if f_in_same_cluster in set(df.columns.tolist()):
        logging.info('featurs : {}'.format(f_in_same_cluster))
        df[f_in_same_cluster] = X_filled1[f_in_same_cluster].tolist()

if 'TARGET' in df.columns.tolist():
    df.drop(['TARGET'], axis = 1, inplace = True)
    
df = pd.merge(df, copy_for_the_following_merge, on = 'SK_ID_CURR', how = 'left')

# %%
df.shape
# Out:
# (356251, 280)

# %%
#-------------------
# save
#-------------------
output_path = '../features/filled_by_knn'
if not os.path.isdir(output_path):
    os.mkdir(output_path)

df.to_hdf(
    os.path.join(output_path, 'normalized_knn_65_cluster1.h5'), 'normalized_knn_65_cluster1')

# %%
# reload again for filling
df = pd.read_hdf('../features/base_featurs.h5','base_featurs')
print (df.shape)
copy_for_the_following_merge = df[['SK_ID_CURR','TARGET']].copy()
no_need_to_inpute = ['index']
df.drop(no_need_to_inpute, axis = 1, inplace = True)
# handling with infinity
df.replace([np.inf, -np.inf], np.nan, inplace = True)
# check the feature nullity
feature_clustering = pd.read_csv('../output/without_normalizing_feature_clustering.csv')
same_cluster_features = feature_clustering[feature_clustering.cluster == 2].features.tolist()
for f_in_same_cluster in same_cluster_features:
    if f_in_same_cluster in set(df.columns.tolist()):
        print (f_in_same_cluster)
        print (df[f_in_same_cluster].count())
base_feature_worth_imputing_ls = list(set(df.columns.tolist()) & set(same_cluster_features))
print ('num_base_feature_worth_imputing_set' , len(base_feature_worth_imputing_ls))
#------

#-----
X_missing_df = df[base_feature_worth_imputing_ls]
# feature scaling before KNN
feature_scaling = True
if feature_scaling == True:
    for f in X_missing_df.columns.tolist():
        mean = X_missing_df[f].mean()
        std = X_missing_df[f].std()
        X_missing_df[f] = (X_missing_df[f] - mean) / std
        
print ('X_missing_df', X_missing_df.shape)
small_df_ls = []
num_split = 20
previous_step = None
for i, step in enumerate(np.arange(0, X_missing_df.shape[0], step = int(X_missing_df.shape[0] / num_split))):
    # for memory problem, we cannot feed all the data points into algorithm, which depends on row and n_features
    if i == 0:
        pass
    elif i == 1:
        small_df_ls.append(X_missing_df[0: step])
        previous_step = step
    elif i == (num_split):
        small_df_ls.append(X_missing_df[previous_step: ])
        break
    else:
        small_df_ls.append(X_missing_df[previous_step: step])
        previous_step = step
        
print ('splitting is okay? {}'.format(pd.concat(small_df_ls, axis = 0).shape))

def multi(small_df):
    k = 65
    X_missing = small_df.copy()
    print ('input of KNN imputing : {}'.format(X_missing.shape))
    # core algorithm: input should be array
    X_filled = KNN(k = k).complete(X_missing.values)
    return pd.DataFrame(X_filled, columns = X_missing.columns)

mp_pool = mp.Pool(len(small_df_ls)) 
small_df_filled_ls = mp_pool.map(multi, small_df_ls)
X_filled1 = pd.concat(small_df_filled_ls, axis = 0)
print ('X_filled1 : {}'.format(X_filled1.shape))

#----------------------------
# reload base_features for filling
#----------------------------
df = pd.read_hdf('../features/base_featurs.h5','base_featurs')
copy_for_the_following_merge = df[['SK_ID_CURR','TARGET']].copy()
no_need_to_inpute = ['index']
df.drop(no_need_to_inpute, axis = 1, inplace = True)
for f_in_same_cluster in X_filled1.columns.tolist():
    if f_in_same_cluster in set(df.columns.tolist()):
        logging.info('featurs : {}'.format(f_in_same_cluster))
        df[f_in_same_cluster] = X_filled1[f_in_same_cluster].tolist()

if 'TARGET' in df.columns.tolist():
    df.drop(['TARGET'], axis = 1, inplace = True)
    
df = pd.merge(df, copy_for_the_following_merge, on = 'SK_ID_CURR', how = 'left')
print ('final', df.shape)
#-------------------
# save
#-------------------
output_path = '../features/filled_by_knn'
if not os.path.isdir(output_path):
    os.mkdir(output_path)

df.to_hdf(
    os.path.join(output_path, 'normalized_knn_65_cluster2.h5'), 'normalized_knn_65_cluster2')
# Out:
# (356251, 281)
# PREV_NAME_PAYMENT_TYPE_XNA_MEAN
# 338853
# PREV_NAME_TYPE_SUITE_nan_MEAN
# 338853
# PREV_NAME_CLIENT_TYPE_New_MEAN
# 338853
# PREV_NAME_YIELD_GROUP_XNA_MEAN
# 338853
# num_base_feature_worth_imputing_set 4
# X_missing_df (356251, 4)
# splitting is okay? (356251, 4)
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17812, 4)
# input of KNN imputing : (17823, 4)
# Imputing row 1/17812 with 0 missing, elapsed time: 60.731
# Imputing row 101/17812 with 4 missing, elapsed time: 60.734
# Imputing row 201/17812 with 0 missing, elapsed time: 60.737
# Imputing row 301/17812 with 0 missing, elapsed time: 60.739
# Imputing row 401/17812 with 0 missing, elapsed time: 60.741
# Imputing row 501/17812 with 0 missing, elapsed time: 60.743
# Imputing row 601/17812 with 0 missing, elapsed time: 60.745
# Imputing row 701/17812 with 0 missing, elapsed time: 60.747
# Imputing row 801/17812 with 0 missing, elapsed time: 60.749
# Imputing row 901/17812 with 0 missing, elapsed time: 60.751
# Imputing row 1001/17812 with 0 missing, elapsed time: 60.753
# Imputing row 1101/17812 with 0 missing, elapsed time: 60.755
# Imputing row 1201/17812 with 0 missing, elapsed time: 60.757
# Imputing row 1301/17812 with 0 missing, elapsed time: 60.760
# Imputing row 1401/17812 with 0 missing, elapsed time: 60.763
# Imputing row 1501/17812 with 0 missing, elapsed time: 60.765
# Imputing row 1601/17812 with 0 missing, elapsed time: 60.768
# Imputing row 1701/17812 with 0 missing, elapsed time: 60.770
# Imputing row 1801/17812 with 0 missing, elapsed time: 60.772
# Imputing row 1901/17812 with 0 missing, elapsed time: 60.774
# Imputing row 2001/17812 with 0 missing, elapsed time: 60.776
# Imputing row 2101/17812 with 0 missing, elapsed time: 60.779
# Imputing row 2201/17812 with 0 missing, elapsed time: 60.782
# Imputing row 2301/17812 with 4 missing, elapsed time: 60.785
# Imputing row 2401/17812 with 0 missing, elapsed time: 60.788
# Imputing row 2501/17812 with 0 missing, elapsed time: 60.791
# Imputing row 2601/17812 with 0 missing, elapsed time: 60.794
# Imputing row 2701/17812 with 0 missing, elapsed time: 60.795
# Imputing row 2801/17812 with 4 missing, elapsed time: 60.797
# Imputing row 2901/17812 with 0 missing, elapsed time: 60.799
# Imputing row 3001/17812 with 0 missing, elapsed time: 60.801
# Imputing row 3101/17812 with 0 missing, elapsed time: 60.803
# Imputing row 3201/17812 with 0 missing, elapsed time: 60.805
# Imputing row 3301/17812 with 0 missing, elapsed time: 60.806
# Imputing row 3401/17812 with 0 missing, elapsed time: 60.808
# Imputing row 3501/17812 with 0 missing, elapsed time: 60.810
# Imputing row 3601/17812 with 0 missing, elapsed time: 60.811
# Imputing row 3701/17812 with 0 missing, elapsed time: 60.813
# Imputing row 3801/17812 with 0 missing, elapsed time: 60.817
# Imputing row 3901/17812 with 0 missing, elapsed time: 60.819
# Imputing row 4001/17812 with 0 missing, elapsed time: 60.821
# Imputing row 4101/17812 with 4 missing, elapsed time: 60.823
# Imputing row 4201/17812 with 0 missing, elapsed time: 60.824
# Imputing row 4301/17812 with 0 missing, elapsed time: 60.827
# Imputing row 4401/17812 with 0 missing, elapsed time: 60.829
# Imputing row 4501/17812 with 0 missing, elapsed time: 60.830
# Imputing row 4601/17812 with 0 missing, elapsed time: 60.832
# Imputing row 4701/17812 with 0 missing, elapsed time: 60.834
# Imputing row 4801/17812 with 0 missing, elapsed time: 60.837
# Imputing row 4901/17812 with 0 missing, elapsed time: 60.839
# Imputing row 5001/17812 with 0 missing, elapsed time: 60.841
# Imputing row 5101/17812 with 0 missing, elapsed time: 60.843
# Imputing row 5201/17812 with 0 missing, elapsed time: 60.845
# Imputing row 5301/17812 with 0 missing, elapsed time: 60.847
# Imputing row 5401/17812 with 0 missing, elapsed time: 60.849
# Imputing row 5501/17812 with 0 missing, elapsed time: 60.851
# Imputing row 5601/17812 with 0 missing, elapsed time: 60.852
# Imputing row 5701/17812 with 0 missing, elapsed time: 60.854
# Imputing row 5801/17812 with 0 missing, elapsed time: 60.856
# Imputing row 5901/17812 with 0 missing, elapsed time: 60.857
# Imputing row 6001/17812 with 0 missing, elapsed time: 60.859
# Imputing row 6101/17812 with 0 missing, elapsed time: 60.861
# Imputing row 6201/17812 with 0 missing, elapsed time: 60.863
# Imputing row 6301/17812 with 0 missing, elapsed time: 60.864
# Imputing row 6401/17812 with 0 missing, elapsed time: 60.865
# Imputing row 6501/17812 with 0 missing, elapsed time: 60.867
# Imputing row 6601/17812 with 0 missing, elapsed time: 60.868
# Imputing row 6701/17812 with 0 missing, elapsed time: 60.869
# Imputing row 6801/17812 with 0 missing, elapsed time: 60.870
# Imputing row 6901/17812 with 0 missing, elapsed time: 60.871
# Imputing row 7001/17812 with 0 missing, elapsed time: 60.872
# Imputing row 7101/17812 with 4 missing, elapsed time: 60.874
# Imputing row 7201/17812 with 0 missing, elapsed time: 60.875
# Imputing row 7301/17812 with 0 missing, elapsed time: 60.876
# Imputing row 7401/17812 with 4 missing, elapsed time: 60.877
# Imputing row 7501/17812 with 0 missing, elapsed time: 60.878
# Imputing row 7601/17812 with 0 missing, elapsed time: 60.879
# Imputing row 7701/17812 with 0 missing, elapsed time: 60.880
# Imputing row 7801/17812 with 0 missing, elapsed time: 60.882
# Imputing row 7901/17812 with 0 missing, elapsed time: 60.883
# Imputing row 8001/17812 with 0 missing, elapsed time: 60.884
# Imputing row 8101/17812 with 0 missing, elapsed time: 60.892
# Imputing row 8201/17812 with 0 missing, elapsed time: 60.893
# Imputing row 8301/17812 with 0 missing, elapsed time: 60.895
# Imputing row 8401/17812 with 0 missing, elapsed time: 60.896
# Imputing row 8501/17812 with 0 missing, elapsed time: 60.897
# Imputing row 8601/17812 with 4 missing, elapsed time: 60.898
# Imputing row 8701/17812 with 0 missing, elapsed time: 60.899
# Imputing row 8801/17812 with 0 missing, elapsed time: 60.901
# Imputing row 8901/17812 with 0 missing, elapsed time: 60.902
# Imputing row 9001/17812 with 4 missing, elapsed time: 60.903
# Imputing row 9101/17812 with 0 missing, elapsed time: 60.904
# Imputing row 9201/17812 with 0 missing, elapsed time: 60.905
# Imputing row 9301/17812 with 0 missing, elapsed time: 60.906
# Imputing row 9401/17812 with 0 missing, elapsed time: 60.908
# Imputing row 9501/17812 with 0 missing, elapsed time: 60.909
# Imputing row 9601/17812 with 0 missing, elapsed time: 60.910
# Imputing row 9701/17812 with 0 missing, elapsed time: 60.911
# Imputing row 9801/17812 with 0 missing, elapsed time: 60.912
# Imputing row 9901/17812 with 0 missing, elapsed time: 60.914
# Imputing row 10001/17812 with 0 missing, elapsed time: 60.914
# Imputing row 10101/17812 with 0 missing, elapsed time: 60.916
# Imputing row 10201/17812 with 0 missing, elapsed time: 60.917
# Imputing row 10301/17812 with 0 missing, elapsed time: 60.918
# Imputing row 10401/17812 with 0 missing, elapsed time: 60.919
# Imputing row 10501/17812 with 0 missing, elapsed time: 60.920
# Imputing row 10601/17812 with 0 missing, elapsed time: 60.921
# Imputing row 10701/17812 with 0 missing, elapsed time: 60.922
# Imputing row 10801/17812 with 0 missing, elapsed time: 60.923
# Imputing row 10901/17812 with 0 missing, elapsed time: 60.924
# Imputing row 11001/17812 with 0 missing, elapsed time: 60.925
# Imputing row 11101/17812 with 0 missing, elapsed time: 60.926
# Imputing row 11201/17812 with 0 missing, elapsed time: 60.927
# Imputing row 11301/17812 with 0 missing, elapsed time: 60.929
# Imputing row 11401/17812 with 4 missing, elapsed time: 60.930
# Imputing row 11501/17812 with 0 missing, elapsed time: 60.931
# Imputing row 11601/17812 with 4 missing, elapsed time: 60.932
# Imputing row 11701/17812 with 0 missing, elapsed time: 60.933
# Imputing row 11801/17812 with 0 missing, elapsed time: 60.934
# Imputing row 11901/17812 with 0 missing, elapsed time: 60.935
# Imputing row 12001/17812 with 0 missing, elapsed time: 60.937
# Imputing row 12101/17812 with 0 missing, elapsed time: 60.938
# Imputing row 12201/17812 with 0 missing, elapsed time: 60.939
# Imputing row 12301/17812 with 0 missing, elapsed time: 60.941
# Imputing row 12401/17812 with 0 missing, elapsed time: 60.942
# Imputing row 12501/17812 with 0 missing, elapsed time: 60.943
# Imputing row 12601/17812 with 0 missing, elapsed time: 60.944
# Imputing row 12701/17812 with 0 missing, elapsed time: 60.945
# Imputing row 12801/17812 with 0 missing, elapsed time: 60.946
# Imputing row 12901/17812 with 0 missing, elapsed time: 60.947
# Imputing row 13001/17812 with 0 missing, elapsed time: 60.948
# Imputing row 13101/17812 with 0 missing, elapsed time: 60.949
# Imputing row 13201/17812 with 0 missing, elapsed time: 60.950
# Imputing row 13301/17812 with 0 missing, elapsed time: 60.952
# Imputing row 13401/17812 with 4 missing, elapsed time: 60.953
# Imputing row 13501/17812 with 0 missing, elapsed time: 60.954
# Imputing row 13601/17812 with 0 missing, elapsed time: 60.955
# Imputing row 13701/17812 with 0 missing, elapsed time: 60.956
# Imputing row 13801/17812 with 0 missing, elapsed time: 60.958
# Imputing row 13901/17812 with 4 missing, elapsed time: 60.959
# Imputing row 14001/17812 with 0 missing, elapsed time: 60.960
# Imputing row 14101/17812 with 0 missing, elapsed time: 60.961
# Imputing row 14201/17812 with 0 missing, elapsed time: 60.962
# Imputing row 14301/17812 with 0 missing, elapsed time: 60.964
# Imputing row 14401/17812 with 0 missing, elapsed time: 60.965
# Imputing row 14501/17812 with 0 missing, elapsed time: 60.966
# Imputing row 14601/17812 with 0 missing, elapsed time: 60.967
# Imputing row 14701/17812 with 0 missing, elapsed time: 60.968
# Imputing row 14801/17812 with 0 missing, elapsed time: 60.970
# Imputing row 14901/17812 with 0 missing, elapsed time: 60.972
# Imputing row 15001/17812 with 0 missing, elapsed time: 60.974
# Imputing row 15101/17812 with 0 missing, elapsed time: 60.975
# Imputing row 15201/17812 with 0 missing, elapsed time: 60.977
# Imputing row 15301/17812 with 0 missing, elapsed time: 60.978
# Imputing row 15401/17812 with 0 missing, elapsed time: 60.981
# Imputing row 15501/17812 with 0 missing, elapsed time: 60.983
# Imputing row 15601/17812 with 0 missing, elapsed time: 60.984
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-30:
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-25:
# Process ForkPoolWorker-40:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-35:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-31:
# Process ForkPoolWorker-37:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %%
import gc
gc.collect()
# Out:
# 409

# %%
# reload again for filling
df = pd.read_hdf('../features/base_featurs.h5','base_featurs')
print (df.shape)
copy_for_the_following_merge = df[['SK_ID_CURR','TARGET']].copy()
no_need_to_inpute = ['index']
df.drop(no_need_to_inpute, axis = 1, inplace = True)
# handling with infinity
df.replace([np.inf, -np.inf], np.nan, inplace = True)
# check the feature nullity
feature_clustering = pd.read_csv('../output/without_normalizing_feature_clustering.csv')
same_cluster_features = feature_clustering[feature_clustering.cluster == 3].features.tolist()
for f_in_same_cluster in same_cluster_features:
    if f_in_same_cluster in set(df.columns.tolist()):
        print (f_in_same_cluster)
        print (df[f_in_same_cluster].count())
base_feature_worth_imputing_ls = list(set(df.columns.tolist()) & set(same_cluster_features))
print ('num_base_feature_worth_imputing_set' , len(base_feature_worth_imputing_ls))
#------

#-----
X_missing_df = df[base_feature_worth_imputing_ls]
# feature scaling before KNN
feature_scaling = True
if feature_scaling == True:
    for f in X_missing_df.columns.tolist():
        mean = X_missing_df[f].mean()
        std = X_missing_df[f].std()
        X_missing_df[f] = (X_missing_df[f] - mean) / std
        
print ('X_missing_df', X_missing_df.shape)
small_df_ls = []
num_split = 20
previous_step = None
for i, step in enumerate(np.arange(0, X_missing_df.shape[0], step = int(X_missing_df.shape[0] / num_split))):
    # for memory problem, we cannot feed all the data points into algorithm, which depends on row and n_features
    if i == 0:
        pass
    elif i == 1:
        small_df_ls.append(X_missing_df[0: step])
        previous_step = step
    elif i == (num_split):
        small_df_ls.append(X_missing_df[previous_step: ])
        break
    else:
        small_df_ls.append(X_missing_df[previous_step: step])
        previous_step = step
        
print ('splitting is okay? {}'.format(pd.concat(small_df_ls, axis = 0).shape))

def multi(small_df):
    k = 65
    X_missing = small_df.copy()
    print ('input of KNN imputing : {}'.format(X_missing.shape))
    # core algorithm: input should be array
    X_filled = KNN(k = k).complete(X_missing.values)
    return pd.DataFrame(X_filled, columns = X_missing.columns)

mp_pool = mp.Pool(len(small_df_ls)) 
small_df_filled_ls = mp_pool.map(multi, small_df_ls)
X_filled1 = pd.concat(small_df_filled_ls, axis = 0)
print ('X_filled1 : {}'.format(X_filled1.shape))

#----------------------------
# reload base_features for filling
#----------------------------
df = pd.read_hdf('../features/base_featurs.h5','base_featurs')
copy_for_the_following_merge = df[['SK_ID_CURR','TARGET']].copy()
no_need_to_inpute = ['index']
df.drop(no_need_to_inpute, axis = 1, inplace = True)
for f_in_same_cluster in X_filled1.columns.tolist():
    if f_in_same_cluster in set(df.columns.tolist()):
        logging.info('featurs : {}'.format(f_in_same_cluster))
        df[f_in_same_cluster] = X_filled1[f_in_same_cluster].tolist()

if 'TARGET' in df.columns.tolist():
    df.drop(['TARGET'], axis = 1, inplace = True)
    
df = pd.merge(df, copy_for_the_following_merge, on = 'SK_ID_CURR', how = 'left')
print ('final', df.shape)
#-------------------
# save
#-------------------
output_path = '../features/filled_by_knn'
if not os.path.isdir(output_path):
    os.mkdir(output_path)

df.to_hdf(
    os.path.join(output_path, 'normalized_knn_65_cluster3.h5'), 'normalized_knn_65_cluster3')
# Out:
# (356251, 281)
# PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN
# 338853
# PREV_NAME_GOODS_CATEGORY_XNA_MEAN
# 338853
# PREV_CHANNEL_TYPE_Credit and cash offices_MEA
# Imputing row 3301/17812 with 0 missing, elapsed time: 58.577
# Imputing row 3401/17812 with 0 missing, elapsed time: 58.579
# Imputing row 3501/17812 with 0 missing, elapsed time: 58.580
# Imputing row 3601/17812 with 0 missing, elapsed time: 58.581
# Imputing row 3701/17812 with 0 missing, elapsed time: 58.582
# Imputing row 3801/17812 with 0 missing, elapsed time: 58.583
# Imputing row 3901/17812 with 0 missing, elapsed time: 58.585
# ...
# Imputing row 17401/17812 with 3 missing, elapsed time: 73.849
# Imputing row 17501/17812 with 0 missing, elapsed time: 73.850
# Imputing row 17601/17812 with 0 missing, elapsed time: 73.852
# Imputing row 17701/17812 with 0 missing, elapsed time: 73.854
# Imputing row 17801/17812 with 0 missing, elapsed time: 73.855
# [KNN] Warning: 2868/53436 still missing after imputation, replacing with 0
# X_filled1 : (356251, 3)
# final (356251, 280)
# Process ForkPoolWorker-60:
# Process ForkPoolWorker-47:
# Process ForkPoolWorker-42:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-58:
# Process ForkPoolWorker-41:
# Process ForkPoolWorker-55:
# Process ForkPoolWorker-54:
# Process ForkPoolWorker-59:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-50:
# Process ForkPoolWorker-56:
# Process ForkPoolWorker-46:
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-43:
# Process ForkPoolWorker-48:
# Process ForkPoolWorker-53:
# Process ForkPoolWorker-51:
# Process ForkPoolWorker-45:
# Process ForkPoolWorker-57:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt

# %%
# reload again for filling
df = pd.read_hdf('../features/base_featurs.h5','base_featurs')
print (df.shape)
copy_for_the_following_merge = df[['SK_ID_CURR','TARGET']].copy()
no_need_to_inpute = ['index']
df.drop(no_need_to_inpute, axis = 1, inplace = True)
# handling with infinity
df.replace([np.inf, -np.inf], np.nan, inplace = True)
# check the feature nullity
feature_clustering = pd.read_csv('../output/without_normalizing_feature_clustering.csv')
for i in range(3):
    print ('cluster : {}'.format(i+1))
    same_cluster_features = feature_clustering[feature_clustering.cluster == i+1].features.tolist()
    for f_in_same_cluster in same_cluster_features:
        if f_in_same_cluster in set(df.columns.tolist()):
            print (f_in_same_cluster)
            print (df[f_in_same_cluster].count())
    base_feature_worth_imputing_ls = list(set(df.columns.tolist()) & set(same_cluster_features))
    print ('num_base_feature_worth_imputing_set' , len(base_feature_worth_imputing_ls))
    #------

    #-----
    X_missing_df = df[base_feature_worth_imputing_ls]
    # feature scaling before KNN
    feature_scaling = True
    if feature_scaling == True:
        for f in X_missing_df.columns.tolist():
            mean = X_missing_df[f].mean()
            std = X_missing_df[f].std()
            X_missing_df[f] = (X_missing_df[f] - mean) / std

    print ('X_missing_df', X_missing_df.shape)
    small_df_ls = []
    num_split = 20
    previous_step = None
    for i, step in enumerate(np.arange(0, X_missing_df.shape[0], step = int(X_missing_df.shape[0] / num_split))):
        # for memory problem, we cannot feed all the data points into algorithm, which depends on row and n_features
        if i == 0:
            pass
        elif i == 1:
            small_df_ls.append(X_missing_df[0: step])
            previous_step = step
        elif i == (num_split):
            small_df_ls.append(X_missing_df[previous_step: ])
            break
        else:
            small_df_ls.append(X_missing_df[previous_step: step])
            previous_step = step

    print ('splitting is okay? {}'.format(pd.concat(small_df_ls, axis = 0).shape))

    def multi(small_df):
        k = 65
        X_missing = small_df.copy()
        print ('input of KNN imputing : {}'.format(X_missing.shape))
        # core algorithm: input should be array
        X_filled = KNN(k = k).complete(X_missing.values)
        return pd.DataFrame(X_filled, columns = X_missing.columns)

    mp_pool = mp.Pool(len(small_df_ls)) 
    small_df_filled_ls = mp_pool.map(multi, small_df_ls)
    X_filled1 = pd.concat(small_df_filled_ls, axis = 0)
    print ('X_filled1 : {}'.format(X_filled1.shape))

    for f_in_same_cluster in X_filled1.columns.tolist():
        if f_in_same_cluster in set(df.columns.tolist()):
            logging.info('featurs : {}'.format(f_in_same_cluster))
            df[f_in_same_cluster] = X_filled1[f_in_same_cluster].tolist()


if 'TARGET' in df.columns.tolist():
    df.drop(['TARGET'], axis = 1, inplace = True)

df = pd.merge(df, copy_for_the_following_merge, on = 'SK_ID_CURR', how = 'left')
print ('final', df.shape)
#-------------------
# save
#-------------------
output_path = '../features/filled_by_knn'
if not os.path.isdir(output_path):
    os.mkdir(output_path)

df.to_hdf(
    os.path.join(output_path, 'normalized_knn_65_cluster_1_2_3.h5'), 'normalized_knn_65_cluster_1_2_3')
# Out:
# (356251, 281)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/internals.py in replace(self, to_replace, value, inplace, filter, regex, convert, mgr)
#     795             values, _, to_replace, _ = self._try_coerce_args(self.values,
# --> 796                                                              to_replace)
#     797             mask = missing.mask_missing(values, to_replace)
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/internals.py in _try_coerce_args(self, values, other)
#     741                 type(other).__name__,
# --> 742                 type(self).__name__.lower().replace('Block', '')))
#     743
#
# TypeError: cannot convert list to an intblock
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-c09086b804c9> in <module>()
#       6 df.drop(no_need_to_inpute, axis = 1, inplace = True)
#       7 # handling with infinity
# ----> 8 df.replace([np.inf, -np.inf], np.nan, inplace = True)
#       9 # check the feature nullity
#      10 feature_clustering = pd.read_csv('../output/without_normalizing_feature_clustering.csv')
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    3796                                               value=value, inplace=inplace,
#    3797                                               limit=limit, regex=regex,
# -> 3798                                               method=method)
#    3799
#    3800     @Appender(_shared_docs['shift'] % _shared_doc_kwargs)
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    5854                     new_data = self._data.replace(to_replace=to_replace,
#    5855                                                   value=value, inplace=inplace,
# -> 5856                                                   regex=regex)
#    5857             elif to_replace is None:
#    5858                 if not (is_re_compilable(regex) or
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/internals.py in replace(self, **kwargs)
#    3718
#    3719     def replace(self, **kwargs):
# -> 3720         return self.apply('replace', **kwargs)
#    3721
#    3722     def replace_list(self, src_list, dest_list, inplace=False, regex=False,
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3579
#    3580             kwargs['mgr'] = self
# -> 3581             applied = getattr(b, f)(**kwargs)
#    3582             result_blocks = _extend_blocks(applied, result_blocks)
#    3583
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/internals.py in replace(self, to_replace, value, inplace, filter, regex, convert, mgr)
#     811             return block.replace(
#     812                 to_replace=original_to_replace, value=value, inplace=inplace,
# --> 813                 filter=filter, regex=regex, convert=convert)
#     814
#     815     def _replace_single(self, *args, **kwargs):
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/internals.py in replace(self, to_replace, value, inplace, filter, regex, convert, mgr)
#    2463         return self._replace_single(to_replace, value, inplace=inplace,
#    2464                                     filter=filter, convert=convert,
# -> 2465                                     regex=regex, mgr=mgr)
#    2466
#    2467     def _replace_single(self, to_replace, value, inplace=False, filter=None,
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/internals.py in _replace_single(self, to_replace, value, inplace, filter, regex, convert, mgr)
#    2504                                                     inplace=inplace,
#    2505                                                     filter=filter, regex=regex,
# -> 2506                                                     mgr=mgr)
#    2507
#    2508         new_values = self.values if inplace else self.values.copy()
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/internals.py in replace(self, to_replace, value, inplace, filter, regex, convert, mgr)
#     795             values, _, to_replace, _ = self._try_coerce_args(self.values,
#     796                                                              to_replace)
# --> 797             mask = missing.mask_missing(values, to_replace)
#     798             if filter is not None:
#     799                 filtered_out = ~self.mgr_locs.isin(filter)
#
# /home/linuxbrew/.linuxbrew/opt/python/lib/python3.6/site-packages/pandas/core/missing.py in mask_missing(arr, values_to_mask)
#      49                 mask = False
#      50             else:
# ---> 51                 mask = arr == x
#      52
#      53             # if x is a string and arr is not, then we get False and we must
#
# KeyboardInterrupt:
