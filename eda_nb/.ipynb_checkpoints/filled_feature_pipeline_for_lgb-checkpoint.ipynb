# %%
from ycimpute.imputer.knnimput import KNN # inputation library
import pandas as pd
import numpy as np

# %%
filled_feature_w_target = pd.read_hdf('../features/base_featurs_filled_knn_5_w_target.h5')
filled_feature_wo_target = pd.read_hdf('../features/base_featurs_filled_knn_5_w_target.h5')

# %%
filled_feature
# Out:
#     AMT_ANNUITY  AMT_CREDIT  AMT_GOODS_PRICE  AMT_REQ_CREDIT_BUREAU_QRT  \
# 0   26419.50000    599778.0         477000.0                   0.000000
# 1   20826.00000    175500.0         175500.0                   1.000000
# 2   24376.50000    675000.0         675000.0                   0.000000
# 3   12928.50000    180000.0         180000.0                   1.000000
# 4    7326.00000    135000.0         135000.0                   0.000000
# 0   19512.00000    539590.5         445500.0                   1.000000
# 1   38938.50000    485640.0         450000.0                   0.000000
# 2   13500.00000    270000.0         270000.0                   0.000000
# 3   23796.00000    720000.0         720000.0                   0.000000
# 4   48429.00000    719860.5         679500.0                   0.000000
# 0   33750.00000    675000.0         675000.0                   0.000000
# 1   12577.50000    225000.0         225000.0                   0.000000
# ...

# %%
for k in np.arange(5,25, step = 5):
    print (k)
# Out:
# 5
# 10
# 15
# 20
