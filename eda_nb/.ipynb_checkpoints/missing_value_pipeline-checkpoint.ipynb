# %%
import os
import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold, StratifiedKFold
import multiprocessing
import warnings
import sys
sys.path.append('../py_model/')
from utils import init_logging
import logging 

warnings.simplefilter(action='ignore', category=FutureWarning)
np.random.seed(int(time.time()))

CPU_USE_RATE = 0.5
NUM_FOLDS = 5
STRATIFIED = True  
TEST_NULL_HYPO = False
ITERATION = (80 if TEST_NULL_HYPO else 10) # It means how many iterations need to get the final stable AUC score.

# %%
@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))

def kfold_lightgbm(df, num_folds, stratified = False):
    '''
    num_folds: int, how many foles u'r going to split.

    Maybe we can write a helper function, to find a best parametres each time when u add a new features, to make sure reliability of experiment.
    But, the experiement time will go up more.
    '''
    #---------------------
    # Divide in training/validation and test data
    #---------------------
    train_df = df[df['TARGET'].notnull()]
    test_df = df[df['TARGET'].isnull()]
    # test_id 如果是隨機的, 會有引響麼, 理論上只要sort就好, 就算有
    logging.info('no bugging in split' if train_df.shape[0] + test_df.shape[0] == df.shape[0] else " opps")
    #---------------------
    # core
    #---------------------
    logging.info("Starting LightGBM. Train shape: {}, test shape: {}".format(train_df.shape, test_df.shape))
    del df
    gc.collect()
    # Cross validation model
    if stratified:
        folds = StratifiedKFold(n_splits= num_folds, shuffle=True, random_state=int(time.time()))
    else:
        folds = KFold(n_splits= num_folds, shuffle=True, random_state=int(time.time()))
    # Create arrays and dataframes to store results
    # train
    oof_preds = np.zeros(train_df.shape[0])
    train_preds = np.zeros(train_df.shape[0])
    # test
    sub_preds = np.zeros(test_df.shape[0])
    # feature importance
    feature_importance_df = pd.DataFrame()

    feats = [f for f in train_df.columns if f not in ['TARGET','SK_ID_CURR','SK_ID_BUREAU','SK_ID_PREV','index']]
    
    if TEST_NULL_HYPO:
        train_df['TARGET'] = train_df['TARGET'].copy().sample(frac = 1.0).values
    for n_fold, (train_idx, valid_idx) in enumerate(folds.split(train_df[feats], train_df['TARGET'])):
        train_x, train_y = train_df[feats].iloc[train_idx], train_df['TARGET'].iloc[train_idx]
        valid_x, valid_y = train_df[feats].iloc[valid_idx], train_df['TARGET'].iloc[valid_idx]

        # LightGBM parameters found by Bayesian optimization
        if TEST_NULL_HYPO:
            clf = LGBMClassifier(
                nthread=int(multiprocessing.cpu_count()*CPU_USE_RATE),
                n_estimators=10000,
                learning_rate=0.02,
                num_leaves=127,
                max_depth=8,
                silent=-1,
                verbose=-1,
                random_state=int(time.time()),
                )
        else:
            clf = LGBMClassifier(
                nthread=int(multiprocessing.cpu_count()*CPU_USE_RATE),
                n_estimators=10000,
                learning_rate=0.02,
                num_leaves=34, # 20
                colsample_bytree=0.2, #0.9497036 < 0.2
                subsample=0.8715623,
                max_depth=8, # 7
                reg_alpha=0.041545473, # 0.3
                reg_lambda=0.0735294,
                min_split_gain=0.0222415,
                min_child_weight=39.3259775, # 60
                silent=-1,
                verbose=-1,
                random_state=int(time.time()),
                )

        clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], 
            eval_metric= 'auc', verbose= False, early_stopping_rounds= 100) # early_stopping_rounds= 200
        # training/validating
        oof_preds[valid_idx] = clf.predict_proba(valid_x, num_iteration=clf.best_iteration_)[:, 1]
        train_preds[train_idx] += clf.predict_proba(train_x, num_iteration=clf.best_iteration_)[:, 1] / folds.n_splits
        # testing
        sub_preds += clf.predict_proba(test_df[feats], num_iteration=clf.best_iteration_)[:, 1] / folds.n_splits

        fold_importance_df = pd.DataFrame()
        fold_importance_df["feature"] = feats
        fold_importance_df["importance"] = clf.feature_importances_
        fold_importance_df["fold"] = n_fold + 1
        feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)

        logging.info('Fold %2d val AUC : %.6f' % (n_fold + 1, roc_auc_score(valid_y, oof_preds[valid_idx])))

        del clf, train_x, train_y, valid_x, valid_y
        gc.collect()
    logging.info('Over-folds train AUC score : {}'.format(roc_auc_score(train_df['TARGET'], train_preds)))
    
    over_folds_val_auc = roc_auc_score(train_df['TARGET'], oof_preds)
    logging.info('Over-folds val AUC score : {}'.format(over_folds_val_auc))
    
    # # Write submission file and plot feature importance
    # test_df.loc[:,'TARGET'] = sub_preds
    # test_df[['SK_ID_CURR', 'TARGET']].to_csv(submission_file_name, index= False)

    return feature_importance_df, over_folds_val_auc

def main():
    #--------------------
    # load features
    #--------------------
    input_dir = "../features/filled_by_knn/"
    for f_p in os.listdir(input_dir):
        df = pd.read_hdf(os.path.join(input_dir, f_p))
        logging.info('loading features: {}'.format(f_p))
        #--------------------
        # out-of-fold validating stratigy + LGB
        #--------------------    
        with timer("Run LightGBM with kfold"):
            feature_importance_df = pd.DataFrame()
            over_folds_val_auc_list = np.zeros(ITERATION)
            for i in range(ITERATION):
                logging.info('Iteration %i' %i)
                iter_feat_imp, over_folds_val_auc = kfold_lightgbm(df, num_folds= NUM_FOLDS, stratified= STRATIFIED)
                feature_importance_df = pd.concat([feature_importance_df, iter_feat_imp], axis=0)
                over_folds_val_auc_list[i] = over_folds_val_auc

            logging.info('Over-iterations val AUC score : {}'.format(over_folds_val_auc_list.mean()))
            logging.info('Standard deviation : {}'.format(over_folds_val_auc_list.std()))

            # display_importances(feature_importance_df)
            feature_importance_df_median = feature_importance_df[["feature", "importance"]].groupby("feature").median().sort_values(by="importance", ascending=False)
            useless_features_df = feature_importance_df_median.loc[feature_importance_df_median['importance'] == 0]
            feature_importance_df_mean = feature_importance_df[["feature", "importance"]].groupby("feature").mean().sort_values(by="importance", ascending=False)
            #---------------------
            # save
            #---------------------
            output_path = '../output'
            if not os.path.isdir(output_path):
                os.mkdir(output_path)

            if TEST_NULL_HYPO:
                feature_importance_df_mean.to_csv(os.path.join(output_path, 'feature_importance-null_hypo.csv'), index = True)
            else:
                feature_importance_df_mean.to_csv(os.path.join(output_path, 'feature_importance.csv'), index = True)
                useless_features_list = useless_features_df.index.tolist()
                logging.info('useless/overfitting features: \'' + '\', \''.join(useless_features_list) + '\'')

# %%
with timer("Lightgbm run a score"):
    main()
# Out:
# loading features: base_featurs_filled_knn_10_w_target.h5
# Iteration 0
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.740681
# Fold  2 val AUC : 0.749132
# Fold  3 val AUC : 0.744320
# Fold  4 val AUC : 0.730504
# Fold  5 val AUC : 0.745857
# Over-folds train AUC score : 0.7643825539076633
# Over-folds val AUC score : 0.7402420698934183
# Iteration 1
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.738166
# Fold  2 val AUC : 0.742753
# Fold  3 val AUC : 0.741713
# Fold  4 val AUC : 0.733229
# Fold  5 val AUC : 0.746878
# Over-folds train AUC score : 0.7607863036814546
# Over-folds val AUC score : 0.7404326337168636
# Iteration 2
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.737450
# Fold  2 val AUC : 0.749093
# Fold  3 val AUC : 0.747489
# Fold  4 val AUC : 0.737776
# Fold  5 val AUC : 0.742487
# Over-folds train AUC score : 0.7624675992145526
# Over-folds val AUC score : 0.7415333909272563
# Iteration 3
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.740922
# Fold  2 val AUC : 0.740187
# Fold  3 val AUC : 0.744508
# Fold  4 val AUC : 0.747434
# Fold  5 val AUC : 0.743427
# Over-folds train AUC score : 0.760613212831405
# Over-folds val AUC score : 0.7425099031102692
# Iteration 4
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.747414
# Fold  2 val AUC : 0.739180
# Fold  3 val AUC : 0.738721
# Fold  4 val AUC : 0.742717
# Fold  5 val AUC : 0.726055
# Over-folds train AUC score : 0.7618755271448144
# Over-folds val AUC score : 0.7385195629351263
# Iteration 5
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.742237
# Fold  2 val AUC : 0.747533
# Fold  3 val AUC : 0.737407
# Fold  4 val AUC : 0.742457
# Fold  5 val AUC : 0.747774
# Over-folds train AUC score : 0.7638421200759553
# Over-folds val AUC score : 0.7433776119124473
# Iteration 6
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.731111
# Fold  2 val AUC : 0.736154
# Fold  3 val AUC : 0.755086
# Fold  4 val AUC : 0.742980
# Fold  5 val AUC : 0.749068
# Over-folds train AUC score : 0.7620845955649972
# Over-folds val AUC score : 0.7426500958702911
# Iteration 7
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.737372
# Fold  2 val AUC : 0.750604
# Fold  3 val AUC : 0.745736
# Fold  4 val AUC : 0.744107
# Fold  5 val AUC : 0.745057
# Over-folds train AUC score : 0.7627294592617186
# Over-folds val AUC score : 0.7440612632645698
# Iteration 8
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.740609
# Fold  2 val AUC : 0.734559
# Fold  3 val AUC : 0.735692
# Fold  4 val AUC : 0.746077
# Fold  5 val AUC : 0.746188
# Over-folds train AUC score : 0.7622523127682188
# Over-folds val AUC score : 0.7399978144177082
# Iteration 9
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.748910
# Fold  2 val AUC : 0.749104
# Fold  3 val AUC : 0.738766
# Fold  4 val AUC : 0.747074
# Fold  5 val AUC : 0.747568
# Over-folds train AUC score : 0.7625326813308516
# Over-folds val AUC score : 0.7459275976400784
# Over-iterations val AUC score : 0.741925194368803
# Standard deviation : 0.002099670918686173
# useless/overfitting features: 'NAME_EDUCATION_TYPE_Lower secondary', 'PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN', 'PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN', 'NAME_EDUCATION_TYPE_Secondary / secondary special', 'PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN', 'NAME_FAMILY_STATUS_Single / not married', 'PREV_NAME_YIELD_GROUP_low_action_MEAN', 'PREV_RATE_DOWN_PAYMENT_MEAN', 'NAME_FAMILY_STATUS_Married', 'WEEKDAY_APPR_PROCESS_START_WEDNESDAY', 'REFUSED_APP_CREDIT_PERC_MIN', 'WEEKDAY_APPR_PROCESS_START_TUESDAY', 'WEEKDAY_APPR_PROCESS_START_SUNDAY', 'YEARS_BEGINEXPLUATATION_MEDI', 'WALLSMATERIAL_MODE_Stone, brick', 'NEW_RATIO_BURO_AMT_CREDIT_SUM_LIMIT_MEAN', 'NAME_HOUSING_TYPE_House / apartment', 'REFUSED_TIME_DECAYED_HUMAN_EVAL_SUM', 'NAME_HOUSING_TYPE_Municipal apartment', 'NEW_DOC_IND_STD', 'REGION_POPULATION_RELATIVE', 'PREV_NAME_YIELD_GROUP_high_MEAN', 'NAME_TYPE_SUITE_Other_B', 'WEEKDAY_APPR_PROCESS_START_MONDAY', 'REG_CITY_NOT_LIVE_CITY', 'SOCIAL_PRED', 'NAME_INCOME_TYPE_State servant', 'NAME_HOUSING_TYPE_Office apartment', 'WALLSMATERIAL_MODE_Others', 'WALLSMATERIAL_MODE_Panel', 'REFUSED_HUMAN_EVAL_SUM', 'PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN', 'PREV_NAME_TYPE_SUITE_nan_MEAN', 'PREV_NAME_CLIENT_TYPE_Refreshed_MEAN', 'ORGANIZATION_TYPE_Security Ministries', 'ORGANIZATION_TYPE_Self-employed', 'ORGANIZATION_TYPE_Transport: type 3', 'OWN_CAR_AGE', 'OWN_CAR_AGE_BY_NAME_EDUCATION_TYPE_OCCUPATION_TYPE', 'POS_MONTHS_BALANCE_MAX', 'POS_NAME_CONTRACT_STATUS_Active_MEAN', 'NAME_CONTRACT_TYPE_Revolving loans', 'POS_TIME_DECAYED_UNPAYED_RATIO_MAX', 'ORGANIZATION_TYPE_School', 'PREV_NAME_CLIENT_TYPE_New_MEAN', 'PREV_HUMAN_EVAL_SUM', 'POS_TIME_DECAYED_UNPAYED_RATIO_MEAN', 'PREV_CODE_REJECT_REASON_SCO_MEAN', 'PREV_CODE_REJECT_REASON_CLIENT_MEAN', 'POS_TIME_DECAYED_UNPAYED_RATIO_SUM', 'PREV_AMT_ANNUITY_MEAN', 'PREV_CHANNEL_TYPE_Credit and cash offices_MEAN', 'PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN', 'ORGANIZATION_TYPE_Restaurant', 'OBS_60_CNT_SOCIAL_CIRCLE', 'OCCUPATION_TYPE_Sales staff', 'OCCUPATION_TYPE_Accountants', 'OCCUPATION_TYPE_Core staff', 'OCCUPATION_TYPE_Drivers', 'OCCUPATION_TYPE_High skill tech staff', 'OCCUPATION_TYPE_Laborers', 'OCCUPATION_TYPE_Low-skill Laborers', 'PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN', 'OCCUPATION_TYPE_Medicine staff', 'ORGANIZATION_TYPE_Bank', 'ORGANIZATION_TYPE_Police', 'ORGANIZATION_TYPE_Business Entity Type 3', 'ORGANIZATION_TYPE_Construction', 'ORGANIZATION_TYPE_Hotel', 'ORGANIZATION_TYPE_Industry: type 9', 'ORGANIZATION_TYPE_Kindergarten', 'PREV_NAME_PORTFOLIO_Cards_MEAN', 'ORGANIZATION_TYPE_Medicine', 'ORGANIZATION_TYPE_Military', 'PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN', 'ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN', 'NAME_CONTRACT_TYPE_Cash loans', 'CC_AMT_PAYMENT_CURRENT_SUM', 'BURO_AMT_CREDIT_SUM_OVERDUE_MEAN', 'BURO_AMT_CREDIT_SUM_SUM', 'BURO_CREDIT_TYPE_Car loan_MEAN', 'BURO_CREDIT_TYPE_Credit card_MEAN', 'BURO_CREDIT_TYPE_Microloan_MEAN', 'BURO_CREDIT_TYPE_Mortgage_MEAN', 'BURO_DAYS_CREDIT_ENDDATE_MAX', 'CC_AMT_BALANCE_MAX', 'CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN', 'CC_AMT_DRAWINGS_ATM_CURRENT_MEAN', 'CC_AMT_INST_MIN_REGULARITY_VAR', 'CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN', 'BURO_AMT_CREDIT_SUM_MAX', 'CC_AMT_PAYMENT_TOTAL_CURRENT_SUM', 'CC_AMT_RECEIVABLE_PRINCIPAL_MAX', 'CC_AMT_RECEIVABLE_PRINCIPAL_MEAN', 'CC_AMT_RECIVABLE_MAX', 'CC_AMT_RECIVABLE_SUM', 'CC_AMT_RECIVABLE_VAR', 'CC_AMT_TOTAL_RECEIVABLE_MAX', 'CC_AMT_TOTAL_RECEIVABLE_MEAN', 'CC_AMT_TOTAL_RECEIVABLE_MIN', 'CC_AMT_TOTAL_RECEIVABLE_SUM', 'CC_AMT_TOTAL_RECEIVABLE_VAR', 'BURO_AMT_CREDIT_SUM_MEAN', 'BURO_AMT_CREDIT_SUM_LIMIT_MEAN', 'CC_CNT_DRAWINGS_CURRENT_VAR', 'AMT_ANNUITY_BY_OCCUPATION_TYPE', 'ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN', 'ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN', 'ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM', 'ACTIVE_AMT_CREDIT_SUM_MAX', 'ACTIVE_AMT_CREDIT_SUM_MEAN', 'ACTIVE_AMT_CREDIT_SUM_SUM', 'ACTIVE_DAYS_CREDIT_ENDDATE_MAX', 'ACTIVE_DAYS_CREDIT_ENDDATE_MEAN', 'ACTIVE_DAYS_CREDIT_ENDDATE_MIN', 'AMT_ANNUITY_BY_CODE_GENDE ...
# Run LightGBM with kfold - done in 367s
# loading features: base_featurs_filled_knn_5_wo_target.h5
# Iteration 0
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.740996
# Fold  2 val AUC : 0.731331
# Fold  3 val AUC : 0.743621
# Fold  4 val AUC : 0.736635
# Fold  5 val AUC : 0.736548
# Over-folds train AUC score : 0.7600130107517895
# Over-folds val AUC score : 0.7375065877582754
# Iteration 1
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.740080
# Fold  2 val AUC : 0.740224
# Fold  3 val AUC : 0.744751
# Fold  4 val AUC : 0.752092
# Fold  5 val AUC : 0.744479
# Over-folds train AUC score : 0.7613412717957149
# Over-folds val AUC score : 0.7430780719990728
# Iteration 2
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.749928
# Fold  2 val AUC : 0.730736
# Fold  3 val AUC : 0.736194
# Fold  4 val AUC : 0.744315
# Fold  5 val AUC : 0.744674
# Over-folds train AUC score : 0.7616927680054522
# Over-folds val AUC score : 0.7399879640855999
# Iteration 3
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.724361
# Fold  2 val AUC : 0.746553
# Fold  3 val AUC : 0.746089
# Fold  4 val AUC : 0.742989
# Fold  5 val AUC : 0.737122
# Over-folds train AUC score : 0.7605943494215488
# Over-folds val AUC score : 0.7394306842059591
# Iteration 4
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.741433
# Fold  2 val AUC : 0.743739
# Fold  3 val AUC : 0.741055
# Fold  4 val AUC : 0.741479
# Fold  5 val AUC : 0.751494
# Over-folds train AUC score : 0.762161373734978
# Over-folds val AUC score : 0.7434352502240213
# Iteration 5
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.739824
# Fold  2 val AUC : 0.741199
# Fold  3 val AUC : 0.739848
# Fold  4 val AUC : 0.752229
# Fold  5 val AUC : 0.742159
# Over-folds train AUC score : 0.7599694075478848
# Over-folds val AUC score : 0.7424835896257208
# Iteration 6
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.738982
# Fold  2 val AUC : 0.748071
# Fold  3 val AUC : 0.741060
# Fold  4 val AUC : 0.752024
# Fold  5 val AUC : 0.743044
# Over-folds train AUC score : 0.7618651891802626
# Over-folds val AUC score : 0.7435530627638745
# Iteration 7
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.747821
# Fold  2 val AUC : 0.735943
# Fold  3 val AUC : 0.746598
# Fold  4 val AUC : 0.741924
# Fold  5 val AUC : 0.731758
# Over-folds train AUC score : 0.7634352001355339
# Over-folds val AUC score : 0.7407374379088896
# Iteration 8
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.743868
# Fold  2 val AUC : 0.743598
# Fold  3 val AUC : 0.699402
# Fold  4 val AUC : 0.743716
# Fold  5 val AUC : 0.740431
# Over-folds train AUC score : 0.76211856845564
# Over-folds val AUC score : 0.73155544981161
# Iteration 9
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.746676
# Fold  2 val AUC : 0.738050
# Fold  3 val AUC : 0.745796
# Fold  4 val AUC : 0.749590
# Fold  5 val AUC : 0.741028
# Over-folds train AUC score : 0.7630613948840046
# Over-folds val AUC score : 0.7438417651103162
# Over-iterations val AUC score : 0.7405609863493339
# Standard deviation : 0.003606600318652637
# useless/overfitting features: 'NEW_DOC_IND_STD', 'REFUSED_TIME_DECAYED_HUMAN_EVAL_SUM', 'PREV_NAME_YIELD_GROUP_low_action_MEAN', 'PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN', 'NEW_RATIO_BURO_AMT_CREDIT_SUM_LIMIT_MEAN', 'REFUSED_HUMAN_EVAL_SUM', 'REFUSED_APP_CREDIT_PERC_MIN', 'PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN', 'REGION_POPULATION_RELATIVE', 'PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN', 'PREV_RATE_DOWN_PAYMENT_MEAN', 'PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN', 'NAME_TYPE_SUITE_Other_B', 'NAME_INCOME_TYPE_State servant', 'YEARS_BEGINEXPLUATATION_MEDI', 'NAME_CONTRACT_TYPE_Cash loans', 'WEEKDAY_APPR_PROCESS_START_WEDNESDAY', 'WEEKDAY_APPR_PROCESS_START_TUESDAY', 'WEEKDAY_APPR_PROCESS_START_SUNDAY', 'NAME_CONTRACT_TYPE_Revolving loans', 'WEEKDAY_APPR_PROCESS_START_MONDAY', 'NAME_EDUCATION_TYPE_Lower secondary', 'WALLSMATERIAL_MODE_Stone, brick', 'WALLSMATERIAL_MODE_Panel', 'WALLSMATERIAL_MODE_Others', 'SOCIAL_PRED', 'NAME_EDUCATION_TYPE_Secondary / secondary special', 'NAME_FAMILY_STATUS_Married', 'NAME_FAMILY_STATUS_Single / not married', 'NAME_HOUSING_TYPE_House / apartment', 'NAME_HOUSING_TYPE_Municipal apartment', 'REG_CITY_NOT_LIVE_CITY', 'PREV_NAME_YIELD_GROUP_high_MEAN', 'NAME_HOUSING_TYPE_Office apartment', 'OBS_60_CNT_SOCIAL_CIRCLE', 'PREV_NAME_TYPE_SUITE_nan_MEAN', 'PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN', 'ORGANIZATION_TYPE_School', 'ORGANIZATION_TYPE_Security Ministries', 'ORGANIZATION_TYPE_Self-employed', 'ORGANIZATION_TYPE_Transport: type 3', 'OWN_CAR_AGE', 'OWN_CAR_AGE_BY_NAME_EDUCATION_TYPE_OCCUPATION_TYPE', 'PREV_NAME_GOODS_CATEGORY_XNA_MEAN', 'POS_MONTHS_BALANCE_MAX', 'POS_NAME_CONTRACT_STATUS_Active_MEAN', 'PREV_NAME_PORTFOLIO_Cards_MEAN', 'LIVINGAREA_MEDI', 'POS_TIME_DECAYED_UNPAYED_RATIO_MAX', 'PREV_NAME_CLIENT_TYPE_Refreshed_MEAN', 'POS_TIME_DECAYED_UNPAYED_RATIO_MEAN', 'PREV_NAME_CLIENT_TYPE_New_MEAN', 'PREV_AMT_ANNUITY_MEAN', 'PREV_CODE_REJECT_REASON_SCO_MEAN', 'PREV_CODE_REJECT_REASON_CLIENT_MEAN', 'PREV_NAME_PAYMENT_TYPE_XNA_MEAN', 'ORGANIZATION_TYPE_Restaurant', 'PREV_CHANNEL_TYPE_Credit and cash offices_MEAN', 'PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN', 'OCCUPATION_TYPE_Accountants', 'OCCUPATION_TYPE_Core staff', 'OCCUPATION_TYPE_Drivers', 'OCCUPATION_TYPE_High skill tech staff', 'PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN', 'OCCUPATION_TYPE_Laborers', 'OCCUPATION_TYPE_Low-skill Laborers', 'OCCUPATION_TYPE_Medicine staff', 'OCCUPATION_TYPE_Sales staff', 'ORGANIZATION_TYPE_Police', 'ORGANIZATION_TYPE_Bank', 'ORGANIZATION_TYPE_Business Entity Type 3', 'ORGANIZATION_TYPE_Construction', 'ORGANIZATION_TYPE_Hotel', 'ORGANIZATION_TYPE_Industry: type 9', 'ORGANIZATION_TYPE_Kindergarten', 'ORGANIZATION_TYPE_Medicine', 'ORGANIZATION_TYPE_Military', 'POS_SK_DPD_DEF_MAX', 'ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN', 'LIVE_CITY_NOT_WORK_CITY', 'CC_CNT_DRAWINGS_CURRENT_MEAN', 'BURO_AMT_CREDIT_SUM_OVERDUE_MEAN', 'BURO_AMT_CREDIT_SUM_SUM', 'BURO_CREDIT_TYPE_Car loan_MEAN', 'BURO_CREDIT_TYPE_Credit card_MEAN', 'BURO_CREDIT_TYPE_Microloan_MEAN', 'BURO_CREDIT_TYPE_Mortgage_MEAN', 'BURO_DAYS_CREDIT_ENDDATE_MAX', 'CC_AMT_BALANCE_MAX', 'CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN', 'CC_AMT_DRAWINGS_ATM_CURRENT_MEAN', 'CC_AMT_INST_MIN_REGULARITY_VAR', 'CC_AMT_PAYMENT_CURRENT_SUM', 'CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN', 'CC_AMT_PAYMENT_TOTAL_CURRENT_SUM', 'CC_AMT_RECEIVABLE_PRINCIPAL_MAX', 'CC_AMT_RECEIVABLE_PRINCIPAL_MEAN', 'CC_AMT_RECIVABLE_MAX', 'CC_AMT_RECIVABLE_MEAN', 'CC_AMT_RECIVABLE_SUM', 'CC_AMT_RECIVABLE_VAR', 'CC_AMT_TOTAL_RECEIVABLE_MAX', 'CC_AMT_TOTAL_RECEIVABLE_MEAN', 'CC_AMT_TOTAL_RECEIVABLE_MIN', 'CC_AMT_TOTAL_RECEIVABLE_SUM', 'CC_AMT_TOTAL_RECEIVABLE_VAR', 'BURO_AMT_CREDIT_SUM_MEAN', 'BURO_AMT_CREDIT_SUM_MAX', 'BURO_AMT_CREDIT_SUM_LIMIT_MEAN', 'AMT_ANNUITY_BY_ORGANIZATION_TYPE_OCCUPATION_TYPE', 'ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN', 'ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN', 'ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM', 'ACTIVE_AMT_CREDIT_SUM_MAX', 'ACTIVE_AMT_CREDIT_SUM_MEAN', 'ACTIVE_AMT_CREDIT_SUM_SUM', 'ACTIV ...
# Run LightGBM with kfold - done in 366s
# loading features: base_featurs_filled_knn_5_w_target.h5
# Iteration 0
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.738218
# Fold  2 val AUC : 0.746455
# Fold  3 val AUC : 0.740304
# Fold  4 val AUC : 0.746535
# Fold  5 val AUC : 0.732652
# Over-folds train AUC score : 0.7621957927907818
# Over-folds val AUC score : 0.7389209342396372
# Iteration 1
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.742792
# Fold  2 val AUC : 0.730905
# Fold  3 val AUC : 0.731653
# Fold  4 val AUC : 0.742173
# Fold  5 val AUC : 0.709929
# Over-folds train AUC score : 0.7578021158901823
# Over-folds val AUC score : 0.7313890376165467
# Iteration 2
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.738399
# Fold  2 val AUC : 0.742145
# Fold  3 val AUC : 0.737875
# Fold  4 val AUC : 0.736545
# Fold  5 val AUC : 0.751529
# Over-folds train AUC score : 0.7603487409866818
# Over-folds val AUC score : 0.7408024296806621
# Iteration 3
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.725206
# Fold  2 val AUC : 0.746181
# Fold  3 val AUC : 0.740133
# Fold  4 val AUC : 0.733202
# Fold  5 val AUC : 0.749020
# Over-folds train AUC score : 0.7592234299437657
# Over-folds val AUC score : 0.7385109967350358
# Iteration 4
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.725074
# Fold  2 val AUC : 0.753442
# Fold  3 val AUC : 0.730371
# Fold  4 val AUC : 0.743567
# Fold  5 val AUC : 0.751670
# Over-folds train AUC score : 0.7641555463990286
# Over-folds val AUC score : 0.7407102319515202
# Iteration 5
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.744712
# Fold  2 val AUC : 0.743382
# Fold  3 val AUC : 0.747552
# Fold  4 val AUC : 0.741166
# Fold  5 val AUC : 0.746429
# Over-folds train AUC score : 0.7640229546916573
# Over-folds val AUC score : 0.7442901791944492
# Iteration 6
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.739665
# Fold  2 val AUC : 0.741356
# Fold  3 val AUC : 0.737287
# Fold  4 val AUC : 0.740036
# Fold  5 val AUC : 0.745796
# Over-folds train AUC score : 0.7610278397726715
# Over-folds val AUC score : 0.739783314852249
# Iteration 7
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.738742
# Fold  2 val AUC : 0.747110
# Fold  3 val AUC : 0.749465
# Fold  4 val AUC : 0.731543
# Fold  5 val AUC : 0.743478
# Over-folds train AUC score : 0.7616524338769088
# Over-folds val AUC score : 0.740351658373887
# Iteration 8
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.748368
# Fold  2 val AUC : 0.742750
# Fold  3 val AUC : 0.727364
# Fold  4 val AUC : 0.747363
# Fold  5 val AUC : 0.707277
# Over-folds train AUC score : 0.7598437950976737
# Over-folds val AUC score : 0.7343348399565597
# Iteration 9
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.750071
# Fold  2 val AUC : 0.740032
# Fold  3 val AUC : 0.718086
# Fold  4 val AUC : 0.740211
# Fold  5 val AUC : 0.736770
# Over-folds train AUC score : 0.7599269596566732
# Over-folds val AUC score : 0.7367903421245325
# Over-iterations val AUC score : 0.738588396472508
# Standard deviation : 0.0034601222524298825
# useless/overfitting features: 'OCCUPATION_TYPE_Accountants', 'OCCUPATION_TYPE_High skill tech staff', 'OCCUPATION_TYPE_Laborers', 'OCCUPATION_TYPE_Low-skill Laborers', 'OBS_60_CNT_SOCIAL_CIRCLE', 'OCCUPATION_TYPE_Drivers', 'OCCUPATION_TYPE_Core staff', 'NEW_DOC_IND_STD', 'NEW_RATIO_BURO_AMT_CREDIT_SUM_LIMIT_MEAN', 'NEW_DOC_IND_KURT', 'NEW_ANNUITY_TO_INCOME_RATIO', 'NAME_TYPE_SUITE_Other_B', 'NAME_INCOME_TYPE_State servant', 'NAME_HOUSING_TYPE_Office apartment', 'NAME_HOUSING_TYPE_Municipal apartment', 'NAME_HOUSING_TYPE_House / apartment', 'NAME_FAMILY_STATUS_Single / not married', 'NAME_FAMILY_STATUS_Married', 'NAME_EDUCATION_TYPE_Secondary / secondary special', 'NAME_EDUCATION_TYPE_Lower secondary', 'NAME_CONTRACT_TYPE_Revolving loans', 'NAME_CONTRACT_TYPE_Cash loans', 'OCCUPATION_TYPE_Medicine staff', 'POS_NAME_CONTRACT_STATUS_Active_MEAN', 'OCCUPATION_TYPE_Sales staff', 'PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN', 'PREV_NAME_PAYMENT_TYPE_XNA_MEAN', 'PREV_NAME_PORTFOLIO_Cards_MEAN', 'PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN', 'PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN', 'PREV_NAME_TYPE_SUITE_nan_MEAN', 'PREV_NAME_YIELD_GROUP_high_MEAN', 'PREV_NAME_YIELD_GROUP_low_action_MEAN', 'PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN', 'PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN', 'PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN', 'PREV_RATE_DOWN_PAYMENT_MEAN', 'REFUSED_APP_CREDIT_PERC_MIN', 'REFUSED_HUMAN_EVAL_SUM', 'REFUSED_TIME_DECAYED_HUMAN_EVAL_SUM', 'REGION_POPULATION_RELATIVE', 'REG_CITY_NOT_LIVE_CITY', 'SOCIAL_PRED', 'WALLSMATERIAL_MODE_Others', 'WALLSMATERIAL_MODE_Panel', 'WALLSMATERIAL_MODE_Stone, brick', 'WEEKDAY_APPR_PROCESS_START_MONDAY', 'WEEKDAY_APPR_PROCESS_START_SUNDAY', 'WEEKDAY_APPR_PROCESS_START_TUESDAY', 'WEEKDAY_APPR_PROCESS_START_WEDNESDAY', 'YEARS_BEGINEXPLUATATION_MEDI', 'PREV_NAME_GOODS_CATEGORY_XNA_MEAN', 'PREV_NAME_CLIENT_TYPE_Refreshed_MEAN', 'ORGANIZATION_TYPE_Bank', 'PREV_CODE_REJECT_REASON_SCO_MEAN', 'ORGANIZATION_TYPE_Business Entity Type 3', 'ORGANIZATION_TYPE_Construction', 'ORGANIZATION_TYPE_Hotel', 'ORGANIZATION_TYPE_Industry: type 9', 'ORGANIZATION_TYPE_Kindergarten', 'ORGANIZATION_TYPE_Medicine', 'ORGANIZATION_TYPE_Military', 'ORGANIZATION_TYPE_Police', 'ORGANIZATION_TYPE_Restaurant', 'ORGANIZATION_TYPE_School', 'ORGANIZATION_TYPE_Security Ministries', 'ORGANIZATION_TYPE_Self-employed', 'ORGANIZATION_TYPE_Transport: type 3', 'OWN_CAR_AGE', 'OWN_CAR_AGE_BY_NAME_EDUCATION_TYPE_OCCUPATION_TYPE', 'POS_MONTHS_BALANCE_MAX', 'LIVE_CITY_NOT_WORK_CITY', 'POS_SK_DPD_DEF_MAX', 'POS_TIME_DECAYED_UNPAYED_RATIO_MAX', 'POS_TIME_DECAYED_UNPAYED_RATIO_MEAN', 'POS_TIME_DECAYED_UNPAYED_RATIO_SUM', 'PREV_AMT_ANNUITY_MEAN', 'PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN', 'PREV_CHANNEL_TYPE_Credit and cash offices_MEAN', 'PREV_CODE_REJECT_REASON_CLIENT_MEAN', 'LIVINGAREA_MEDI', 'ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN', 'INSTAL_PAYMENT_PERC_SUM_SUM', 'CC_CNT_DRAWINGS_CURRENT_MEAN', 'BURO_AMT_CREDIT_SUM_SUM', 'BURO_CREDIT_TYPE_Car loan_MEAN', 'BURO_CREDIT_TYPE_Credit card_MEAN', 'BURO_CREDIT_TYPE_Microloan_MEAN', 'BURO_CREDIT_TYPE_Mortgage_MEAN', 'BURO_DAYS_CREDIT_ENDDATE_MAX', 'CC_AMT_BALANCE_MAX', 'CC_AMT_BALANCE_MEAN', 'CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN', 'CC_AMT_DRAWINGS_ATM_CURRENT_MEAN', 'CC_AMT_INST_MIN_REGULARITY_VAR', 'CC_AMT_PAYMENT_CURRENT_SUM', 'CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN', 'CC_AMT_PAYMENT_TOTAL_CURRENT_SUM', 'CC_AMT_RECEIVABLE_PRINCIPAL_MAX', 'CC_AMT_RECEIVABLE_PRINCIPAL_MEAN', 'CC_AMT_RECIVABLE_MAX', 'CC_AMT_RECIVABLE_MEAN', 'CC_AMT_RECIVABLE_SUM', 'CC_AMT_RECIVABLE_VAR', 'CC_AMT_TOTAL_RECEIVABLE_MAX', 'CC_AMT_TOTAL_RECEIVABLE_MEAN', 'CC_AMT_TOTAL_RECEIVABLE_MIN', 'CC_AMT_TOTAL_RECEIVABLE_SUM', 'CC_AMT_TOTAL_RECEIVABLE_VAR', 'BURO_AMT_CREDIT_SUM_OVERDUE_MEAN', 'BURO_AMT_CREDIT_SUM_MEAN', 'BURO_AMT_CREDIT_SUM_MAX', 'AMT_ANNUITY_BY_ORGANIZATION_TYPE_OCCUPATION_TYPE', 'ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN', 'ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN', 'ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM', 'ACTIVE_AMT_CREDIT_ ...
# Run LightGBM with kfold - done in 364s
# loading features: base_featurs_filled_knn_15_wo_target.h5
# Iteration 0
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.746556
# Fold  2 val AUC : 0.741693
# Fold  3 val AUC : 0.750720
# Fold  4 val AUC : 0.745365
# Fold  5 val AUC : 0.735587
# Over-folds train AUC score : 0.7634345418602351
# Over-folds val AUC score : 0.7436007654575371
# Iteration 1
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.750974
# Fold  2 val AUC : 0.716407
# Fold  3 val AUC : 0.744531
# Fold  4 val AUC : 0.740554
# Fold  5 val AUC : 0.744358
# Over-folds train AUC score : 0.7632320908203598
# Over-folds val AUC score : 0.7385462784813168
# Iteration 2
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.748464
# Fold  2 val AUC : 0.748500
# Fold  3 val AUC : 0.742853
# Fold  4 val AUC : 0.746684
# Fold  5 val AUC : 0.737725
# Over-folds train AUC score : 0.7634728344732312
# Over-folds val AUC score : 0.7446893051382316
# Iteration 3
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.748600
# Fold  2 val AUC : 0.740434
# Fold  3 val AUC : 0.739210
# Fold  4 val AUC : 0.747951
# Fold  5 val AUC : 0.751193
# Over-folds train AUC score : 0.7627459592502155
# Over-folds val AUC score : 0.7437981315540705
# Iteration 4
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.745658
# Fold  2 val AUC : 0.742845
# Fold  3 val AUC : 0.747814
# Fold  4 val AUC : 0.743618
# Fold  5 val AUC : 0.745143
# Over-folds train AUC score : 0.7628039694848395
# Over-folds val AUC score : 0.7440340382123005
# Iteration 5
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.741119
# Fold  2 val AUC : 0.737648
# Fold  3 val AUC : 0.744002
# Fold  4 val AUC : 0.740774
# Fold  5 val AUC : 0.738367
# Over-folds train AUC score : 0.761912776734529
# Over-folds val AUC score : 0.73971235592426
# Iteration 6
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.741413
# Fold  2 val AUC : 0.748168
# Fold  3 val AUC : 0.745274
# Fold  4 val AUC : 0.746891
# Fold  5 val AUC : 0.747886
# Over-folds train AUC score : 0.764197493832864
# Over-folds val AUC score : 0.7457817276385701
# Iteration 7
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.749026
# Fold  2 val AUC : 0.751104
# Fold  3 val AUC : 0.736856
# Fold  4 val AUC : 0.745862
# Fold  5 val AUC : 0.743759
# Over-folds train AUC score : 0.7626471573931964
# Over-folds val AUC score : 0.7446864251570803
# Iteration 8
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.743288
# Fold  2 val AUC : 0.745691
# Fold  3 val AUC : 0.748886
# Fold  4 val AUC : 0.729209
# Fold  5 val AUC : 0.749084
# Over-folds train AUC score : 0.7635248504767808
# Over-folds val AUC score : 0.741847117638755
# Iteration 9
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.722077
# Fold  2 val AUC : 0.748156
# Fold  3 val AUC : 0.741655
# Fold  4 val AUC : 0.740475
# Fold  5 val AUC : 0.714734
# Over-folds train AUC score : 0.7604900874919049
# Over-folds val AUC score : 0.7326165732772875
# Over-iterations val AUC score : 0.7419312718479408
# Standard deviation : 0.003793021051909003
# useless/overfitting features: 'REGION_POPULATION_RELATIVE', 'REG_CITY_NOT_LIVE_CITY', 'NAME_HOUSING_TYPE_Municipal apartment', 'WEEKDAY_APPR_PROCESS_START_WEDNESDAY', 'REFUSED_TIME_DECAYED_HUMAN_EVAL_SUM', 'YEARS_BEGINEXPLUATATION_MEDI', 'OBS_60_CNT_SOCIAL_CIRCLE', 'WEEKDAY_APPR_PROCESS_START_TUESDAY', 'NAME_FAMILY_STATUS_Married', 'NAME_EDUCATION_TYPE_Lower secondary', 'NAME_EDUCATION_TYPE_Secondary / secondary special', 'NAME_HOUSING_TYPE_Office apartment', 'NAME_FAMILY_STATUS_Single / not married', 'WALLSMATERIAL_MODE_Stone, brick', 'OCCUPATION_TYPE_Core staff', 'NAME_INCOME_TYPE_State servant', 'NAME_TYPE_SUITE_Other_B', 'NEW_DOC_IND_KURT', 'NEW_DOC_IND_STD', 'WEEKDAY_APPR_PROCESS_START_MONDAY', 'WALLSMATERIAL_MODE_Panel', 'WALLSMATERIAL_MODE_Others', 'SOCIAL_PRED', 'NEW_RATIO_BURO_AMT_CREDIT_SUM_LIMIT_MEAN', 'WEEKDAY_APPR_PROCESS_START_SUNDAY', 'NAME_HOUSING_TYPE_House / apartment', 'OCCUPATION_TYPE_Accountants', 'ORGANIZATION_TYPE_Business Entity Type 3', 'OCCUPATION_TYPE_Drivers', 'PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN', 'POS_TIME_DECAYED_UNPAYED_RATIO_MAX', 'POS_TIME_DECAYED_UNPAYED_RATIO_MEAN', 'POS_TIME_DECAYED_UNPAYED_RATIO_SUM', 'PREV_AMT_ANNUITY_MEAN', 'PREV_APP_CREDIT_PERC_MIN', 'PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN', 'PREV_CHANNEL_TYPE_Credit and cash offices_MEAN', 'PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN', 'PREV_CODE_REJECT_REASON_CLIENT_MEAN', 'PREV_CODE_REJECT_REASON_SCO_MEAN', 'PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN', 'OCCUPATION_TYPE_High skill tech staff', 'PREV_NAME_CLIENT_TYPE_New_MEAN', 'PREV_NAME_CLIENT_TYPE_Refreshed_MEAN', 'PREV_NAME_YIELD_GROUP_low_action_MEAN', 'PREV_NAME_YIELD_GROUP_high_MEAN', 'PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN', 'PREV_NAME_PAYMENT_TYPE_XNA_MEAN', 'PREV_NAME_PORTFOLIO_Cards_MEAN', 'PREV_NAME_TYPE_SUITE_nan_MEAN', 'PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN', 'PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN', 'NAME_CONTRACT_TYPE_Cash loans', 'POS_NAME_CONTRACT_STATUS_Active_MEAN', 'PREV_RATE_DOWN_PAYMENT_MEAN', 'POS_MONTHS_BALANCE_MAX', 'OCCUPATION_TYPE_Laborers', 'REFUSED_HUMAN_EVAL_SUM', 'OCCUPATION_TYPE_Low-skill Laborers', 'OCCUPATION_TYPE_Medicine staff', 'OCCUPATION_TYPE_Sales staff', 'ORGANIZATION_TYPE_Bank', 'ORGANIZATION_TYPE_Construction', 'ORGANIZATION_TYPE_Hotel', 'ORGANIZATION_TYPE_Industry: type 9', 'ORGANIZATION_TYPE_Kindergarten', 'REFUSED_APP_CREDIT_PERC_MIN', 'ORGANIZATION_TYPE_Medicine', 'ORGANIZATION_TYPE_Military', 'ORGANIZATION_TYPE_Police', 'ORGANIZATION_TYPE_Restaurant', 'ORGANIZATION_TYPE_School', 'ORGANIZATION_TYPE_Security Ministries', 'ORGANIZATION_TYPE_Self-employed', 'ORGANIZATION_TYPE_Transport: type 3', 'OWN_CAR_AGE', 'OWN_CAR_AGE_BY_NAME_EDUCATION_TYPE_OCCUPATION_TYPE', 'NAME_CONTRACT_TYPE_Revolving loans', 'ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN', 'LIVINGAREA_MEDI', 'LIVE_CITY_NOT_WORK_CITY', 'BURO_AMT_CREDIT_SUM_SUM', 'BURO_CREDIT_TYPE_Car loan_MEAN', 'BURO_CREDIT_TYPE_Credit card_MEAN', 'BURO_CREDIT_TYPE_Microloan_MEAN', 'BURO_CREDIT_TYPE_Mortgage_MEAN', 'BURO_DAYS_CREDIT_ENDDATE_MAX', 'CC_AMT_BALANCE_MAX', 'CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN', 'CC_AMT_DRAWINGS_ATM_CURRENT_MEAN', 'CC_AMT_INST_MIN_REGULARITY_VAR', 'CC_AMT_PAYMENT_CURRENT_SUM', 'CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN', 'CC_AMT_PAYMENT_TOTAL_CURRENT_SUM', 'CC_AMT_RECEIVABLE_PRINCIPAL_MAX', 'CC_AMT_RECEIVABLE_PRINCIPAL_MEAN', 'CC_AMT_RECIVABLE_MAX', 'CC_AMT_RECIVABLE_SUM', 'CC_AMT_RECIVABLE_VAR', 'CC_AMT_TOTAL_RECEIVABLE_MAX', 'CC_AMT_TOTAL_RECEIVABLE_MEAN', 'CC_AMT_TOTAL_RECEIVABLE_MIN', 'CC_AMT_TOTAL_RECEIVABLE_SUM', 'CC_AMT_TOTAL_RECEIVABLE_VAR', 'CC_CNT_DRAWINGS_ATM_CURRENT_VAR', 'CC_CNT_DRAWINGS_CURRENT_MEAN', 'BURO_AMT_CREDIT_SUM_OVERDUE_MEAN', 'BURO_AMT_CREDIT_SUM_MEAN', 'BURO_AMT_CREDIT_SUM_MAX', 'AMT_ANNUITY_BY_OCCUPATION_TYPE', 'ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN', 'ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN', 'ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM', 'ACTIVE_AMT_CREDIT_SUM_MAX', 'ACTIVE_AMT_CREDIT_SUM_MEAN', 'ACTIVE_AMT_CREDIT_SUM_SUM', 'ACTIVE_DAYS_CREDIT_E ...
# Run LightGBM with kfold - done in 365s
# loading features: base_featurs_filled_knn_20_wo_target.h5
# Iteration 0
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.747405
# Fold  2 val AUC : 0.740634
# Fold  3 val AUC : 0.730414
# Fold  4 val AUC : 0.746628
# Fold  5 val AUC : 0.744106
# Over-folds train AUC score : 0.7629820384037909
# Over-folds val AUC score : 0.7412093656522493
# Iteration 1
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.735089
# Fold  2 val AUC : 0.739993
# Fold  3 val AUC : 0.749893
# Fold  4 val AUC : 0.739302
# Fold  5 val AUC : 0.752392
# Over-folds train AUC score : 0.7625066532723068
# Over-folds val AUC score : 0.7427848114577779
# Iteration 2
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.745776
# Fold  2 val AUC : 0.743328
# Fold  3 val AUC : 0.745774
# Fold  4 val AUC : 0.750176
# Fold  5 val AUC : 0.742980
# Over-folds train AUC score : 0.7618598850018204
# Over-folds val AUC score : 0.7454323308703265
# Iteration 3
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.747289
# Fold  2 val AUC : 0.735047
# Fold  3 val AUC : 0.742665
# Fold  4 val AUC : 0.746633
# Fold  5 val AUC : 0.743029
# Over-folds train AUC score : 0.7627055900668558
# Over-folds val AUC score : 0.7416350439805776
# Iteration 4
# no bugging in split
# Starting LightGBM. Train shape: (307507, 280), test shape: (48744, 280)
# Fold  1 val AUC : 0.741169
# Fold  2 val AUC : 0.740234

# %%
log_dir = '../log_imputating_exp'
init_logging(log_dir)

# %%
input_dir = "../features/filled_by_knn/"
for f_p in os.listdir(input_dir):
    print (os.path.join(input_dir, f_p))
# Out:
# ../features/filled_by_knn/base_featurs_filled_knn_10_w_target.h5
# ../features/filled_by_knn/base_featurs_filled_knn_5_wo_target.h5
# ../features/filled_by_knn/base_featurs_filled_knn_5_w_target.h5
# ../features/filled_by_knn/base_featurs_filled_knn_15_wo_target.h5
# ../features/filled_by_knn/base_featurs_filled_knn_20_wo_target.h5
# ../features/filled_by_knn/base_featurs_filled_knn_20_w_target.h5
# ../features/filled_by_knn/base_featurs_filled_knn_10_wo_target.h5
# ../features/filled_by_knn/base_featurs_filled_knn_15_w_target.h5
